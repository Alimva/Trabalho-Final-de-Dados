# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
e_cont = pd.read_csv('../../Energydata/Continent_Consumption_TWH.csv')
e_cont
# Out:
#     Year      World      OECD     BRICS    Europe  North America  \
# 0   1990  101855.54  52602.49  26621.07  20654.88       24667.23
# 1   1991  102483.56  53207.25  26434.99  20631.62       24841.68
# 2   1992  102588.23  53788.75  25993.05  20189.68       25341.77
# 3   1993  103646.56  54614.48  26283.80  20189.68       25830.23
# 4   1994  104449.03  55579.77  25993.05  20085.01       26365.21
# 5   1995  107112.30  56754.40  26946.71  20713.03       26714.11
# 6   1996  109763.94  58417.49  27481.69  21445.72       27295.61
# 7   1997  110903.68  59022.25  27446.80  21341.05       27574.73
# 8   1998  111450.29  59219.96  27528.21  21503.87       27772.44
# 9   1999  113974.00  60301.55  28319.05  21306.16       28528.39
# 10  2000  116590.75  61685.52  28923.81  21538.76       29342.49
# 11  2001  117521.15  61452.92  29528.57  21934.18       28795.88
# 12  2002  120207.68  61987.90  30552.01  21969.07       29156.41
# ...

# %%
e_cont = e_cont.set_index('Year')

# %% [markdown]
# # Analise do Consumo por Continente

# %% [markdown]
# 5 anos com maior consumo

# %%
df = e_cont.sort_values(by = ['World'], ascending = False)
df.iloc[:5, :1]
# Out:
#           World
# Year
# 2019  167553.41
# 2018  166297.37
# 2017  162459.47
# 2020  160819.64
# 2016  159377.52

# %%
df = e_cont.sort_values(by = ['OECD'], ascending = False)
df.iloc[:5, 1:2]
# Out:
#           OECD
# Year
# 2007  64883.77
# 2006  64616.28
# 2005  64453.46
# 2004  64058.04
# 2008  64034.78

# %%
df = e_cont.sort_values(by = ['BRICS'], ascending = False)
df.iloc[:5, 2:3]
# Out:
#          BRICS
# Year
# 2019  63255.57
# 2020  63162.53
# 2018  61673.89
# 2017  59429.30
# 2016  57742.95

# %%
df = e_cont.sort_values(by = ['Europe'], ascending = False)
df.iloc[:5, 3:4]
# Out:
#         Europe
# Year
# 2006  23108.81
# 2005  22864.58
# 2008  22829.69
# 2007  22829.69
# 2004  22748.28

# %%
df = e_cont.sort_values(by = ['North America'], ascending = False)
df.iloc[:5, 4:5]
# Out:
#       North America
# Year
# 2007       30424.08
# 2005       30168.22
# 2004       29993.77
# 2006       29958.88
# 2008       29644.87

# %%
df = e_cont.sort_values(by = ['Latin America'], ascending = False)
df.iloc[:5, 5:6]
# Out:
#       Latin America
# Year
# 2013        9978.54
# 2014        9943.65
# 2015        9873.87
# 2016        9745.94
# 2017        9687.79

# %%
df = e_cont.sort_values(by = ['Asia'], ascending = False)
df.iloc[:5, 6:7]
# Out:
#           Asia
# Year
# 2019  69582.29
# 2020  69256.65
# 2018  68035.50
# 2017  65721.13
# 2016  63941.74

# %%
df = e_cont.sort_values(by = ['Pacific'], ascending = False)
df.iloc[:5, 7:8]
# Out:
#       Pacific
# Year
# 2019  1802.65
# 2018  1791.02
# 2017  1791.02
# 2020  1767.76
# 2016  1767.76

# %%
df = e_cont.sort_values(by = ['Africa'], ascending = False)
df.iloc[:5, 8:9]
# Out:
#        Africa
# Year
# 2019  9641.27
# 2018  9559.86
# 2020  9408.67
# 2017  9304.00
# 2016  9106.29

# %%
df = e_cont.sort_values(by = ['Middle-East'], ascending = False)
df.iloc[:5, 9:10]
# Out:
#       Middle-East
# Year
# 2019      9455.19
# 2020      9338.89
# 2018      9257.48
# 2017      9210.96
# 2016      8862.06

# %%
df = e_cont.sort_values(by = ['CIS'], ascending = False)
df.iloc[:5, 10:11]
# Out:
#            CIS
# Year
# 1990  16049.40
# 1991  15898.21
# 1992  14339.79
# 1993  13246.57
# 2019  12490.62

# %% [markdown]
# 5 anos com menor consumo

# %%
df = e_cont.sort_values(by = ['World'])
df.iloc[:5, :1]
# Out:
#           World
# Year
# 1990  101855.54
# 1991  102483.56
# 1992  102588.23
# 1993  103646.56
# 1994  104449.03

# %%
df = e_cont.sort_values(by = ['OECD'])
df.iloc[:5, 1:2]
# Out:
#           OECD
# Year
# 1990  52602.49
# 1991  53207.25
# 1992  53788.75
# 1993  54614.48
# 1994  55579.77

# %%
df = e_cont.sort_values(by = ['BRICS'])
df.iloc[:5, 2:3]
# Out:
#          BRICS
# Year
# 1992  25993.05
# 1994  25993.05
# 1993  26283.80
# 1991  26434.99
# 1990  26621.07

# %%
df = e_cont.sort_values(by = ['Europe'])
df.iloc[:5, 3:4]
# Out:
#         Europe
# Year
# 2020  19643.07
# 1994  20085.01
# 1992  20189.68
# 1993  20189.68
# 1991  20631.62

# %%
df = e_cont.sort_values(by = ['North America'])
df.iloc[:5, 4:5]
# Out:
#       North America
# Year
# 1990       24667.23
# 1991       24841.68
# 1992       25341.77
# 1993       25830.23
# 1994       26365.21

# %%
df = e_cont.sort_values(by = ['Latin America'])
df.iloc[:5, 5:6]
# Out:
#       Latin America
# Year
# 1990        5373.06
# 1991        5500.99
# 1992        5628.92
# 1993        5675.44
# 1994        5989.45

# %%
df = e_cont.sort_values(by = ['Asia'])
df.iloc[:5, 6:7]
# Out:
#           Asia
# Year
# 1990  24574.19
# 1991  24783.53
# 1992  25690.67
# 1993  26876.93
# 1994  28098.08

# %%
df = e_cont.sort_values(by = ['Pacific'])
df.iloc[:5, 7:8]
# Out:
#       Pacific
# Year
# 1991  1186.26
# 1990  1197.89
# 1992  1209.52
# 1993  1267.67
# 1994  1279.30

# %%
df = e_cont.sort_values(by = ['Africa'])
df.iloc[:5, 8:9]
# Out:
#        Africa
# Year
# 1990  4407.77
# 1991  4535.70
# 1992  4582.22
# 1993  4721.78
# 1994  4803.19

# %%
df = e_cont.sort_values(by = ['Middle-East'])
df.iloc[:5, 9:10]
# Out:
#       Middle-East
# Year
# 1990      2581.86
# 1991      2744.68
# 1992      3081.95
# 1993      3349.44
# 1994      3640.19

# %%
df = e_cont.sort_values(by = ['CIS'])
df.iloc[:5, 10:11]
# Out:
#            CIS
# Year
# 1998  10152.99
# 1999  10373.96
# 1997  10373.96
# 2000  10501.89
# 2001  10571.67

# %% [markdown]
# Gráficos

# %%
cont = pd.read_csv('../../Energydata/Continent_Consumption_TWH.csv')
cont.pop('CIS')
cont.pop('BRICS')
cont.pop('OECD')
cont = cont.set_index('Year')

# %%
cont.iloc[:,:1].plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
cont.pop('World')
cont.pop('Pacific')
cont.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
cont = pd.read_csv('../../Energydata/Continent_Consumption_TWH.csv')
cont = cont.set_index('Year')
cont.iloc[:,:1].plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
cont.iloc[:,1:2].plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
cont.iloc[:, 2:3].plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
cont.iloc[: , 3:4].plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
cont.iloc[:, 4:5].plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
cont.iloc[: , 5:6].plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %% [markdown]
# Os 5 continentes com menor consumo em cada ano

# %%
dt = cont.T

an1 = dt.iloc[: , :6]
an2 = dt.iloc[: , 6: 11]
an3 = dt.iloc[: , 11:16]
an4 = dt.iloc[: , 16:21]
an5 = dt.iloc[: , 21:26]
an6 = dt.iloc[: , 26: ]

# %%
an1.sort_values(by = [1990]).iloc[:5, :1]
# Out:
# Year               1990
# Pacific         1197.89
# Middle-East     2581.86
# Africa          4407.77
# Latin America   5373.06
# CIS            16049.40

# %%
an1.sort_values(by = [1991]).iloc[:5, 1:2]
# Out:
# Year               1991
# Pacific         1186.26
# Middle-East     2744.68
# Africa          4535.70
# Latin America   5500.99
# CIS            15898.21

# %%
an1.sort_values(by = [1992]).iloc[:5, 2:3]
# Out:
# Year               1992
# Pacific         1209.52
# Middle-East     3081.95
# Africa          4582.22
# Latin America   5628.92
# CIS            14339.79

# %%
an1.sort_values(by = [1993]).iloc[:5, 3:4]
# Out:
# Year               1993
# Pacific         1267.67
# Middle-East     3349.44
# Africa          4721.78
# Latin America   5675.44
# CIS            13246.57

# %%
an1.sort_values(by = [1994]).iloc[:5, 4:5]
# Out:
# Year               1994
# Pacific         1279.30
# Middle-East     3640.19
# Africa          4803.19
# Latin America   5989.45
# CIS            11606.74

# %%
an1.sort_values(by = [1995]).iloc[:5, 5:6]
# Out:
# Year               1995
# Pacific         1290.93
# Middle-East     3744.86
# Africa          5000.90
# Latin America   6024.34
# CIS            11188.06

# %%
an2.sort_values(by = [1996]).iloc[:5, :1]
# Out:
# Year               1996
# Pacific         1372.34
# Middle-East     3814.64
# Africa          5152.09
# Latin America   6303.46
# CIS            10850.79

# %%
an2.sort_values(by = [1997]).iloc[:5, 1:2]
# Out:
# Year               1997
# Pacific         1407.23
# Middle-East     4058.87
# Africa          5280.02
# Latin America   6570.95
# CIS            10373.96

# %%
an2.sort_values(by = [1998]).iloc[:5, 2:3]
# Out:
# Year               1998
# Pacific         1442.12
# Middle-East     4082.13
# Africa          5431.21
# Latin America   6803.55
# CIS            10152.99

# %%
an2.sort_values(by = [1999]).iloc[:5, 3:4]
# Out:
# Year               1999
# Pacific         1477.01
# Middle-East     4244.95
# Africa          5559.14
# Latin America   6989.63
# CIS            10373.96

# %%
an2.sort_values(by = [2000]).iloc[:5, 4:5]
# Out:
# Year               2000
# Pacific         1500.27
# Middle-East     4314.73
# Africa          5617.29
# Latin America   7024.52
# CIS            10501.89

# %%
an3.sort_values(by = [2001]).iloc[:5, :1]
# Out:
# Year               2001
# Pacific         1477.01
# Middle-East     4663.63
# Africa          5756.85
# Latin America   7036.15
# CIS            10571.67

# %%
an3.sort_values(by = [2002]).iloc[:5, 1:2]
# Out:
# Year               2002
# Pacific         1523.53
# Middle-East     4884.60
# Africa          5849.89
# Latin America   7280.38
# CIS            10653.08

# %%
an3.sort_values(by = [2003]).iloc[:5, 2:3]
# Out:
# Year               2003
# Pacific         1535.16
# Middle-East     4954.38
# Africa          6140.64
# Latin America   7501.35
# CIS            11036.87

# %%
an3.sort_values(by = [2004]).iloc[:5, 3:4]
# Out:
# Year               2004
# Pacific         1558.42
# Middle-East     5245.13
# Africa          6466.28
# Latin America   7780.47
# CIS            11188.06

# %%
an3.sort_values(by = [2005]).iloc[:5, 4:5]
# Out:
# Year               2005
# Pacific         1570.05
# Middle-East     5675.44
# Africa          6652.36
# Latin America   8059.59
# CIS            11222.95

# %%
an4.sort_values(by = [2006]).iloc[:5, :1]
# Out:
# Year               2006
# Pacific         1616.57
# Middle-East     5989.45
# Africa          6861.70
# Latin America   8303.82
# CIS            11548.59

# %%
an4.sort_values(by = [2007]).iloc[:5, 1:2]
# Out:
# Year               2007
# Pacific         1663.09
# Middle-East     6315.09
# Africa          7129.19
# Latin America   8571.31
# CIS            11664.89

# %%
an4.sort_values(by = [2008]).iloc[:5, 2:3]
# Out:
# Year               2008
# Pacific         1721.24
# Middle-East     6850.07
# Africa          7443.20
# Latin America   8780.65
# CIS            11874.23

# %%
an4.sort_values(by = [2009]).iloc[:5, 3:4]
# Out:
# Year               2009
# Pacific         1721.24
# Middle-East     7059.41
# Africa          7606.02
# Latin America   8559.68
# CIS            10967.09

# %%
an4.sort_values(by = [2010]).iloc[:5, 4:5]
# Out:
# Year               2010
# Pacific         1732.87
# Middle-East     7361.79
# Africa          7803.73
# Latin America   9117.92
# CIS            11804.45

# %%
an5.sort_values(by = [2011]).iloc[:5, :1]
# Out:
# Year               2011
# Pacific         1744.50
# Middle-East     7524.61
# Africa          8117.74
# Latin America   9304.00
# CIS            12164.98

# %%
an5.sort_values(by = [2012]).iloc[:5, 1:2]
# Out:
# Year               2012
# Pacific         1744.50
# Middle-East     7943.29
# Africa          8303.82
# Latin America   9594.75
# CIS            12269.65

# %%
an5.sort_values(by = [2013]).iloc[:5, 2:3]
# Out:
# Year               2013
# Pacific         1767.76
# Middle-East     8071.22
# Africa          8431.75
# Latin America   9978.54
# CIS            12002.16

# %%
an5.sort_values(by = [2014]).iloc[:5, 3:4]
# Out:
# Year               2014
# Pacific         1767.76
# Middle-East     8513.16
# Africa          8896.95
# Latin America   9943.65
# CIS            11699.78

# %%
an5.sort_values(by = [2014]).iloc[:5, 4:5]
# Out:
# Year               2015
# Pacific         1767.76
# Middle-East     8675.98
# Africa          8838.80
# Latin America   9873.87
# CIS            11222.95

# %%
an6.sort_values(by = [2016]).iloc[:5, :1]
# Out:
# Year               2016
# Pacific         1767.76
# Middle-East     8862.06
# Africa          9106.29
# Latin America   9745.94
# CIS            11595.11

# %%
an6.sort_values(by = [2017]).iloc[:5, 1:2]
# Out:
# Year               2017
# Pacific         1791.02
# Middle-East     9210.96
# Africa          9304.00
# Latin America   9687.79
# CIS            11792.82

# %%
an6.sort_values(by = [2018]).iloc[:5, 2:3]
# Out:
# Year               2018
# Pacific         1791.02
# Middle-East     9257.48
# Latin America   9513.34
# Africa          9559.86
# CIS            12385.95

# %%
an6.sort_values(by = [2019]).iloc[:5, 3:4]
# Out:
# Year               2019
# Pacific         1802.65
# Middle-East     9455.19
# Latin America   9478.45
# Africa          9641.27
# CIS            12490.62

# %%
an6.sort_values(by = [2020]).iloc[:5, 4:5]
# Out:
# Year               2020
# Pacific         1767.76
# Latin America   8815.54
# Middle-East     9338.89
# Africa          9408.67
# CIS            11804.45

# %% [markdown]
# Os 5 continente com maior consumo em cada ano

# %%
an1.sort_values(by = [1990],ascending = False).iloc[:5, :1]
# Out:
# Year                1990
# World          101855.54
# OECD            52602.49
# BRICS           26621.07
# North America   24667.23
# Asia            24574.19

# %%
an1.sort_values(by = [1991],ascending = False).iloc[:5, 1:2]
# Out:
# Year                1991
# World          102483.56
# OECD            53207.25
# BRICS           26434.99
# North America   24841.68
# Asia            24783.53

# %%
an1.sort_values(by = [1992],ascending = False).iloc[:5, 2:3]
# Out:
# Year                1992
# World          102588.23
# OECD            53788.75
# BRICS           25993.05
# Asia            25690.67
# North America   25341.77

# %%
an1.sort_values(by = [1993],ascending = False).iloc[:5, 3:4]
# Out:
# Year                1993
# World          103646.56
# OECD            54614.48
# Asia            26876.93
# BRICS           26283.80
# North America   25830.23

# %%
an1.sort_values(by = [1994],ascending = False).iloc[:5, 4:5]
# Out:
# Year                1994
# World          104449.03
# OECD            55579.77
# Asia            28098.08
# North America   26365.21
# BRICS           25993.05

# %%
an1.sort_values(by = [1995],ascending = False).iloc[:5, 5:6]
# Out:
# Year                1995
# World          107112.30
# OECD            56754.40
# Asia            29761.17
# BRICS           26946.71
# North America   26714.11

# %%
an2.sort_values(by = [1996],ascending = False).iloc[:5, :1]
# Out:
# Year                1996
# World          109763.94
# OECD            58417.49
# Asia            30772.98
# BRICS           27481.69
# North America   27295.61

# %%
an2.sort_values(by = [1997],ascending = False).iloc[:5, 1:2]
# Out:
# Year                1997
# World          110903.68
# OECD            59022.25
# Asia            31435.89
# North America   27574.73
# BRICS           27446.80

# %%
an2.sort_values(by = [1998],ascending = False).iloc[:5, 2:3]
# Out:
# Year                1998
# World          111450.29
# OECD            59219.96
# Asia            31331.22
# North America   27772.44
# BRICS           27528.21

# %%
an2.sort_values(by = [1999],ascending = False).iloc[:5, 3:4]
# Out:
# Year                1999
# World          113974.00
# OECD            60301.55
# Asia            32412.81
# North America   28528.39
# BRICS           28319.05

# %%
an2.sort_values(by = [2000],ascending = False).iloc[:5, 4:5]
# Out:
# Year                2000
# World          116590.75
# OECD            61685.52
# Asia            33564.18
# North America   29342.49
# BRICS           28923.81

# %%
an3.sort_values(by = [2001],ascending = False).iloc[:5, :1]
# Out:
# Year                2001
# World          117521.15
# OECD            61452.92
# Asia            34227.09
# BRICS           29528.57
# North America   28795.88

# %%
an3.sort_values(by = [2002],ascending = False).iloc[:5, 1:2]
# Out:
# Year                2002
# World          120207.68
# OECD            61987.90
# Asia            35680.84
# BRICS           30552.01
# North America   29156.41

# %%
an3.sort_values(by = [2003],ascending = False).iloc[:5, 2:3]
# Out:
# Year                2003
# World          124464.26
# OECD            62871.78
# Asia            38181.29
# BRICS           33157.13
# North America   29377.38

# %%
an3.sort_values(by = [2004],ascending = False).iloc[:5, 3:4]
# Out:
# Year                2004
# World          129953.62
# OECD            64058.04
# Asia            41437.69
# BRICS           35994.85
# North America   29993.77

# %%
an3.sort_values(by = [2005],ascending = False).iloc[:5, 4:5]
# Out:
# Year                2005
# World          133582.18
# OECD            64453.46
# Asia            43693.91
# BRICS           38169.66
# North America   30168.22

# %%
an4.sort_values(by = [2006],ascending = False).iloc[:5, :1]
# Out:
# Year                2006
# World          137396.82
# OECD            64616.28
# Asia            46124.58
# BRICS           40670.11
# North America   29958.88

# %%
an4.sort_values(by = [2007],ascending = False).iloc[:5, 1:2]
# Out:
# Year                2007
# World          141211.46
# OECD            64883.77
# Asia            48555.25
# BRICS           43112.41
# North America   30424.08

# %%
an4.sort_values(by = [2008],ascending = False).iloc[:5, 2:3]
# Out:
# Year                2008
# World          142874.55
# OECD            64034.78
# Asia            49636.84
# BRICS           44635.94
# North America   29644.87

# %%
an4.sort_values(by = [2009],ascending = False).iloc[:5, 3:4]
# Out:
# Year                2009
# World          141490.58
# OECD            61197.06
# Asia            51858.17
# BRICS           46426.96
# North America   28214.38

# %%
an4.sort_values(by = [2010],ascending = False).iloc[:5, 4:5]
# Out:
# Year                2010
# World          149294.31
# OECD            63255.57
# Asia            56010.08
# BRICS           50323.01
# North America   28830.77

# %%
an5.sort_values(by = [2011],ascending = False).iloc[:5, :1]
# Out:
# Year                2011
# World          151783.13
# OECD            62127.46
# Asia            58324.45
# BRICS           53207.25
# North America   28598.17

# %%
an5.sort_values(by = [2012],ascending = False).iloc[:5, 1:2]
# Out:
# Year                2012
# World          153748.60
# OECD            61685.52
# Asia            60022.43
# BRICS           54975.01
# North America   28167.86

# %%
an5.sort_values(by = [2013],ascending = False).iloc[:5, 2:3]
# Out:
# Year                2013
# World          155958.30
# OECD            62080.94
# Asia            61499.44
# BRICS           56068.23
# North America   28667.95

# %%
an5.sort_values(by = [2014],ascending = False).iloc[:5, 3:4]
# Out:
# Year                2014
# World          157667.91
# Asia            62895.04
# OECD            61499.44
# BRICS           57405.68
# North America   29063.37

# %%
an5.sort_values(by = [2015],ascending = False).iloc[:5, 4:5]
# Out:
# Year                2015
# World          158086.59
# Asia            63476.54
# OECD            61511.07
# BRICS           57533.61
# North America   28784.25

# %%
an6.sort_values(by = [2016],ascending = False).iloc[:5, :1]
# Out:
# Year                2016
# World          159377.52
# Asia            63941.74
# OECD            61545.96
# BRICS           57742.95
# North America   28563.28

# %%
an6.sort_values(by = [2017],ascending = False).iloc[:5, 1:2]
# Out:
# Year                2017
# World          162459.47
# Asia            65721.13
# OECD            61929.75
# BRICS           59429.30
# North America   28563.28

# %%
an6.sort_values(by = [2018],ascending = False).iloc[:5, 2:3]
# Out:
# Year                2018
# World          166297.37
# Asia            68035.50
# OECD            62592.66
# BRICS           61673.89
# North America   29470.42

# %%
an6.sort_values(by = [2019],ascending = False).iloc[:5, 3:4]
# Out:
# Year                2019
# World          167553.41
# Asia            69582.29
# BRICS           63255.57
# OECD            61825.08
# North America   29249.45

# %%
an6.sort_values(by = [2020],ascending = False).iloc[:5, 4:5]
# Out:
# Year                2020
# World          160819.64
# Asia            69256.65
# BRICS           63162.53
# OECD            57487.09
# North America   27063.01

# %% [markdown]
# Gráficos

# %%
x_cont = pd.read_csv('../../Energydata/Continent_Consumption_TWH.csv')
x_cont.pop('World')
x_cont.pop('OECD')
x_cont.pop('BRICS')
x_cont.pop('CIS')

x_cont.iloc[:, :1]
a_cont = x_cont.set_index('Year').T


Y = list(x_cont.iloc[:, 1:])

# %%
X = list(x_cont.iloc[:, 1:])
Y = list(a_cont.iloc[:, 0])

plt.figure(figsize=(10, 10),facecolor='#94F088') 
plt.bar(X, Y, color='g')
plt.title("CONSUMO DE ENERGIA EM CADA CONTINENTE EM 1990", fontweight='bold')
plt.xlabel("Continente", fontweight='bold')
plt.ylabel("Consumo", fontweight='bold')
  
plt.show()

# %%
X = list(x_cont.iloc[:, 1:])
Y = list(a_cont.iloc[:, 1])

plt.figure(figsize=(10, 10),facecolor='#94F088') 
plt.bar(X, Y, color='g')
plt.title("CONSUMO DE ENERGIA EM CADA CONTINENTE EM 1992", fontweight='bold')
plt.xlabel("Consumo", fontweight='bold')
plt.ylabel("Continente", fontweight='bold')
  
plt.show()

# %%
X = list(x_cont.iloc[:, 1:])
Y = list(a_cont.iloc[:, 2])

plt.figure(figsize=(10, 10),facecolor='#94F088') 
plt.bar(X, Y, color='g')
plt.title("CONSUMO DE ENERGIA EM CADA CONTINENTE EM 1993", fontweight='bold')
plt.xlabel("Consumo", fontweight='bold')
plt.ylabel("Continente", fontweight='bold')
  
plt.show()

# %%
X = list(x_cont.iloc[:, 1:])
Y = list(a_cont.iloc[:, 3])

plt.figure(figsize=(10, 10),facecolor='#94F088') 
plt.bar(X, Y, color='g')
plt.title("CONSUMO DE ENERGIA EM CADA CONTINENTE EM 1993", fontweight='bold')
plt.xlabel("Consumo", fontweight='bold')
plt.ylabel("Continente", fontweight='bold')
  
plt.show()

# %%
X = list(x_cont.iloc[:, 1:])
Y = list(a_cont.iloc[:, 4])

plt.figure(figsize=(10, 10),facecolor='#94F088') 
plt.bar(X, Y, color='g')
plt.title("CONSUMO DE ENERGIA EM CADA CONTINENTE EM 1994", fontweight='bold')
plt.xlabel("Consumo", fontweight='bold')
plt.ylabel("Continente", fontweight='bold')
  
plt.show()

# %%
X = list(x_cont.iloc[:, 1:])
Y = list(a_cont.iloc[:, 5])

plt.figure(figsize=(10, 10),facecolor='#94F088') 
plt.bar(X, Y, color='g')
plt.title("CONSUMO DE ENERGIA EM CADA CONTINENTE EM 1995", fontweight='bold')
plt.xlabel("Consumo", fontweight='bold')
plt.ylabel("Continente", fontweight='bold')
  
plt.show()

# %%
X = list(x_cont.iloc[:, 1:])
Y = list(a_cont.iloc[:, 6])

plt.figure(figsize=(10, 10),facecolor='#94F088') 
plt.bar(X, Y, color='g')
plt.title("CONSUMO DE ENERGIA EM CADA CONTINENTE EM 1996", fontweight='bold')
plt.xlabel("Consumo", fontweight='bold')
plt.ylabel("Continente", fontweight='bold')
  
plt.show()

# %%
X = list(x_cont.iloc[:, 1:])
Y = list(a_cont.iloc[:, 7])

plt.figure(figsize=(10, 10),facecolor='#94F088') 
plt.bar(X, Y, color='g')
plt.title("CONSUMO DE ENERGIA EM CADA CONTINENTE EM 1997", fontweight='bold')
plt.xlabel("Consumo", fontweight='bold')
plt.ylabel("Continente", fontweight='bold')
  
plt.show()

# %%
X = list(x_cont.iloc[:, 1:])
Y = list(a_cont.iloc[:, 8])

plt.figure(figsize=(10, 10),facecolor='#94F088') 
plt.bar(X, Y, color='g')
plt.title("CONSUMO DE ENERGIA EM CADA CONTINENTE EM 1998", fontweight='bold')
plt.xlabel("Consumo", fontweight='bold')
plt.ylabel("Continente", fontweight='bold')
  
plt.show()

# %%
X = list(x_cont.iloc[:, 1:])
Y = list(a_cont.iloc[:, 9])

plt.figure(figsize=(10, 10),facecolor='#94F088') 
plt.bar(X, Y, color='g')
plt.title("CONSUMO DE ENERGIA EM CADA CONTINENTE EM 1999", fontweight='bold')
plt.xlabel("Consumo", fontweight='bold')
plt.ylabel("Continente", fontweight='bold')
  
plt.show()

# %%
X = list(x_cont.iloc[:, 1:])
Y = list(a_cont.iloc[:, 10])

plt.figure(figsize=(10, 10),facecolor='#94F088') 
plt.bar(X, Y, color='g')
plt.title("CONSUMO DE ENERGIA EM CADA CONTINENTE EM 2000", fontweight='bold')
plt.xlabel("Consumo", fontweight='bold')
plt.ylabel("Continente", fontweight='bold')
  
plt.show()

# %%
X = list(x_cont.iloc[:, 1:])
Y = list(a_cont.iloc[:, 11])

plt.figure(figsize=(10, 10),facecolor='#94F088') 
plt.bar(X, Y, color='g')
plt.title("CONSUMO DE ENERGIA EM CADA CONTINENTE EM 2001", fontweight='bold')
plt.xlabel("Consumo", fontweight='bold')
plt.ylabel("Continente", fontweight='bold')
  
plt.show()

# %%
X = list(x_cont.iloc[:, 1:])
Y = list(a_cont.iloc[:, 12])

plt.figure(figsize=(10, 10),facecolor='#94F088') 
plt.bar(X, Y, color='g')
plt.title("CONSUMO DE ENERGIA EM CADA CONTINENTE EM 2002", fontweight='bold')
plt.xlabel("Consumo", fontweight='bold')
plt.ylabel("Continente", fontweight='bold')
  
plt.show()

# %%
X = list(x_cont.iloc[:, 1:])
Y = list(a_cont.iloc[:, 13])

plt.figure(figsize=(10, 10),facecolor='#94F088') 
plt.bar(X, Y, color='g')
plt.title("CONSUMO DE ENERGIA EM CADA CONTINENTE EM 2003", fontweight='bold')
plt.xlabel("Consumo", fontweight='bold')
plt.ylabel("Continente", fontweight='bold')
  
plt.show()

# %%
X = list(x_cont.iloc[:, 1:])
Y = list(a_cont.iloc[:, 14])

plt.figure(figsize=(10, 10),facecolor='#94F088') 
plt.bar(X, Y, color='g')
plt.title("CONSUMO DE ENERGIA EM CADA CONTINENTE EM 2004", fontweight='bold')
plt.xlabel("Consumo", fontweight='bold')
plt.ylabel("Continente", fontweight='bold')
  
plt.show()

# %%
X = list(x_cont.iloc[:, 1:])
Y = list(a_cont.iloc[:, 15])

plt.figure(figsize=(10, 10),facecolor='#94F088') 
plt.bar(X, Y, color='g')
plt.title("CONSUMO DE ENERGIA EM CADA CONTINENTE EM 2005", fontweight='bold')
plt.xlabel("Consumo", fontweight='bold')
plt.ylabel("Continente", fontweight='bold')
  
plt.show()

# %%
X = list(x_cont.iloc[:, 1:])
Y = list(a_cont.iloc[:, 16])

plt.figure(figsize=(10, 10),facecolor='#94F088') 
plt.bar(X, Y, color='g')
plt.title("CONSUMO DE ENERGIA EM CADA CONTINENTE EM 2006", fontweight='bold')
plt.xlabel("Consumo", fontweight='bold')
plt.ylabel("Continente", fontweight='bold')
  
plt.show()

# %%
X = list(x_cont.iloc[:, 1:])
Y = list(a_cont.iloc[:, 17])

plt.figure(figsize=(10, 10),facecolor='#94F088') 
plt.bar(X, Y, color='g')
plt.title("CONSUMO DE ENERGIA EM CADA CONTINENTE EM 2007", fontweight='bold')
plt.xlabel("Consumo", fontweight='bold')
plt.ylabel("Continente", fontweight='bold')
  
plt.show()

# %%
X = list(x_cont.iloc[:, 1:])
Y = list(a_cont.iloc[:, 18])

plt.figure(figsize=(10, 10),facecolor='#94F088') 
plt.bar(X, Y, color='g')
plt.title("CONSUMO DE ENERGIA EM CADA CONTINENTE EM 2008", fontweight='bold')
plt.xlabel("Consumo", fontweight='bold')
plt.ylabel("Continente", fontweight='bold')
  
plt.show()

# %%
X = list(x_cont.iloc[:, 1:])
Y = list(a_cont.iloc[:, 19])

plt.figure(figsize=(10, 10),facecolor='#94F088') 
plt.bar(X, Y, color='g')
plt.title("CONSUMO DE ENERGIA EM CADA CONTINENTE EM 2009", fontweight='bold')
plt.xlabel("Consumo", fontweight='bold')
plt.ylabel("Continente", fontweight='bold')
  
plt.show()

# %%
X = list(x_cont.iloc[:, 1:])
Y = list(a_cont.iloc[:, 20])

plt.figure(figsize=(10, 10),facecolor='#94F088') 
plt.bar(X, Y, color='g')
plt.title("CONSUMO DE ENERGIA EM CADA CONTINENTE EM 2010", fontweight='bold')
plt.xlabel("Consumo", fontweight='bold')
plt.ylabel("Continente", fontweight='bold')
  
plt.show()

# %%
X = list(x_cont.iloc[:, 1:])
Y = list(a_cont.iloc[:, 21])

plt.figure(figsize=(10, 10),facecolor='#94F088') 
plt.bar(X, Y, color='g')
plt.title("CONSUMO DE ENERGIA EM CADA CONTINENTE EM 2011", fontweight='bold')
plt.xlabel("Consumo", fontweight='bold')
plt.ylabel("Continente", fontweight='bold')
  
plt.show()

# %%
X = list(x_cont.iloc[:, 1:])
Y = list(a_cont.iloc[:, 22])

plt.figure(figsize=(10, 10),facecolor='#94F088') 
plt.bar(X, Y, color='g')
plt.title("CONSUMO DE ENERGIA EM CADA CONTINENTE EM 2012", fontweight='bold')
plt.xlabel("Consumo", fontweight='bold')
plt.ylabel("Continente", fontweight='bold')
  
plt.show()

# %%
X = list(x_cont.iloc[:, 1:])
Y = list(a_cont.iloc[:, 23])

plt.figure(figsize=(10, 10),facecolor='#94F088') 
plt.bar(X, Y, color='g')
plt.title("CONSUMO DE ENERGIA EM CADA CONTINENTE EM 2013", fontweight='bold')
plt.xlabel("Consumo", fontweight='bold')
plt.ylabel("Continente", fontweight='bold')
  
plt.show()

# %%
X = list(x_cont.iloc[:, 1:])
Y = list(a_cont.iloc[:, 24])

plt.figure(figsize=(10, 10),facecolor='#94F088') 
plt.bar(X, Y, color='g')
plt.title("CONSUMO DE ENERGIA EM CADA CONTINENTE EM 2014", fontweight='bold')
plt.xlabel("Consumo", fontweight='bold')
plt.ylabel("Continente", fontweight='bold')
  
plt.show()

# %%
X = list(x_cont.iloc[:, 1:])
Y = list(a_cont.iloc[:, 25])

plt.figure(figsize=(10, 10),facecolor='#94F088') 
plt.bar(X, Y, color='g')
plt.title("CONSUMO DE ENERGIA EM CADA CONTINENTE EM 2015", fontweight='bold')
plt.xlabel("Consumo", fontweight='bold')
plt.ylabel("Continente", fontweight='bold')
  
plt.show()

# %%
X = list(x_cont.iloc[:, 1:])
Y = list(a_cont.iloc[:, 26])

plt.figure(figsize=(10, 10),facecolor='#94F088') 
plt.bar(X, Y, color='g')
plt.title("CONSUMO DE ENERGIA EM CADA CONTINENTE EM 2016", fontweight='bold')
plt.xlabel("Consumo", fontweight='bold')
plt.ylabel("Continente", fontweight='bold')
  
plt.show()

# %%
X = list(x_cont.iloc[:, 1:])
Y = list(a_cont.iloc[:, 27])

plt.figure(figsize=(10, 10),facecolor='#94F088') 
plt.bar(X, Y, color='g')
plt.title("CONSUMO DE ENERGIA EM CADA CONTINENTE EM 2017", fontweight='bold')
plt.xlabel("Consumo", fontweight='bold')
plt.ylabel("Continente", fontweight='bold')
  
plt.show()

# %%
X = list(x_cont.iloc[:, 1:])
Y = list(a_cont.iloc[:, 28])

plt.figure(figsize=(10, 10),facecolor='#94F088') 
plt.bar(X, Y, color='g')
plt.title("CONSUMO DE ENERGIA EM CADA CONTINENTE EM 2018", fontweight='bold')
plt.xlabel("Consumo", fontweight='bold')
plt.ylabel("Continente", fontweight='bold')
  
plt.show()

# %%
X = list(x_cont.iloc[:, 1:])
Y = list(a_cont.iloc[:, 29])

plt.figure(figsize=(10, 10),facecolor='#94F088') 
plt.bar(X, Y, color='g')
plt.title("CONSUMO DE ENERGIA EM CADA CONTINENTE EM 2019", fontweight='bold')
plt.xlabel("Consumo", fontweight='bold')
plt.ylabel("Continente", fontweight='bold')
  
plt.show()

# %%
X = list(x_cont.iloc[:, 1:])
Y = list(a_cont.iloc[:, 30])

plt.figure(figsize=(10, 10),facecolor='#94F088') 
plt.bar(X, Y, color='g')
plt.title("CONSUMO DE ENERGIA EM CADA CONTINENTE EM 2020", fontweight='bold')
plt.xlabel("Consumo", fontweight='bold')
plt.ylabel("Continente", fontweight='bold')
  
plt.show()

# %% [markdown]
# # Analise do Consumo por país

# %%
e_pais = pd.read_csv("../../Energydata/Country_Consumption_TWH.csv")
e_pais
# Out:
#       Year   China  United States  Brazil  Belgium  Czechia  France  Germany  \
# 0   1990.0   874.0         1910.0   141.0     48.0     50.0   225.0    351.0
# 1   1991.0   848.0         1925.0   143.0     50.0     45.0   237.0    344.0
# 2   1992.0   877.0         1964.0   145.0     51.0     44.0   234.0    338.0
# 3   1993.0   929.0         1998.0   148.0     49.0     43.0   238.0    335.0
# 4   1994.0   973.0         2036.0   156.0     52.0     41.0   231.0    333.0
# 5   1995.0  1045.0         2063.0   162.0     53.0     42.0   240.0    336.0
# 6   1996.0  1074.0         2108.0   170.0     56.0     43.0   251.0    348.0
# 7   1997.0  1073.0         2130.0   179.0     56.0     43.0   244.0    345.0
# 8   1998.0  1079.0         2148.0   183.0     57.0     42.0   252.0    343.0
# 9   1999.0  1099.0         2206.0   187.0     57.0     39.0   252.0    335.0
# 10  2000.0  1130.0         2269.0   188.0     58.0     41.0   255.0    337.0
# ...

# %%
e_pais = e_pais.set_index('Year')

# %% [markdown]
# 5 anos de maior consumo em cada país

# %%
df = e_pais.sort_values(by = ['China'],ascending = False)
df.iloc[ :5, :1]
# Out:
#          China
# Year
# 2020.0  3381.0
# 2019.0  3309.0
# 2018.0  3201.0
# 2017.0  3070.0
# 2015.0  2994.0

# %%
dt = df.sort_values(by = ['United States'],ascending = False)
dt.iloc[ :5, 1:2]
# Out:
#         United States
# Year
# 2007.0         2338.0
# 2005.0         2320.0
# 2004.0         2308.0
# 2006.0         2298.0
# 2008.0         2278.0

# %%
df = e_pais.sort_values(by = ['Brazil'],ascending = False)
df.iloc[ :5, 2:3]
# Out:
#         Brazil
# Year
# 2014.0   303.0
# 2015.0   297.0
# 2013.0   294.0
# 2019.0   293.0
# 2017.0   292.0

# %%
df = e_pais.sort_values(by = ['Belgium'],ascending = False)
df.iloc[ :5, 3:4]
# Out:
#         Belgium
# Year
# 2010.0     60.0
# 2005.0     58.0
# 2000.0     58.0
# 2008.0     58.0
# 2004.0     58.0

# %%
df = e_pais.sort_values(by = ['Czechia'],ascending = False)
df.iloc[ :5, 4:5]
# Out:
#         Czechia
# Year
# 1990.0     50.0
# 2007.0     46.0
# 2006.0     46.0
# 2004.0     46.0
# 2003.0     45.0

# %%
df = e_pais.sort_values(by = ['France'],ascending = False)
df.iloc[ :5, 5:6]
# Out:
#         France
# Year
# 2005.0   273.0
# 2004.0   271.0
# 2006.0   268.0
# 2003.0   268.0
# 2008.0   266.0

# %%
df = e_pais.sort_values(by = ['Germany'],ascending = False)
df.iloc[ :5, 6:7]
# Out:
#         Germany
# Year
# 1990.0    351.0
# 2006.0    349.0
# 1996.0    348.0
# 2001.0    347.0
# 1997.0    345.0

# %%
df = e_pais.sort_values(by = ['Italy'],ascending = False)
df.iloc[ :5, 7:8]
# Out:
#         Italy
# Year
# 2005.0  187.0
# 2006.0  185.0
# 2007.0  184.0
# 2004.0  183.0
# 2008.0  182.0

# %%
df = e_pais.sort_values(by = ['Netherlands'],ascending = False)
df.iloc[ :5, 8:9]
# Out:
#         Netherlands
# Year
# 2010.0         83.0
# 2004.0         81.0
# 2005.0         80.0
# 2003.0         80.0
# 2007.0         79.0

# %%
df = e_pais.sort_values(by = ['Poland'],ascending = False)
df.iloc[ :5, 9:10]
# Out:
#         Poland
# Year
# 2018.0   106.0
# 2017.0   104.0
# 1996.0   104.0
# 2019.0   103.0
# 1990.0   103.0

# %%
dt = df.sort_values(by = ['Portugal'],ascending = False)
dt.iloc[ :5, 10:11]
# Out:
#         Portugal
# Year
# 2002.0      26.0
# 2004.0      26.0
# 2005.0      26.0
# 2008.0      25.0
# 2007.0      25.0

# %%
df = e_pais.sort_values(by = ['Romania'],ascending = False)
df.iloc[ :5, 11:12]
# Out:
#         Romania
# Year
# 1990.0     62.0
# 1991.0     51.0
# 1996.0     48.0
# 1995.0     47.0
# 1992.0     46.0

# %%
df = e_pais.sort_values(by = ['Spain'],ascending = False)
df.iloc[ :5, 12:13]
# Out:
#         Spain
# Year
# 2007.0  143.0
# 2005.0  142.0
# 2006.0  141.0
# 2008.0  139.0
# 2004.0  139.0

# %%
df = e_pais.sort_values(by = ['Sweden'],ascending = False)
df.iloc[ :5, 13:14]
# Out:
#         Sweden
# Year
# 2004.0    53.0
# 2005.0    52.0
# 2002.0    52.0
# 2010.0    51.0
# 1996.0    51.0

# %%
df = e_pais.sort_values(by = ['United Kingdom'],ascending = False)
df.iloc[ :5, 14:15]
# Out:
#         United Kingdom
# Year
# 1996.0           226.0
# 2003.0           224.0
# 2001.0           224.0
# 2005.0           223.0
# 2000.0           223.0

# %%
df = e_pais.sort_values(by = ['Norway'],ascending = False)
df.iloc[ :5, 15:16]
# Out:
#         Norway
# Year
# 2013.0    33.0
# 2010.0    33.0
# 2009.0    32.0
# 2008.0    32.0
# 2012.0    31.0

# %%
df = e_pais.sort_values(by = ['Turkey'],ascending = False)
df.iloc[ :5, 16:17]
# Out:
#         Turkey
# Year
# 2017.0   147.0
# 2019.0   145.0
# 2018.0   144.0
# 2020.0   141.0
# 2016.0   137.0

# %%
df = e_pais.sort_values(by = ['Kazakhstan'],ascending = False)
df.iloc[ :5, 17:18]
# Out:
#         Kazakhstan
# Year
# 2013.0        82.0
# 1992.0        79.0
# 2019.0        77.0
# 2011.0        77.0
# 2018.0        76.0

# %%
df = e_pais.sort_values(by = ['Russia'],ascending = False)
df.iloc[ :5, 18:19]
# Out:
#         Russia
# Year
# 1990.0   879.0
# 1991.0   871.0
# 1992.0   795.0
# 2019.0   768.0
# 2018.0   760.0

# %%
df = e_pais.sort_values(by = ['Ukraine'],ascending = False)
df.iloc[ :5, 19:20]
# Out:
#         Ukraine
# Year
# 1990.0    252.0
# 1991.0    252.0
# 1992.0    220.0
# 1993.0    195.0
# 1994.0    166.0

# %%
df = e_pais.sort_values(by = ['Uzbekistan'],ascending = False)
df.iloc[ :5, 20:21]
# Out:
#         Uzbekistan
# Year
# 2002.0        53.0
# 2004.0        51.0
# 2000.0        51.0
# 2001.0        51.0
# 2003.0        51.0

# %%
df = e_pais.sort_values(by = ['Argentina'],ascending = False)
df.iloc[ :5, 21:22]
# Out:
#         Argentina
# Year
# 2015.0       83.0
# 2017.0       82.0
# 2016.0       82.0
# 2014.0       82.0
# 2013.0       82.0

# %%
df = e_pais.sort_values(by = ['Canada'],ascending = False)
df.iloc[ :5, 22:23]
# Out:
#         Canada
# Year
# 2019.0   301.0
# 2018.0   298.0
# 2017.0   295.0
# 2016.0   287.0
# 2015.0   283.0

# %%
df = e_pais.sort_values(by = ['Chile'],ascending = False)
df.iloc[ :5, 23:24]
# Out:
#         Chile
# Year
# 2019.0   40.0
# 2018.0   39.0
# 2020.0   38.0
# 2017.0   38.0
# 2016.0   38.0

# %%
df = e_pais.sort_values(by = ['Colombia'],ascending = False)
df.iloc[ :5, 24:25]
# Out:
#         Colombia
# Year
# 2016.0      42.0
# 2015.0      41.0
# 2019.0      41.0
# 2013.0      40.0
# 2017.0      40.0

# %%
df = e_pais.sort_values(by = ['Mexico'],ascending = False)
df.iloc[ :5, 25:26]
# Out:
#         Mexico
# Year
# 2012.0   192.0
# 2013.0   192.0
# 2014.0   188.0
# 2011.0   187.0
# 2016.0   185.0

# %%
df = e_pais.sort_values(by = ['Venezuela'],ascending = False)
df.iloc[ :5, 26:27]
# Out:
#         Venezuela
# Year
# 2013.0       76.0
# 2010.0       75.0
# 2012.0       69.0
# 2011.0       67.0
# 2002.0       67.0

# %%
df = e_pais.sort_values(by = ['Indonesia'],ascending = False)
df.iloc[ :5, 27:28]
# Out:
#         Indonesia
# Year
# 2019.0      237.0
# 2018.0      231.0
# 2020.0      225.0
# 2017.0      222.0
# 2016.0      209.0

# %%
df = e_pais.sort_values(by = ['Japan'],ascending = False)
df.iloc[ :5, 28:29]
# Out:
#         Japan
# Year
# 2004.0  526.0
# 2005.0  524.0
# 2006.0  524.0
# 2000.0  520.0
# 2007.0  519.0

# %%
df = e_pais.sort_values(by = ['Malaysia'],ascending = False)
df.iloc[ :5, 29:30]
# Out:
#         Malaysia
# Year
# 2019.0      96.0
# 2018.0      94.0
# 2014.0      89.0
# 2020.0      88.0
# 2016.0      88.0

# %%
df = e_pais.sort_values(by = ['South Korea'],ascending = False)
df.iloc[ :5, 30:31]
# Out:
#         South Korea
# Year
# 2018.0        296.0
# 2017.0        295.0
# 2019.0        293.0
# 2016.0        293.0
# 2020.0        283.0

# %%
df = e_pais.sort_values(by = ['Taiwan'],ascending = False)
df.iloc[ :5, 31:32]
# Out:
#         Taiwan
# Year
# 2018.0   110.0
# 2016.0   109.0
# 2014.0   109.0
# 2019.0   108.0
# 2017.0   107.0

# %%
df = e_pais.sort_values(by = ['Thailand'],ascending = False)
df.iloc[ :5, 32:33]
# Out:
#         Thailand
# Year
# 2017.0     139.0
# 2016.0     139.0
# 2019.0     137.0
# 2018.0     136.0
# 2015.0     136.0

# %%
df = e_pais.sort_values(by = ['India'],ascending = False)
df.iloc[ :5, 33:34]
# Out:
#         India
# Year
# 2019.0  940.0
# 2018.0  919.0
# 2020.0  908.0
# 2017.0  883.0
# 2016.0  852.0

# %%
df = e_pais.sort_values(by = ['Australia'],ascending = False)
df.iloc[ :5, 34:35]
# Out:
#         Australia
# Year
# 2019.0      129.0
# 2018.0      128.0
# 2017.0      128.0
# 2016.0      127.0
# 2015.0      127.0

# %%
df = e_pais.sort_values(by = ['New Zealand'],ascending = False)
df.iloc[ :5, 35:36]
# Out:
#         New Zealand
# Year
# 2020.0         21.0
# 2019.0         21.0
# 2017.0         21.0
# 2016.0         21.0
# 2015.0         21.0

# %%
df = e_pais.sort_values(by = ['Algeria'],ascending = False)
df.iloc[ :5, 36:37]
# Out:
#         Algeria
# Year
# 2019.0     65.0
# 2018.0     61.0
# 2020.0     59.0
# 2017.0     57.0
# 2016.0     56.0

# %%
df = e_pais.sort_values(by = ['Egypt'],ascending = False)
df.iloc[ :5, 37:38]
# Out:
#         Egypt
# Year
# 2019.0   97.0
# 2018.0   96.0
# 2017.0   93.0
# 2020.0   92.0
# 2016.0   88.0

# %%
df = e_pais.sort_values(by = ['Nigeria'],ascending = False)
df.iloc[ :5, 38:39]
# Out:
#         Nigeria
# Year
# 2018.0    160.0
# 2020.0    159.0
# 2019.0    157.0
# 2017.0    152.0
# 2016.0    150.0

# %%
df = e_pais.sort_values(by = ['South Africa'],ascending = False)
df.iloc[ :5, 39:40]
# Out:
#         South Africa
# Year
# 2009.0         144.0
# 2008.0         142.0
# 2014.0         138.0
# 2011.0         137.0
# 2017.0         136.0

# %%
df = e_pais.sort_values(by = ['Iran'],ascending = False)
df.iloc[ :5, 40:41]
# Out:
#          Iran
# Year
# 2019.0  269.0
# 2020.0  268.0
# 2018.0  266.0
# 2017.0  262.0
# 2016.0  246.0

# %%
df = e_pais.sort_values(by = ['Kuwait'],ascending = False)
df.iloc[ :5, 41:42]
# Out:
#         Kuwait
# Year
# 2020.0    38.0
# 2019.0    36.0
# 2016.0    36.0
# 2018.0    34.0
# 2017.0    34.0

# %%
df = e_pais.sort_values(by = ['Saudi Arabia'],ascending = False)
df.iloc[ :5, 42:43]
# Out:
#         Saudi Arabia
# Year
# 2017.0         219.0
# 2015.0         216.0
# 2019.0         215.0
# 2016.0         215.0
# 2018.0         214.0

# %%
df = e_pais.sort_values(by = ['United Arab Emirates'],ascending = False)
df.iloc[ :5, 43:44]
# Out:
#         United Arab Emirates
# Year
# 2019.0                  83.0
# 2020.0                  81.0
# 2016.0                  79.0
# 2018.0                  78.0
# 2017.0                  78.0

# %% [markdown]
# 5 anos de menor consumo em cada país

# %%
df = e_pais.sort_values(by = ['China'])
df.iloc[ :5, :1]
# Out:
#         China
# Year
# 1991.0  848.0
# 1990.0  874.0
# 1992.0  877.0
# 1993.0  929.0
# 1994.0  973.0

# %%
df = e_pais.sort_values(by = ['United States'])
df.iloc[ :5, 1:2]
# Out:
#         United States
# Year
# 1990.0         1910.0
# 1991.0         1925.0
# 1992.0         1964.0
# 1993.0         1998.0
# 1994.0         2036.0

# %%
df = e_pais.sort_values(by = ['Brazil'])
df.iloc[ :5, 2:3]
# Out:
#         Brazil
# Year
# 1990.0   141.0
# 1991.0   143.0
# 1992.0   145.0
# 1993.0   148.0
# 1994.0   156.0

# %%
df = e_pais.sort_values(by = ['Belgium'])
df.iloc[ :5, 3:4]
# Out:
#         Belgium
# Year
# 1990.0     48.0
# 1993.0     49.0
# 1991.0     50.0
# 2020.0     51.0
# 1992.0     51.0

# %%
df = e_pais.sort_values(by = ['Czechia'])
df.iloc[ :5, 4:5]
# Out:
#         Czechia
# Year
# 2020.0     39.0
# 1999.0     39.0
# 2016.0     41.0
# 1994.0     41.0
# 2000.0     41.0

# %%
df = e_pais.sort_values(by = ['France'])
df.iloc[ :5, 5:6]
# Out:
#         France
# Year
# 2020.0   217.0
# 1990.0   225.0
# 1994.0   231.0
# 1992.0   234.0
# 1991.0   237.0

# %%
df = e_pais.sort_values(by = ['Germany'])
df.iloc[ :5, 6:7]
# Out:
#         Germany
# Year
# 2020.0    275.0
# 2019.0    294.0
# 2018.0    302.0
# 2014.0    307.0
# 2015.0    309.0

# %%
df = e_pais.sort_values(by = ['Italy'])
df.iloc[ :5, 7:8]
# Out:
#         Italy
# Year
# 2020.0  137.0
# 2014.0  147.0
# 1994.0  147.0
# 1990.0  147.0
# 1992.0  149.0

# %%
df = e_pais.sort_values(by = ['Netherlands'])
df.iloc[ :5, 8:9]
# Out:
#         Netherlands
# Year
# 1990.0         67.0
# 1991.0         69.0
# 1992.0         69.0
# 1994.0         70.0
# 2020.0         70.0

# %%
df = e_pais.sort_values(by = ['Poland'])
df.iloc[ :5, 9:10]
# Out:
#         Poland
# Year
# 2000.0    89.0
# 2002.0    89.0
# 2001.0    90.0
# 2004.0    91.0
# 2003.0    91.0

# %%
df = e_pais.sort_values(by = ['Portugal'])
df.iloc[ :5, 10:11]
# Out:
#         Portugal
# Year
# 1990.0      17.0
# 1991.0      17.0
# 1992.0      18.0
# 1993.0      18.0
# 1994.0      18.0

# %%
df = e_pais.sort_values(by = ['Romania'])
df.iloc[ :5, 11:12]
# Out:
#         Romania
# Year
# 2020.0     32.0
# 2016.0     32.0
# 2015.0     32.0
# 2014.0     32.0
# 2013.0     32.0

# %%
df = e_pais.sort_values(by = ['Spain'])
df.iloc[ :5, 12:13]
# Out:
#         Spain
# Year
# 1990.0   90.0
# 1993.0   91.0
# 1991.0   93.0
# 1992.0   95.0
# 1994.0   96.0

# %%
df = e_pais.sort_values(by = ['Sweden'])
df.iloc[ :5, 13:14]
# Out:
#         Sweden
# Year
# 2015.0    44.0
# 2009.0    45.0
# 1993.0    46.0
# 1990.0    47.0
# 2020.0    47.0

# %%
df = e_pais.sort_values(by = ['United Kingdom'])
df.iloc[ :5, 14:15]
# Out:
#         United Kingdom
# Year
# 2020.0           154.0
# 2019.0           170.0
# 2018.0           175.0
# 2017.0           176.0
# 2016.0           179.0

# %%
df = e_pais.sort_values(by = ['Norway'])
df.iloc[ :5, 15:16]
# Out:
#         Norway
# Year
# 1990.0    21.0
# 1991.0    22.0
# 1992.0    22.0
# 1994.0    23.0
# 1996.0    23.0

# %%
df = e_pais.sort_values(by = ['Turkey'])
df.iloc[ :5, 16:17]
# Out:
#         Turkey
# Year
# 1990.0    51.0
# 1991.0    51.0
# 1992.0    53.0
# 1993.0    56.0
# 1994.0    56.0

# %%
df = e_pais.sort_values(by = ['Kazakhstan'])
df.iloc[ :5, 17:18]
# Out:
#         Kazakhstan
# Year
# 2001.0        35.0
# 2000.0        36.0
# 1999.0        36.0
# 1997.0        39.0
# 1998.0        39.0

# %%
df = e_pais.sort_values(by = ['Russia'])
df.iloc[ :5, 18:19]
# Out:
#         Russia
# Year
# 1998.0   588.0
# 1997.0   602.0
# 1999.0   609.0
# 2000.0   619.0
# 2002.0   623.0

# %%
df = e_pais.sort_values(by = ['Ukraine'])
df.iloc[ :5, 19:20]
# Out:
#         Ukraine
# Year
# 2020.0     86.0
# 2017.0     89.0
# 2019.0     89.0
# 2016.0     92.0
# 2018.0     93.0

# %%
df = e_pais.sort_values(by = ['Uzbekistan'])
df.iloc[ :5, 20:21]
# Out:
#         Uzbekistan
# Year
# 2015.0        39.0
# 2014.0        41.0
# 2016.0        42.0
# 1995.0        43.0
# 2020.0        44.0

# %%
df = e_pais.sort_values(by = ['Argentina'])
df.iloc[ :5, 21:22]
# Out:
#         Argentina
# Year
# 1990.0       44.0
# 1991.0       46.0
# 1992.0       47.0
# 1993.0       48.0
# 1994.0       52.0

# %%
df = e_pais.sort_values(by = ['Canada'])
df.iloc[ :5, 22:23]
# Out:
#         Canada
# Year
# 1991.0   210.0
# 1990.0   211.0
# 1992.0   216.0
# 1993.0   223.0
# 1994.0   231.0

# %%
df = e_pais.sort_values(by = ['Chile'])
df.iloc[ :5, 23:24]
# Out:
#         Chile
# Year
# 1990.0   14.0
# 1991.0   14.0
# 1992.0   15.0
# 1993.0   16.0
# 1994.0   17.0

# %%
df = e_pais.sort_values(by = ['Colombia'])
df.iloc[ :5, 24:25]
# Out:
#         Colombia
# Year
# 1990.0      24.0
# 1991.0      24.0
# 1992.0      25.0
# 2002.0      25.0
# 1993.0      26.0

# %%
df = e_pais.sort_values(by = ['Mexico'])
df.iloc[ :5, 25:26]
# Out:
#         Mexico
# Year
# 1990.0   124.0
# 1991.0   130.0
# 1992.0   131.0
# 1995.0   132.0
# 1993.0   133.0

# %%
df = e_pais.sort_values(by = ['Venezuela'])
df.iloc[ :5, 26:27]
# Out:
#         Venezuela
# Year
# 2020.0       29.0
# 2019.0       36.0
# 1990.0       40.0
# 1991.0       41.0
# 2018.0       42.0

# %%
df = e_pais.sort_values(by = ['Indonesia'])
df.iloc[ :5, 27:28]
# Out:
#         Indonesia
# Year
# 1990.0       99.0
# 1991.0      103.0
# 1992.0      108.0
# 1993.0      119.0
# 1994.0      119.0

# %%
df = e_pais.sort_values(by = ['Japan'])
df.iloc[ :5, 28:29]
# Out:
#         Japan
# Year
# 2020.0  386.0
# 2019.0  416.0
# 2018.0  428.0
# 2016.0  429.0
# 2017.0  434.0

# %%
df = e_pais.sort_values(by = ['Malaysia'])
df.iloc[ :5, 29:30]
# Out:
#         Malaysia
# Year
# 1990.0      21.0
# 1991.0      26.0
# 1992.0      29.0
# 1993.0      32.0
# 1994.0      32.0

# %%
df = e_pais.sort_values(by = ['South Korea'])
df.iloc[ :5, 30:31]
# Out:
#         South Korea
# Year
# 1990.0         94.0
# 1991.0        101.0
# 1992.0        111.0
# 1993.0        125.0
# 1994.0        133.0

# %%
df = e_pais.sort_values(by = ['Taiwan'])
df.iloc[ :5, 31:32]
# Out:
#         Taiwan
# Year
# 1990.0    48.0
# 1991.0    52.0
# 1992.0    54.0
# 1993.0    58.0
# 1994.0    60.0

# %%
df = e_pais.sort_values(by = ['Thailand'])
df.iloc[ :5, 32:33]
# Out:
#         Thailand
# Year
# 1990.0      42.0
# 1991.0      46.0
# 1992.0      49.0
# 1993.0      51.0
# 1994.0      57.0

# %%
df = e_pais.sort_values(by = ['India'])
df.iloc[ :5, 33:34]
# Out:
#         India
# Year
# 1990.0  306.0
# 1991.0  318.0
# 1992.0  330.0
# 1993.0  338.0
# 1994.0  351.0

# %%
df = e_pais.sort_values(by = ['Australia'])
df.iloc[ :5, 34:35]
# Out:
#         Australia
# Year
# 1991.0       85.0
# 1990.0       86.0
# 1992.0       87.0
# 1993.0       91.0
# 1994.0       91.0

# %%
df = e_pais.sort_values(by = ['New Zealand'])
df.iloc[ :5, 35:36]
# Out:
#         New Zealand
# Year
# 1990.0         14.0
# 1991.0         14.0
# 1992.0         14.0
# 1993.0         15.0
# 1994.0         15.0

# %%
df = e_pais.sort_values(by = ['Algeria'])
df.iloc[ :5, 36:37]
# Out:
#         Algeria
# Year
# 1990.0     22.0
# 1991.0     23.0
# 1994.0     23.0
# 1996.0     23.0
# 1992.0     24.0

# %%
df = e_pais.sort_values(by = ['Egypt'])
df.iloc[ :5, 37:38]
# Out:
#         Egypt
# Year
# 1990.0   33.0
# 1991.0   33.0
# 1992.0   34.0
# 1994.0   34.0
# 1993.0   35.0

# %%
df = e_pais.sort_values(by = ['Nigeria'])
df.iloc[ :5, 38:39]
# Out:
#         Nigeria
# Year
# 1990.0     66.0
# 1991.0     70.0
# 1992.0     72.0
# 1994.0     72.0
# 1995.0     73.0

# %%
df = e_pais.sort_values(by = ['South Africa'])
df.iloc[ :5, 39:40]
# Out:
#         South Africa
# Year
# 1992.0          88.0
# 1990.0          90.0
# 1991.0          92.0
# 1993.0          94.0
# 1994.0          98.0

# %%
df = e_pais.sort_values(by = ['Iran'])
df.iloc[ :5, 40:41]
# Out:
#         Iran
# Year
# 1990.0  69.0
# 1991.0  77.0
# 1992.0  81.0
# 1993.0  87.0
# 1994.0  97.0

# %%
df = e_pais.sort_values(by = ['Kuwait'])
df.iloc[ :5, 41:42]
# Out:
#         Kuwait
# Year
# 1991.0     3.0
# 1990.0     9.0
# 1992.0     9.0
# 1993.0    12.0
# 1994.0    14.0

# %%
df = e_pais.sort_values(by = ['Saudi Arabia'])
df.iloc[ :5, 42:43]
# Out:
#         Saudi Arabia
# Year
# 1990.0          58.0
# 1991.0          68.0
# 1992.0          77.0
# 1993.0          80.0
# 1994.0          84.0

# %%
df = e_pais.sort_values(by = ['United Arab Emirates'])
df.iloc[ :5, 43:44]
# Out:
#         United Arab Emirates
# Year
# 1990.0                  20.0
# 1992.0                  22.0
# 1991.0                  23.0
# 1993.0                  23.0
# 1994.0                  26.0

# %% [markdown]
# Paises com maior consumo em cada ano

# %%
df = e_pais.T 

an1 = df.iloc[: , :6]
an2 = df.iloc[: , 6: 11]
an3 = df.iloc[: , 11:16]
an4 = df.iloc[: , 16:21]
an5 = df.iloc[: , 21:26]
an6 = df.iloc[: , 26: ]

# %%
an1.sort_values(by = [1990], ascending = False).iloc[:5 , :1]
# Out:
# Year           1990.0
# United States  1910.0
# Russia          879.0
# China           874.0
# Japan           440.0
# Germany         351.0

# %%
an1.sort_values(by = [1991], ascending = False).iloc[:5 , 1:2]
# Out:
# Year           1991.0
# United States  1925.0
# Russia          871.0
# China           848.0
# Japan           445.0
# Germany         344.0

# %%
an1.sort_values(by = [1992], ascending = False).iloc[:5 , 2:3]
# Out:
# Year           1992.0
# United States  1964.0
# China           877.0
# Russia          795.0
# Japan           455.0
# Germany         338.0

# %%
an1.sort_values(by = [1993], ascending = False).iloc[:5 , 3:4]
# Out:
# Year           1993.0
# United States  1998.0
# China           929.0
# Russia          751.0
# Japan           458.0
# India           338.0

# %%
an1.sort_values(by = [1994], ascending = False).iloc[:5 , 4:5]
# Out:
# Year           1994.0
# United States  2036.0
# China           973.0
# Russia          657.0
# Japan           483.0
# India           351.0

# %%
an1.sort_values(by = [1995], ascending = False).iloc[:5 , 5:6]
# Out:
# Year           1995.0
# United States  2063.0
# China          1045.0
# Russia          636.0
# Japan           495.0
# India           371.0

# %%
an2.sort_values(by = [1996], ascending = False).iloc[:5 , :1]
# Out:
# Year           1996.0
# United States  2108.0
# China          1074.0
# Russia          630.0
# Japan           506.0
# India           383.0

# %%
an2.sort_values(by = [1997], ascending = False).iloc[:5 , 1:2]
# Out:
# Year           1997.0
# United States  2130.0
# China          1073.0
# Russia          602.0
# Japan           511.0
# India           398.0

# %%
an2.sort_values(by = [1998], ascending = False).iloc[:5 , 2:3]
# Out:
# Year           1998.0
# United States  2148.0
# China          1079.0
# Russia          588.0
# Japan           502.0
# India           407.0

# %%
an2.sort_values(by = [1999], ascending = False).iloc[:5 , 3:4]
# Out:
# Year           1999.0
# United States  2206.0
# China          1099.0
# Russia          609.0
# Japan           510.0
# India           431.0

# %%
an2.sort_values(by = [2000], ascending = False).iloc[:5 , 4:5]
# Out:
# Year           2000.0
# United States  2269.0
# China          1130.0
# Russia          619.0
# Japan           520.0
# India           441.0

# %%
an3.sort_values(by = [2001], ascending = False).iloc[:5 , :1]
# Out:
# Year           2001.0
# United States  2226.0
# China          1168.0
# Russia          626.0
# Japan           511.0
# India           448.0

# %%
an3.sort_values(by = [2002], ascending = False).iloc[:5 , 1:2]
# Out:
# Year           2002.0
# United States  2256.0
# China          1246.0
# Russia          623.0
# Japan           513.0
# India           462.0

# %%
an3.sort_values(by = [2003], ascending = False).iloc[:5 , 2:3]
# Out:
# Year           2003.0
# United States  2262.0
# China          1420.0
# Russia          645.0
# Japan           509.0
# India           474.0

# %%
an3.sort_values(by = [2004], ascending = False).iloc[:5 , 3:4]
# Out:
# Year           2004.0
# United States  2308.0
# China          1615.0
# Russia          647.0
# Japan           526.0
# India           500.0

# %%
an3.sort_values(by = [2005], ascending = False).iloc[:5 , 4:5]
# Out:
# Year           2005.0
# United States  2320.0
# China          1782.0
# Russia          651.0
# Japan           524.0
# India           515.0

# %%
an4.sort_values(by = [2006], ascending = False).iloc[:5 , :1]
# Out:
# Year           2006.0
# United States  2298.0
# China          1950.0
# Russia          670.0
# India           533.0
# Japan           524.0

# %%
an4.sort_values(by = [2007], ascending = False).iloc[:5 , 1:2]
# Out:
# Year           2007.0
# United States  2338.0
# China          2099.0
# Russia          672.0
# India           568.0
# Japan           519.0

# %%
an4.sort_values(by = [2008], ascending = False).iloc[:5 , 2:3]
# Out:
# Year           2008.0
# United States  2278.0
# China          2155.0
# Russia          688.0
# India           604.0
# Japan           500.0

# %%
an4.sort_values(by = [2009], ascending = False).iloc[:5 , 3:4]
# Out:
# Year           2009.0
# China          2297.0
# United States  2165.0
# India           663.0
# Russia          647.0
# Japan           477.0

# %%
an4.sort_values(by = [2010], ascending = False).iloc[:5 , 4:5]
# Out:
# Year           2010.0
# China          2536.0
# United States  2217.0
# India           701.0
# Russia          688.0
# Japan           503.0

# %%
an5.sort_values(by = [2011], ascending = False).iloc[:5 , :1]
# Out:
# Year           2011.0
# China          2723.0
# United States  2191.0
# India           734.0
# Russia          711.0
# Japan           466.0

# %%
an5.sort_values(by = [2012], ascending = False).iloc[:5 , 1:2]
# Out:
# Year           2012.0
# China          2821.0
# United States  2152.0
# India           766.0
# Russia          728.0
# Japan           456.0

# %%
an5.sort_values(by = [2013], ascending = False).iloc[:5 , 2:3]
# Out:
# Year           2013.0
# China          2912.0
# United States  2190.0
# India           779.0
# Russia          707.0
# Japan           457.0

# %%
an5.sort_values(by = [2014], ascending = False).iloc[:5 , 3:4]
# Out:
# Year           2014.0
# China          2966.0
# United States  2216.0
# India           822.0
# Russia          707.0
# Japan           442.0

# %%
an5.sort_values(by = [2015], ascending = False).iloc[:5 , 4:5]
# Out:
# Year           2015.0
# China          2994.0
# United States  2192.0
# India           835.0
# Russia          693.0
# Japan           434.0

# %%
an6.sort_values(by = [2016], ascending = False).iloc[:5 , :1]
# Out:
# Year           2016.0
# China          2977.0
# United States  2168.0
# India           852.0
# Russia          714.0
# Japan           429.0

# %%
an6.sort_values(by = [2017], ascending = False).iloc[:5 , 1:2]
# Out:
# Year           2017.0
# China          3070.0
# United States  2161.0
# India           883.0
# Russia          729.0
# Japan           434.0

# %%
an6.sort_values(by = [2018], ascending = False).iloc[:5 , 2:3]
# Out:
# Year           2018.0
# China          3201.0
# United States  2236.0
# India           919.0
# Russia          760.0
# Japan           428.0

# %%
an6.sort_values(by = [2019], ascending = False).iloc[:5 , 3:4]
# Out:
# Year           2019.0
# China          3309.0
# United States  2214.0
# India           940.0
# Russia          768.0
# Japan           416.0

# %%
an6.sort_values(by = [2020], ascending = False).iloc[:5 , 4:5]
# Out:
# Year           2020.0
# China          3381.0
# United States  2046.0
# India           908.0
# Russia          731.0
# Japan           386.0

# %% [markdown]
# Paises com o menor consumo com cada ano

# %%
an1.sort_values(by = [1990]).iloc[:5 , :1]
# Out:
# Year                  1990.0
# Kuwait                   9.0
# New Zealand             14.0
# Chile                   14.0
# Portugal                17.0
# United Arab Emirates    20.0

# %%
an1.sort_values(by = [1991]).iloc[:5 , 1:2]
# Out:
# Year         1991.0
# Kuwait          3.0
# New Zealand    14.0
# Chile          14.0
# Portugal       17.0
# Norway         22.0

# %%
an1.sort_values(by = [1992]).iloc[:5 , 2:3]
# Out:
# Year                  1992.0
# Kuwait                   9.0
# New Zealand             14.0
# Chile                   15.0
# Portugal                18.0
# United Arab Emirates    22.0

# %%
an1.sort_values(by = [1993]).iloc[:5 , 3:4]
# Out:
# Year                  1993.0
# Kuwait                  12.0
# New Zealand             15.0
# Chile                   16.0
# Portugal                18.0
# United Arab Emirates    23.0

# %%
an1.sort_values(by = [1994]).iloc[:5 , 4:5]
# Out:
# Year         1994.0
# Kuwait         14.0
# New Zealand    15.0
# Chile          17.0
# Portugal       18.0
# Algeria        23.0

# %%
an1.sort_values(by = [1995]).iloc[:5 , 5:6]
# Out:
# Year         1995.0
# Kuwait         15.0
# New Zealand    15.0
# Chile          18.0
# Portugal       20.0
# Algeria        24.0

# %%
an2.sort_values(by = [1996]).iloc[:5 , :1]
# Out:
# Year         1996.0
# Kuwait         14.0
# New Zealand    16.0
# Chile          20.0
# Portugal       20.0
# Algeria        23.0

# %%
an2.sort_values(by = [1997]).iloc[:5 , 1:2]
# Out:
# Year         1997.0
# Kuwait         15.0
# New Zealand    16.0
# Portugal       21.0
# Chile          23.0
# Algeria        24.0

# %%
an2.sort_values(by = [1998]).iloc[:5 , 2:3]
# Out:
# Year         1998.0
# New Zealand    16.0
# Kuwait         17.0
# Portugal       23.0
# Chile          24.0
# Algeria        25.0

# %%
an2.sort_values(by = [1999]).iloc[:5 , 3:4]
# Out:
# Year         1999.0
# New Zealand    17.0
# Kuwait         18.0
# Portugal       24.0
# Chile          25.0
# Colombia       26.0

# %%
an2.sort_values(by = [2000]).iloc[:5 , 4:5]
# Out:
# Year         2000.0
# New Zealand    17.0
# Kuwait         19.0
# Chile          25.0
# Portugal       25.0
# Colombia       26.0

# %%
an3.sort_values(by = [2001]).iloc[:5 , :1]
# Out:
# Year         2001.0
# New Zealand    17.0
# Kuwait         20.0
# Chile          25.0
# Portugal       25.0
# Colombia       26.0

# %%
an3.sort_values(by = [2002]).iloc[:5 , 1:2]
# Out:
# Year         2002.0
# New Zealand    17.0
# Kuwait         20.0
# Colombia       25.0
# Norway         25.0
# Chile          26.0

# %%
an3.sort_values(by = [2003]).iloc[:5 , 2:3]
# Out:
# Year         2003.0
# New Zealand    17.0
# Kuwait         21.0
# Portugal       25.0
# Colombia       26.0
# Chile          26.0

# %%
an3.sort_values(by = [2004]).iloc[:5 , 3:4]
# Out:
# Year         2004.0
# New Zealand    18.0
# Kuwait         24.0
# Colombia       26.0
# Portugal       26.0
# Norway         27.0

# %%
an3.sort_values(by = [2005]).iloc[:5 , 4:5]
# Out:
# Year         2005.0
# New Zealand    17.0
# Portugal       26.0
# Kuwait         27.0
# Norway         27.0
# Colombia       27.0

# %%
an4.sort_values(by = [2006]).iloc[:5 , :1]
# Out:
# Year         2006.0
# New Zealand    17.0
# Kuwait         25.0
# Portugal       25.0
# Norway         27.0
# Colombia       29.0

# %%
an4.sort_values(by = [2007]).iloc[:5 , 1:2]
# Out:
# Year         2007.0
# New Zealand    17.0
# Kuwait         25.0
# Portugal       25.0
# Norway         28.0
# Colombia       28.0

# %%
an4.sort_values(by = [2008]).iloc[:5 , 2:3]
# Out:
# Year         2008.0
# New Zealand    18.0
# Portugal       25.0
# Kuwait         28.0
# Colombia       30.0
# Chile          30.0

# %%
an4.sort_values(by = [2009]).iloc[:5 , 3:4]
# Out:
# Year         2009.0
# New Zealand    18.0
# Portugal       24.0
# Kuwait         29.0
# Chile          30.0
# Colombia       31.0

# %%
an4.sort_values(by = [2010]).iloc[:5 , 4:5]
# Out:
# Year         2010.0
# New Zealand    19.0
# Portugal       23.0
# Kuwait         29.0
# Colombia       30.0
# Chile          31.0

# %%
an5.sort_values(by = [2011]).iloc[:5 , :1]
# Out:
# Year         2011.0
# New Zealand    18.0
# Portugal       23.0
# Kuwait         28.0
# Norway         28.0
# Colombia       31.0

# %%
an5.sort_values(by = [2012]).iloc[:5 , 1:2]
# Out:
# Year         2012.0
# New Zealand    19.0
# Portugal       21.0
# Kuwait         29.0
# Colombia       30.0
# Norway         31.0

# %%
an5.sort_values(by = [2013]).iloc[:5 , 2:3]
# Out:
# Year         2013.0
# New Zealand    19.0
# Portugal       22.0
# Kuwait         30.0
# Romania        32.0
# Norway         33.0

# %%
an5.sort_values(by = [2014]).iloc[:5 , 3:4]
# Out:
# Year         2014.0
# New Zealand    21.0
# Portugal       21.0
# Kuwait         27.0
# Norway         29.0
# Romania        32.0

# %%
an5.sort_values(by = [2015]).iloc[:5 , 4:5]
# Out:
# Year         2015.0
# New Zealand    21.0
# Portugal       22.0
# Norway         30.0
# Romania        32.0
# Kuwait         33.0

# %%
an6.sort_values(by = [2016]).iloc[:5 , :1]
# Out:
# Year         2016.0
# New Zealand    21.0
# Portugal       22.0
# Norway         29.0
# Romania        32.0
# Kuwait         36.0

# %%
an6.sort_values(by = [2017]).iloc[:5 , 1:2]
# Out:
# Year         2017.0
# New Zealand    21.0
# Portugal       23.0
# Norway         30.0
# Romania        33.0
# Kuwait         34.0

# %%
an6.sort_values(by = [2018]).iloc[:5 , 2:3]
# Out:
# Year         2018.0
# New Zealand    20.0
# Portugal       22.0
# Norway         29.0
# Kuwait         34.0
# Romania        34.0

# %%
an6.sort_values(by = [2019]).iloc[:5 , 3:4]
# Out:
# Year         2019.0
# New Zealand    21.0
# Portugal       22.0
# Norway         28.0
# Romania        33.0
# Kuwait         36.0

# %%
an6.sort_values(by = [2020]).iloc[:5 , 4:5]
# Out:
# Year         2020.0
# Portugal       20.0
# New Zealand    21.0
# Norway         27.0
# Venezuela      29.0
# Romania        32.0

# %% [markdown]
# Gráficos

# %%
algeria = e_pais['Algeria']
argentina = e_pais['Argentina']
australia = e_pais['Australia']
belgium = e_pais['Belgium']
brazil = e_pais['Brazil']
canada = e_pais['Canada']
chile = e_pais['Chile']
china = e_pais['China']
colombia = e_pais['Colombia']
czechia = e_pais['Czechia']
egypt = e_pais['Egypt']
france = e_pais['France']
germany = e_pais['Germany']
india = e_pais['India']
indonesia = e_pais['Indonesia']
iran = e_pais['Iran']
italy = e_pais['Italy']
japan = e_pais['Japan']
kazakhstan = e_pais['Kazakhstan']
kuwait = e_pais['Kuwait']
malaysia = e_pais['Malaysia']
mexico = e_pais['Mexico']
netherlands = e_pais['Netherlands']
new_zhealand = e_pais['New Zealand']
nigeria = e_pais['Nigeria']
norway = e_pais['Norway']
poland = e_pais['Poland']
portugal = e_pais['Portugal']
romania = e_pais['Romania']
russia = e_pais['Russia']
saudi_arabia = e_pais['Saudi Arabia']
south_africa = e_pais['South Africa']
south_korea = e_pais['South Korea']
spain = e_pais['Spain']
sweden = e_pais['Sweden']
taiwan = e_pais['Taiwan']
thailand = e_pais['Thailand']
turkey = e_pais['Turkey']
ukraine = e_pais['Ukraine']
united_emirates = e_pais['United Arab Emirates']
united_kingdom = e_pais['United Kingdom']
united_states = e_pais['United States']
uzbequistan = e_pais['Uzbekistan']
venezuela = e_pais['Venezuela']

# %%
algeria.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
argentina.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
australia.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
belgium.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
brazil.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
canada.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
chile.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
china.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
colombia.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
czechia.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
egypt.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
france.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
germany.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
india.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
indonesia.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
iran.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
italy.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
japan.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
kazakhstan.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
kuwait.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
malaysia.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
mexico.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
netherlands.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
new_zhealand.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
nigeria.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
norway.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
poland.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
portugal.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
romania.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
russia.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
saudi_arabia.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
south_africa.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
south_korea.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
spain.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
sweden.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
taiwan.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
thailand.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
turkey.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
ukraine.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
united_emirates.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
united_kingdom.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
united_states.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
uzbequistan.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
venezuela.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %% [markdown]
# # Analise do consumo por pais e por continente

# %% [markdown]
# Porcentagem de consumo de cada país por continente

# %% [markdown]
# Analise Mundial

# %%
e_cont = pd.read_csv('../../Energydata/Continent_Consumption_TWH.csv')
e_cont = e_cont.set_index('Year')
e_pais = pd.read_csv("../../Energydata/Country_Consumption_TWH.csv")
e_pais = e_pais.set_index('Year')

# %%
world = e_cont['World']

world_pais=pd.DataFrame({ 'Algeria' : algeria, 
                          'Australia' : australia, 
                          'Belgium' : belgium, 
                          'Brazil' : brazil, 
                          'Canada' : canada, 
                          'Chile' : chile, 
                          'China' : china, 
                          'Colombia' : colombia, 
                          'Czechia' : czechia, 
                          'Egypt' : egypt,
                          'France' : france, 
                          'Germany' : germany, 
                          'Indonesia' : indonesia, 
                          'Iran' : iran, 
                          'Italy' : italy, 
                          'Japan' : japan,
                          'Kazakhstan' : kazakhstan, 
                          'Kuwait' : kuwait, 
                          'Malaysia' : malaysia, 
                          'Netherlands' : netherlands, 
                          'New Zhealand' : new_zhealand,
                          'Nigeria' : nigeria, 
                          'Norway' : norway, 
                          'Poland' : poland,
                          'Portugal' : portugal, 
                          'Romania' : romania, 
                          'Russia' : russia, 
                          'Saudi Arabia' : saudi_arabia, 
                          'South Africa' : south_africa,
                          'South Korea' : south_korea,
                          'Spain' : spain,
                          'Sweden' : sweden, 
                          'Taiwan' : taiwan,
                          'Thailand' : thailand, 
                          'Turkey' : turkey,
                          'Ukraine' : ukraine, 
                          'United Arab Emirates' : united_emirates, 
                          'United Kingdom' : united_kingdom,
                          'United States' : united_states,
                          'Uzbequistan' : uzbequistan,
                          'Venezuela' : venezuela, 
                          'Total' : world})

world_ano = world_pais.T

# %% [markdown]
# Percentagem por continente

# %% [markdown]
# África

# %%
africa = e_cont['Africa']

africa_pais = pd.DataFrame({'Algeria' : algeria, 
                            'Egypt' : egypt, 
                            'Nigeria' : nigeria, 
                            'South_Africa' : south_africa,
                            'Total' : africa})

africa_ano = africa_pais.T
africa_ano
# Out:
# Year           1990.0  1991.0   1992.0   1993.0   1994.0  1995.0   1996.0  \
# Algeria         22.00    23.0    24.00    24.00    23.00    24.0    23.00
# Egypt           33.00    33.0    34.00    35.00    34.00    36.0    38.00
# Nigeria         66.00    70.0    72.00    74.00    72.00    73.0    76.00
# South_Africa    90.00    92.0    88.00    94.00    98.00   104.0   107.00
# Total         4407.77  4535.7  4582.22  4721.78  4803.19  5000.9  5152.09
#
# Year           1997.0   1998.0   1999.0  ...   2013.0   2014.0  2015.0  \
# Algeria         24.00    25.00    27.00  ...    49.00    54.00    56.0
# Egypt           40.00    42.00    43.00  ...    78.00    80.00    81.0
# Nigeria         79.00    80.00    83.00  ...   143.00   147.00   145.0
# South_Africa   109.00   111.00   109.00  ...   130.00   138.00   129.0
# Total         5280.02  5431.21  5559.14  ...  8431.75  8896.95  8838.8
#
# Year           2016.0  2017.0   2018.0   2019.0   2020.0  NaN     NaN
# ...

# %%
top_1af = africa_ano.sort_values(by=[1990],ascending = False).iloc[:,:1]
top_1af = top_1af.T

top_1af['Outros'] = top_1af.Total - (top_1af.South_Africa + top_1af.Nigeria + top_1af.Egypt + top_1af.Algeria)
top_1af.pop('Total')
top_1af = top_1af.T


top_2af = africa_ano.sort_values(by=[2000],ascending = False).iloc[:, 10:11]
top_2af = top_2af.T

top_2af['Outros'] = top_2af.Total - (top_2af.South_Africa + top_2af.Nigeria + top_2af.Egypt + top_2af.Algeria)
top_2af.pop('Total')
top_2af = top_2af.T


top_3af = africa_ano.sort_values(by=[2010],ascending = False).iloc[:, 20:21]
top_3af = top_3af.T

top_3af['Outros'] = top_3af.Total - (top_3af.South_Africa + top_3af.Nigeria + top_3af.Egypt + top_3af.Algeria)
top_3af.pop('Total')
top_3af = top_3af.T


top_4af = africa_ano.sort_values(by=[2020],ascending = False).iloc[:, 30:31]
top_4af = top_4af.T

top_4af['Outros'] = top_4af.Total - (top_4af.South_Africa + top_4af.Nigeria + top_4af.Egypt + top_4af.Algeria)
top_4af.pop('Total')
top_4af = top_4af.T

# %%
x = np.linspace(0, np.pi, 100)
fig = plt.figure(figsize=(20, 20), facecolor = '#ffff')

ax1 = plt.subplot2grid((2,2),(0,0))
plt.pie(top_1af[1990],labels = top_1af.T.columns)
plt.title("Consumo Africano em 1990")

ax2 = fig.add_subplot(2,2,2)
plt.pie(top_2af[2000],labels = top_2af.T.columns)
plt.title("Consumo Africano em 2000")

ax3 = fig.add_subplot(2,2,3)
plt.pie(top_3af[2010],labels = top_3af.T.columns)
plt.title("Consumo Africano em 2010")

ax4 = fig.add_subplot(2,2,4)
plt.pie(top_4af[2020],labels = top_4af.T.columns)
plt.title("Consumo Africano em 2020")
# Out:
# Text(0.5, 1.0, 'Consumo Africano em 2020')

# %% [markdown]
# Asia

# %%
asia = e_cont['Asia']

asia_pais=pd.DataFrame({'China' : china, 
                        'Egypt' : egypt,
                        'India' : india, 
                        'Indonesia' : indonesia,
                        'Iran' : iran, 
                        'Japan' : japan, 
                        'Kazakhstan' : kazakhstan,
                        'Kuwait' : kuwait, 
                        'Malaysia' : malaysia, 
                        'South_Korea' : south_korea, 
                        'Taiwan' : taiwan,
                        'Thailand' : thailand,
                        'United Arab Emirates' : united_emirates,
                        'Uzbequistan' : uzbequistan, 
                        'Total' : asia})

asia_ano = asia_pais.T

# %%
ano_1 = asia_ano.sort_values(by=[1990],ascending = False).iloc[:,:1]
top_1as = ano_1.iloc[:6, :1]
top_1as = top_1as.T
ano_1 = ano_1.T

ano_1['Outros'] = top_1as.Total - (top_1as.China + top_1as.Japan + top_1as.India + top_1as.Indonesia + top_1as.South_Korea)
ano_1 = ano_1.T
ano_1 = ano_1.sort_values(by = [1990],ascending = False)
top_1as = ano_1.iloc[1:7, :1]


ano_2 = asia_ano.sort_values(by=[2000],ascending = False).iloc[: , 10:11]
top_2as = ano_2.iloc[:6, :1]
top_2as = top_2as.T
ano_2 = ano_2.T

ano_2['Outros'] = top_2as.Total - (top_2as.China + top_2as.Japan + top_2as.India + top_2as.South_Korea + top_2as.Indonesia )
ano_2 = ano_2.T
ano_2 = ano_2.sort_values(by = [2000],ascending = False)
top_2as = ano_2.iloc[1:7, :1]


ano_3 = asia_ano.sort_values(by=[2010],ascending = False).iloc[: , 20:21]
top_3as = ano_3.iloc[:6, :1]
top_3as = top_3as.T
ano_3 = ano_3.T

ano_3['Outros'] = top_3as.Total - (top_3as.China + top_3as.India + top_3as.Japan + top_3as.South_Korea + top_3as.Iran)
ano_3 = ano_3.T
ano_3 = ano_3.sort_values(by = [2010],ascending = False)
top_3as = ano_3.iloc[1:7, :1]


ano_4 = asia_ano.sort_values(by=[2020],ascending = False).iloc[: , 30:31]
top_4as = ano_4.iloc[:6, :1]
top_4as = top_4as.T
ano_4 = ano_4.T

ano_4['Outros'] = top_4as.Total - (top_4as.China + top_4as.India + top_4as.Japan + top_4as.South_Korea + top_4as.Iran)
ano_4 = ano_4.T
ano_4 = ano_4.sort_values(by = [2020],ascending = False)
top_4as = ano_4.iloc[1:7, :1]

# %%
x = np.linspace(0, np.pi, 100)
fig = plt.figure(figsize=(20, 20), facecolor = '#ffff')

ax1 = plt.subplot2grid((2,2),(0,0))
plt.pie(top_1as[1990],labels = top_1as.T.columns)
plt.title("Consumo Asiático em 1990")

ax2 = fig.add_subplot(2,2,2)
plt.pie(top_2as[2000],labels = top_2as.T.columns)
plt.title("Consumo Asiático em 2000")

ax3 = fig.add_subplot(2,2,3)
plt.pie(top_3as[2010],labels = top_3as.T.columns)
plt.title("Consumo Asiático em 2010")

ax4 = fig.add_subplot(2,2,4)
plt.pie(top_4as[2020],labels = top_4as.T.columns)
plt.title("Consumo Asiático em 2020")
# Out:
# Text(0.5, 1.0, 'Consumo Asiático em 2020')

# %% [markdown]
# Europe

# %%
europe = e_cont['Europe']



europe_pais=pd.DataFrame({'Belgium' : belgium, 
                          'Czechia' : czechia,
                          'France' : france,
                          'Germany' : germany,
                          'Italy' : italy,
                          'Netherlands' : netherlands,
                          'Norway' : norway,
                          'Poland' : poland,
                          'Portugal' : portugal,
                          'Romania' : romania, 
                          'Russia' : russia,
                          'Spain' : spain, 
                          'Sweden' : sweden,
                          'Ukraine' : ukraine,
                          'United_Kingdom' : united_kingdom, 
                          'Total' : europe})

europe_ano = europe_pais.T

# %%
ano_1 = europe_ano.sort_values(by=[1990],ascending = False).iloc[:,:1]
top_1e = ano_1.iloc[:6, :1]
top_1e = top_1e.T
ano_1 = ano_1.T

ano_1['Outros'] = top_1e.Total - (top_1e.Russia + top_1e.Germany + top_1e.Ukraine + top_1e.France + top_1e.United_Kingdom )
ano_1 = ano_1.T
ano_1 = ano_1.sort_values(by = [1990],ascending = False)
top_1e = ano_1.iloc[1:7, :1]


ano_2 = europe_ano.sort_values(by=[2000],ascending = False).iloc[: , 10:11]
top_2e = ano_2.iloc[:6, :1]
top_2e = top_2e.T
ano_2 = ano_2.T

ano_2['Outros'] = top_2e.Total - (top_2e.Russia + top_2e.Germany + top_2e.France + top_2e.United_Kingdom + top_2e.Italy )
ano_2 = ano_2.T
ano_2 = ano_2.sort_values(by = [2000],ascending = False)
top_2e = ano_2.iloc[1:7, :1]

ano_3 = europe_ano.sort_values(by=[2010],ascending = False).iloc[: , 20:21]
top_3e = ano_3.iloc[:6, :1]
top_3e = top_3e.T
ano_3 = ano_3.T

ano_3['Outros'] = top_3e.Total - (top_3e.Russia + top_3e.Germany + top_3e.France + top_3e.United_Kingdom + top_3e.Italy )
ano_3 = ano_3.T
ano_3 = ano_3.sort_values(by = [2010],ascending = False)
top_3e = ano_3.iloc[1:7, :1]

ano_4 = europe_ano.sort_values(by=[2020],ascending = False).iloc[: , 30:31]
top_4e = ano_4.iloc[:6, :1]
top_4e = top_4e.T
ano_4 = ano_4.T

ano_4['Outros'] = top_4e.Total - (top_4e.Russia + top_4e.Germany + top_4e.France + top_4e.United_Kingdom + top_4e.Italy )
ano_4 = ano_4.T
ano_4 = ano_4.sort_values(by = [2020],ascending = False)
top_4e = ano_4.iloc[1:7, :1]

# %%
x = np.linspace(0, np.pi, 100)
fig = plt.figure(figsize=(20, 20), facecolor = '#ffff')

ax1 = plt.subplot2grid((2,2),(0,0))
plt.pie(top_1e[1990],labels = top_1e.T.columns)
plt.title("Consumo do Oriente Médio em 1990")

ax2 = fig.add_subplot(2,2,2)
plt.pie(top_2e[2000],labels = top_2e.T.columns)
plt.title("Consumo do Oriente Médio em 2000")

ax3 = fig.add_subplot(2,2,3)
plt.pie(top_3e[2010],labels = top_3e.T.columns)
plt.title("Consumo do Oriente Médio em 2010")

ax4 = fig.add_subplot(2,2,4)
plt.pie(top_4e[2020],labels = top_4e.T.columns)
plt.title("Consumo do Orente Médio em 2020")
# Out:
# Text(0.5, 1.0, 'Consumo do Orente Médio em 2020')

# %% [markdown]
# Latin America

# %%
latin_america = e_cont['Latin America']

latin_pais=pd.DataFrame({'Argentina' : argentina, 
                         'Brazil' : brazil, 
                         'Chile' : chile, 
                         'Colombia' : colombia, 
                         'Mexico' : mexico, 
                         'Venezuela' : venezuela,
                         'Total' : latin_america})

latin_ano = latin_pais.T

# %%
ano_1 = latin_ano.sort_values(by=[1990],ascending = False).iloc[:,:1]
top_1l = ano_1.iloc[:6, :1]
top_1l = top_1l.T
ano_1 = ano_1.T

ano_1['Outros'] = top_1l.Total - (top_1l.Brazil + top_1l.Mexico + top_1l.Argentina + top_1l.Venezuela + top_1l.Colombia)
ano_1 = ano_1.T
ano_1 = ano_1.sort_values(by = [1990],ascending = False)
top_1l = ano_1.iloc[1:7, :1]


ano_2 = latin_ano.sort_values(by=[2000],ascending = False).iloc[: , 10:11]
top_2l = ano_2.iloc[:6, :1]
top_2l = top_2l.T
ano_2 = ano_2.T

ano_2['Outros'] = top_2l.Total - (top_2l.Brazil + top_2l.Mexico + top_2l.Argentina + top_2l.Venezuela + top_2l.Colombia)
ano_2 = ano_2.T
ano_2 = ano_2.sort_values(by = [2000],ascending = False)
top_2l = ano_2.iloc[1:7, :1]

ano_3 = latin_ano.sort_values(by=[2010],ascending = False).iloc[: , 20:21]
top_3l = ano_3.iloc[:6, :1]
top_3l = top_3l.T
ano_3 = ano_3.T

ano_3['Outros'] = top_3l.Total - (top_3l.Brazil + top_3l.Mexico + top_3l.Argentina + top_3l.Venezuela + top_3l.Chile)
ano_3 = ano_3.T
ano_3 = ano_3.sort_values(by = [2010],ascending = False)
top_3l = ano_3.iloc[1:7, :1]

ano_4 = latin_ano.sort_values(by=[2020],ascending = False).iloc[: , 30:31]
top_4l = ano_4.iloc[:6, :1]
top_4l = top_4l.T
ano_4 = ano_4.T

ano_4['Outros'] = top_4l.Total - (top_4l.Brazil + top_4l.Mexico + top_4l.Argentina + top_4l.Colombia + top_4l.Chile)
ano_4 = ano_4.T
ano_4 = ano_4.sort_values(by = [2020],ascending = False)
top_4l = ano_4.iloc[1:7, :1]

# %%
x = np.linspace(0, np.pi, 100)
fig = plt.figure(figsize=(20, 20), facecolor = '#ffff')

ax1 = plt.subplot2grid((2,2),(0,0))
plt.pie(top_1l[1990],labels = top_1l.T.columns)
plt.title("Consumo Latino em 1990")

ax2 = fig.add_subplot(2,2,2)
plt.pie(top_2l[2000],labels = top_2l.T.columns)
plt.title("Consumo Latino em 2000")

ax3 = fig.add_subplot(2,2,3)
plt.pie(top_3l[2010],labels = top_3l.T.columns)
plt.title("Consumo Latino em 2010")

ax4 = fig.add_subplot(2,2,4)
plt.pie(top_4l[2020],labels = top_4l.T.columns)
plt.title("Consumo Latino em 2020")
# Out:
# Text(0.5, 1.0, 'Consumo Latino em 2020')

# %% [markdown]
# Middle-East

# %%
middle_east = e_cont['Middle-East']

middle_east_pais=pd.DataFrame({'Algeria' : algeria,
                                'Egypt' : egypt, 
                                'Iran' : iran,
                                'Kuwait' : kuwait, 
                                'Saudi_Arabia' : saudi_arabia, 
                                'Arab_Emirates' : united_emirates, 
                                'Total' : middle_east})

middle_east_ano = middle_east_pais.T

# %%
ano_1 = middle_east_ano.sort_values(by=[1990],ascending = False).iloc[:,:1]
top_1e = ano_1.iloc[:6, :1]
top_1e = top_1e.T
ano_1 = ano_1.T


ano_1['Outros'] = top_1e.Total - (top_1e.Iran + top_1e.Saudi_Arabia + top_1e.Egypt + top_1e.Algeria + top_1e.Arab_Emirates)
ano_1 = ano_1.T
ano_1 = ano_1.sort_values(by = [1990],ascending = False)
top_1e = ano_1.iloc[1:7, :1]



ano_2 = middle_east_ano.sort_values(by=[2000],ascending = False).iloc[: , 10:11]
top_2e = ano_2.iloc[:6, :1]
top_2e = top_2e.T
ano_2 = ano_2.T

ano_2['Outros'] = top_2e.Total - (top_2e.Saudi_Arabia + top_2e.Egypt + top_2e.Arab_Emirates + top_2e.Algeria + top_2e.Iran)
ano_2 = ano_2.T
ano_2 = ano_2.sort_values(by = [2000],ascending = False)
top_2e = ano_2.iloc[1:7, :1]

ano_3 = middle_east_ano.sort_values(by=[2010],ascending = False).iloc[: , 20:21]
top_3e = ano_3.iloc[:6, :1]
top_3e = top_3e.T
ano_3 = ano_3.T

ano_3['Outros'] = top_3e.Total - (top_3e.Iran + top_3e.Saudi_Arabia + top_3e.Egypt + top_3e.Algeria + top_3e.Arab_Emirates)
ano_3 = ano_3.T
ano_3 = ano_3.sort_values(by = [2010],ascending = False)
top_3e = ano_3.iloc[1:7, :1]


ano_4 = middle_east_ano.sort_values(by=[2020],ascending = False).iloc[: , 30:31]
top_4e = ano_4.iloc[:6, :1]
top_4e = top_4e.T
ano_4 = ano_4.T

ano_4['Outros'] = top_4e.Total - (top_4e.Iran + top_4e.Saudi_Arabia + top_4e.Egypt + top_4e.Arab_Emirates + top_4e.Algeria)
ano_4 = ano_4.T
ano_4 = ano_4.sort_values(by = [2020],ascending = False)
top_4e = ano_4.iloc[1:7, :1]

# %%
x = np.linspace(0, np.pi, 100)
fig = plt.figure(figsize=(20, 20), facecolor = '#ffff')

ax1 = plt.subplot2grid((2,2),(0,0))
plt.pie(top_1e[1990],labels = top_1e.T.columns)
plt.title("Consumo do Oriente Médio em 1990")

ax2 = fig.add_subplot(2,2,2)
plt.pie(top_2e[2000],labels = top_2e.T.columns)
plt.title("Consumo do Oriente Médio em 2000")

ax3 = fig.add_subplot(2,2,3)
plt.pie(top_3e[2010],labels = top_3e.T.columns)
plt.title("Consumo do Oriente Médio em 2010")

ax4 = fig.add_subplot(2,2,4)
plt.pie(top_4e[2020],labels = top_4e.T.columns)
plt.title("Consumo do Oriente Médio em 2020")
# Out:
# Text(0.5, 1.0, 'Consumo do Oriente Médio em 2020')

# %% [markdown]
# North America

# %%
north_america = e_cont['North America']

north_pais=pd.DataFrame({'Canada' : canada,
                         'Mexico' : mexico, 
                         'United_States' : united_states,
                         'Total' : north_america})

north_america_ano = north_pais.T

# %%
top_1n = north_america_ano.sort_values(by=[1990],ascending = False).iloc[:,:1]
top_1n = top_1n.T

top_1n['Outros'] = top_1n.Total - (top_1n.United_States + top_1n.Canada + top_1n.Mexico)
top_1n.pop('Total')
top_1n = top_1n.T


top_2n = north_america_ano.sort_values(by=[2000],ascending = False).iloc[:, 10:11]
top_2n = top_2n.T

top_2n['Outros'] = top_2n.Total - (top_2n.United_States + top_2n.Canada + top_2n.Mexico)
top_2n.pop('Total')
top_2n = top_2n.T


top_3n = north_america_ano.sort_values(by=[2010],ascending = False).iloc[:, 20:21]
top_3n = top_3n.T

top_3n['Outros'] = top_3n.Total - (top_3n.United_States + top_3n.Canada + top_3n.Mexico)
top_3n.pop('Total')
top_3n = top_3n.T


top_4n = north_america_ano.sort_values(by=[2020],ascending = False).iloc[:, 30:31]
top_4n = top_4n.T

top_4n['Outros'] = top_4n.Total - (top_4n.United_States + top_4n.Canada + top_4n.Mexico)
top_4n.pop('Total')
top_4n = top_4n.T

# %%
fig = plt.figure(figsize=(20, 20), facecolor = '#ffff')

ax1 = plt.subplot2grid((2,2),(0,0))
plt.pie(top_1n[1990],labels = top_1n.T.columns)
plt.title("Consumo da América do Norte em 1990")

ax2 = fig.add_subplot(2,2,2)
plt.pie(top_2n[2000],labels = top_2n.T.columns)
plt.title("Consumo da América do Norte em 2000")

ax3 = fig.add_subplot(2,2,3)
plt.pie(top_3n[2010],labels = top_3n.T.columns)
plt.title("Consumo da América do Norte em 2010")

ax4 = fig.add_subplot(2,2,4)
plt.pie(top_4n[2020],labels = top_4n.T.columns)
plt.title("Consumo da América do Norte em 2020")
# Out:
# Text(0.5, 1.0, 'Consumo da América do Norte em 2020')
