# 13        7501.35  38181.29  1535.16  6140.64      4954.38  11036.87
# 14        7780.47  41437.69  1558.42  6466.28      5245.13  11188.06
# 15        8059.59  43693.91  1570.05  6652.36      5675.44  11222.95
# 16        8303.82  46124.58  1616.57  6861.70      5989.45  11548.59
# 17        8571.31  48555.25  1663.09  7129.19      6315.09  11664.89
# 18        8780.65  49636.84  1721.24  7443.20      6850.07  11874.23
# 19        8559.68  51858.17  1721.24  7606.02      7059.41  10967.09
# 20        9117.92  56010.08  1732.87  7803.73      7361.79  11804.45
# 21        9304.00  58324.45  1744.50  8117.74      7524.61  12164.98
# 22        9594.75  60022.43  1744.50  8303.82      7943.29  12269.65
# 23        9978.54  61499.44  1767.76  8431.75      8071.22  12002.16
# 24        9943.65  62895.04  1767.76  8896.95      8513.16  11699.78
# 25        9873.87  63476.54  1767.76  8838.80      8675.98  11222.95
# 26        9745.94  63941.74  1767.76  9106.29      8862.06  11595.11
# 27        9687.79  65721.13  1791.02  9304.00      9210.96  11792.82
# 28        9513.34  68035.50  1791.02  9559.86      9257.48  12385.95
# 29        9478.45  69582.29  1802.65  9641.27      9455.19  12490.62
# 30        8815.54  69256.65  1767.76  9408.67      9338.89  11804.45

# %%
df = df.set_index('Year')

# %% [markdown]
# # Analise do Consumo por Continente

# %% [markdown]
# 5 anos com maior consumo

# %%
dt = df.sort_values(by = ['World'], ascending = False)
dt.iloc[:5, :1]
# Out:
#           World
# Year
# 2019  167553.41
# 2018  166297.37
# 2017  162459.47
# 2020  160819.64
# 2016  159377.52

# %%
dt = df.sort_values(by = ['OECD'], ascending = False)
dt.iloc[:5, 1:2]
# Out:
#           OECD
# Year
# 2007  64883.77
# 2006  64616.28
# 2005  64453.46
# 2004  64058.04
# 2008  64034.78

# %%
dt = df.sort_values(by = ['BRICS'], ascending = False)
dt.iloc[:5, 2:3]
# Out:
#          BRICS
# Year
# 2019  63255.57
# 2020  63162.53
# 2018  61673.89
# 2017  59429.30
# 2016  57742.95

# %%
dt = df.sort_values(by = ['Europe'], ascending = False)
dt.iloc[:5, 3:4]
# Out:
#         Europe
# Year
# 2006  23108.81
# 2005  22864.58
# 2008  22829.69
# 2007  22829.69
# 2004  22748.28

# %%
dt = df.sort_values(by = ['North America'], ascending = False)
dt.iloc[:5, 4:5]
# Out:
#       North America
# Year
# 2007       30424.08
# 2005       30168.22
# 2004       29993.77
# 2006       29958.88
# 2008       29644.87

# %%
dt = df.sort_values(by = ['Latin America'], ascending = False)
dt.iloc[:5, 5:6]
# Out:
#       Latin America
# Year
# 2013        9978.54
# 2014        9943.65
# 2015        9873.87
# 2016        9745.94
# 2017        9687.79

# %%
dt = df.sort_values(by = ['Asia'], ascending = False)
dt.iloc[:5, 6:7]
# Out:
#           Asia
# Year
# 2019  69582.29
# 2020  69256.65
# 2018  68035.50
# 2017  65721.13
# 2016  63941.74

# %%
dt = df.sort_values(by = ['Pacific'], ascending = False)
dt.iloc[:5, 7:8]
# Out:
#       Pacific
# Year
# 2019  1802.65
# 2018  1791.02
# 2017  1791.02
# 2020  1767.76
# 2016  1767.76

# %%
dt = df.sort_values(by = ['Africa'], ascending = False)
dt.iloc[:5, 8:9]
# Out:
#        Africa
# Year
# 2019  9641.27
# 2018  9559.86
# 2020  9408.67
# 2017  9304.00
# 2016  9106.29

# %%
dt = df.sort_values(by = ['Middle-East'], ascending = False)
dt.iloc[:5, 9:10]
# Out:
#       Middle-East
# Year
# 2019      9455.19
# 2020      9338.89
# 2018      9257.48
# 2017      9210.96
# 2016      8862.06

# %%
dt = df.sort_values(by = ['CIS'], ascending = False)
dt.iloc[:5, 10:11]
# Out:
#            CIS
# Year
# 1990  16049.40
# 1991  15898.21
# 1992  14339.79
# 1993  13246.57
# 2019  12490.62

# %% [markdown]
# 5 anos com menor consumo

# %%
dt = df.sort_values(by = ['World'])
dt.iloc[:5, :1]
# Out:
#           World
# Year
# 1990  101855.54
# 1991  102483.56
# 1992  102588.23
# 1993  103646.56
# 1994  104449.03

# %%
dt = df.sort_values(by = ['OECD'])
dt.iloc[:5, 1:2]
# Out:
#           OECD
# Year
# 1990  52602.49
# 1991  53207.25
# 1992  53788.75
# 1993  54614.48
# 1994  55579.77

# %%
dt = df.sort_values(by = ['BRICS'])
dt.iloc[:5, 2:3]
# Out:
#          BRICS
# Year
# 1992  25993.05
# 1994  25993.05
# 1993  26283.80
# 1991  26434.99
# 1990  26621.07

# %%
dt = df.sort_values(by = ['Europe'])
dt.iloc[:5, 3:4]
# Out:
#         Europe
# Year
# 2020  19643.07
# 1994  20085.01
# 1992  20189.68
# 1993  20189.68
# 1991  20631.62

# %%
dt = df.sort_values(by = ['North America'])
dt.iloc[:5, 4:5]
# Out:
#       North America
# Year
# 1990       24667.23
# 1991       24841.68
# 1992       25341.77
# 1993       25830.23
# 1994       26365.21

# %%
dt = df.sort_values(by = ['Latin America'])
dt.iloc[:5, 5:6]
# Out:
#       Latin America
# Year
# 1990        5373.06
# 1991        5500.99
# 1992        5628.92
# 1993        5675.44
# 1994        5989.45

# %%
dt = df.sort_values(by = ['Asia'])
dt.iloc[:5, 6:7]
# Out:
#           Asia
# Year
# 1990  24574.19
# 1991  24783.53
# 1992  25690.67
# 1993  26876.93
# 1994  28098.08

# %%
dt = df.sort_values(by = ['Pacific'])
dt.iloc[:5, 7:8]
# Out:
#       Pacific
# Year
# 1991  1186.26
# 1990  1197.89
# 1992  1209.52
# 1993  1267.67
# 1994  1279.30

# %%
dt = df.sort_values(by = ['Africa'])
dt.iloc[:5, 8:9]
# Out:
#        Africa
# Year
# 1990  4407.77
# 1991  4535.70
# 1992  4582.22
# 1993  4721.78
# 1994  4803.19

# %%
dt = df.sort_values(by = ['Middle-East'])
dt.iloc[:5, 9:10]
# Out:
#       Middle-East
# Year
# 1990      2581.86
# 1991      2744.68
# 1992      3081.95
# 1993      3349.44
# 1994      3640.19

# %%
dt = df.sort_values(by = ['CIS'])
dt.iloc[:5, 10:11]
# Out:
#            CIS
# Year
# 1998  10152.99
# 1999  10373.96
# 1997  10373.96
# 2000  10501.89
# 2001  10571.67

# %% [markdown]
# Os 5 continentes com menor consumo em cada ano

# %%
df.pop('World')
df.pop('OECD')
df.pop('BRICS')
df.pop('CIS')
# Out:
# Year
# 1990    16049.40
# 1991    15898.21
# 1992    14339.79
# 1993    13246.57
# 1994    11606.74
# 1995    11188.06
# 1996    10850.79
# 1997    10373.96
# 1998    10152.99
# 1999    10373.96
# 2000    10501.89
# 2001    10571.67
# 2002    10653.08
# 2003    11036.87
# 2004    11188.06
# 2005    11222.95
# 2006    11548.59
# 2007    11664.89
# 2008    11874.23
# 2009    10967.09
# 2010    11804.45
# 2011    12164.98
# 2012    12269.65
# 2013    12002.16
# 2014    11699.78
# 2015    11222.95
# 2016    11595.11
# 2017    11792.82
# 2018    12385.95
# 2019    12490.62
# 2020    11804.45
# Name: CIS, dtype: float64

# %%
dt = df.T

an1 = dt.iloc[: , :6]
an2 = dt.iloc[: , 6: 11]
an3 = dt.iloc[: , 11:16]
an4 = dt.iloc[: , 16:21]
an5 = dt.iloc[: , 21:26]
an6 = dt.iloc[: , 26: ]

# %%
an1.sort_values(by = [1990]).iloc[:5, :1]
# Out:
# Year               1990
# Pacific         1197.89
# Middle-East     2581.86
# Africa          4407.77
# Latin America   5373.06
# Europe         20654.88

# %%
an1.sort_values(by = [1991]).iloc[:5, 1:2]
# Out:
# Year               1991
# Pacific         1186.26
# Middle-East     2744.68
# Africa          4535.70
# Latin America   5500.99
# Europe         20631.62

# %%
an1.sort_values(by = [1992]).iloc[:5, 2:3]
# Out:
# Year               1992
# Pacific         1209.52
# Middle-East     3081.95
# Africa          4582.22
# Latin America   5628.92
# Europe         20189.68

# %%
an1.sort_values(by = [1993]).iloc[:5, 3:4]
# Out:
# Year               1993
# Pacific         1267.67
# Middle-East     3349.44
# Africa          4721.78
# Latin America   5675.44
# Europe         20189.68

# %%
an1.sort_values(by = [1994]).iloc[:5, 4:5]
# Out:
# Year               1994
# Pacific         1279.30
# Middle-East     3640.19
# Africa          4803.19
# Latin America   5989.45
# Europe         20085.01

# %%
an1.sort_values(by = [1995]).iloc[:5, 5:6]
# Out:
# Year               1995
# Pacific         1290.93
# Middle-East     3744.86
# Africa          5000.90
# Latin America   6024.34
# Europe         20713.03

# %%
an2.sort_values(by = [1996]).iloc[:5, :1]
# Out:
# Year               1996
# Pacific         1372.34
# Middle-East     3814.64
# Africa          5152.09
# Latin America   6303.46
# Europe         21445.72

# %%
an2.sort_values(by = [1997]).iloc[:5, 1:2]
# Out:
# Year               1997
# Pacific         1407.23
# Middle-East     4058.87
# Africa          5280.02
# Latin America   6570.95
# Europe         21341.05

# %%
an2.sort_values(by = [1998]).iloc[:5, 2:3]
# Out:
# Year               1998
# Pacific         1442.12
# Middle-East     4082.13
# Africa          5431.21
# Latin America   6803.55
# Europe         21503.87

# %%
an2.sort_values(by = [1999]).iloc[:5, 3:4]
# Out:
# Year               1999
# Pacific         1477.01
# Middle-East     4244.95
# Africa          5559.14
# Latin America   6989.63
# Europe         21306.16

# %%
an2.sort_values(by = [2000]).iloc[:5, 4:5]
# Out:
# Year               2000
# Pacific         1500.27
# Middle-East     4314.73
# Africa          5617.29
# Latin America   7024.52
# Europe         21538.76

# %%
an3.sort_values(by = [2001]).iloc[:5, :1]
# Out:
# Year               2001
# Pacific         1477.01
# Middle-East     4663.63
# Africa          5756.85
# Latin America   7036.15
# Europe         21934.18

# %%
an3.sort_values(by = [2002]).iloc[:5, 1:2]
# Out:
# Year               2002
# Pacific         1523.53
# Middle-East     4884.60
# Africa          5849.89
# Latin America   7280.38
# Europe         21969.07

# %%
an3.sort_values(by = [2003]).iloc[:5, 2:3]
# Out:
# Year               2003
# Pacific         1535.16
# Middle-East     4954.38
# Africa          6140.64
# Latin America   7501.35
# Europe         22515.68

# %%
an3.sort_values(by = [2004]).iloc[:5, 3:4]
# Out:
# Year               2004
# Pacific         1558.42
# Middle-East     5245.13
# Africa          6466.28
# Latin America   7780.47
# Europe         22748.28

# %%
an3.sort_values(by = [2005]).iloc[:5, 4:5]
# Out:
# Year               2005
# Pacific         1570.05
# Middle-East     5675.44
# Africa          6652.36
# Latin America   8059.59
# Europe         22864.58

# %%
an4.sort_values(by = [2006]).iloc[:5, :1]
# Out:
# Year               2006
# Pacific         1616.57
# Middle-East     5989.45
# Africa          6861.70
# Latin America   8303.82
# Europe         23108.81

# %%
an4.sort_values(by = [2007]).iloc[:5, 1:2]
# Out:
# Year               2007
# Pacific         1663.09
# Middle-East     6315.09
# Africa          7129.19
# Latin America   8571.31
# Europe         22829.69

# %%
an4.sort_values(by = [2008]).iloc[:5, 2:3]
# Out:
# Year               2008
# Pacific         1721.24
# Middle-East     6850.07
# Africa          7443.20
# Latin America   8780.65
# Europe         22829.69

# %%
an4.sort_values(by = [2009]).iloc[:5, 3:4]
# Out:
# Year               2009
# Pacific         1721.24
# Middle-East     7059.41
# Africa          7606.02
# Latin America   8559.68
# Europe         21608.54

# %%
an4.sort_values(by = [2010]).iloc[:5, 4:5]
# Out:
# Year               2010
# Pacific         1732.87
# Middle-East     7361.79
# Africa          7803.73
# Latin America   9117.92
# Europe         22469.16

# %%
an5.sort_values(by = [2011]).iloc[:5, :1]
# Out:
# Year               2011
# Pacific         1744.50
# Middle-East     7524.61
# Africa          8117.74
# Latin America   9304.00
# Europe         21794.62

# %%
an5.sort_values(by = [2012]).iloc[:5, 1:2]
# Out:
# Year               2012
# Pacific         1744.50
# Middle-East     7943.29
# Africa          8303.82
# Latin America   9594.75
# Europe         21689.95

# %%
an5.sort_values(by = [2013]).iloc[:5, 2:3]
# Out:
# Year               2013
# Pacific         1767.76
# Middle-East     8071.22
# Africa          8431.75
# Latin America   9978.54
# Europe         21480.61

# %%
an5.sort_values(by = [2014]).iloc[:5, 3:4]
# Out:
# Year               2014
# Pacific         1767.76
# Middle-East     8513.16
# Africa          8896.95
# Latin America   9943.65
# Europe         20689.77

# %%
an5.sort_values(by = [2014]).iloc[:5, 4:5]
# Out:
# Year               2015
# Pacific         1767.76
# Middle-East     8675.98
# Africa          8838.80
# Latin America   9873.87
# Europe         21038.67

# %%
an6.sort_values(by = [2016]).iloc[:5, :1]
# Out:
# Year               2016
# Pacific         1767.76
# Middle-East     8862.06
# Africa          9106.29
# Latin America   9745.94
# Europe         21224.75

# %%
an6.sort_values(by = [2017]).iloc[:5, 1:2]
# Out:
# Year               2017
# Pacific         1791.02
# Middle-East     9210.96
# Africa          9304.00
# Latin America   9687.79
# Europe         21620.17

# %%
an6.sort_values(by = [2018]).iloc[:5, 2:3]
# Out:
# Year               2018
# Pacific         1791.02
# Middle-East     9257.48
# Latin America   9513.34
# Africa          9559.86
# Europe         21399.20

# %%
an6.sort_values(by = [2019]).iloc[:5, 3:4]
# Out:
# Year               2019
# Pacific         1802.65
# Middle-East     9455.19
# Latin America   9478.45
# Africa          9641.27
# Europe         21061.93

# %%
an6.sort_values(by = [2020]).iloc[:5, 4:5]
# Out:
# Year               2020
# Pacific         1767.76
# Latin America   8815.54
# Middle-East     9338.89
# Africa          9408.67
# Europe         19643.07

# %% [markdown]
# Os 5 continente com maior consumo em cada ano

# %%
an1.sort_values(by = [1990],ascending = False).iloc[:5, :1]
# Out:
# Year               1990
# North America  24667.23
# Asia           24574.19
# Europe         20654.88
# Latin America   5373.06
# Africa          4407.77

# %%
an1.sort_values(by = [1991],ascending = False).iloc[:5, 1:2]
# Out:
# Year               1991
# North America  24841.68
# Asia           24783.53
# Europe         20631.62
# Latin America   5500.99
# Africa          4535.70

# %%
an1.sort_values(by = [1992],ascending = False).iloc[:5, 2:3]
# Out:
# Year               1992
# Asia           25690.67
# North America  25341.77
# Europe         20189.68
# Latin America   5628.92
# Africa          4582.22

# %%
an1.sort_values(by = [1993],ascending = False).iloc[:5, 3:4]
# Out:
# Year               1993
# Asia           26876.93
# North America  25830.23
# Europe         20189.68
# Latin America   5675.44
# Africa          4721.78

# %%
an1.sort_values(by = [1994],ascending = False).iloc[:5, 4:5]
# Out:
# Year               1994
# Asia           28098.08
# North America  26365.21
# Europe         20085.01
# Latin America   5989.45
# Africa          4803.19

# %%
an1.sort_values(by = [1995],ascending = False).iloc[:5, 5:6]
# Out:
# Year               1995
# Asia           29761.17
# North America  26714.11
# Europe         20713.03
# Latin America   6024.34
# Africa          5000.90

# %%
an2.sort_values(by = [1996],ascending = False).iloc[:5, :1]
# Out:
# Year               1996
# Asia           30772.98
# North America  27295.61
# Europe         21445.72
# Latin America   6303.46
# Africa          5152.09

# %%
an2.sort_values(by = [1997],ascending = False).iloc[:5, 1:2]
# Out:
# Year               1997
# Asia           31435.89
# North America  27574.73
# Europe         21341.05
# Latin America   6570.95
# Africa          5280.02

# %%
an2.sort_values(by = [1998],ascending = False).iloc[:5, 2:3]
# Out:
# Year               1998
# Asia           31331.22
# North America  27772.44
# Europe         21503.87
# Latin America   6803.55
# Africa          5431.21

# %%
an2.sort_values(by = [1999],ascending = False).iloc[:5, 3:4]
# Out:
# Year               1999
# Asia           32412.81
# North America  28528.39
# Europe         21306.16
# Latin America   6989.63
# Africa          5559.14

# %%
an2.sort_values(by = [2000],ascending = False).iloc[:5, 4:5]
# Out:
# Year               2000
# Asia           33564.18
# North America  29342.49
# Europe         21538.76
# Latin America   7024.52
# Africa          5617.29

# %%
an3.sort_values(by = [2001],ascending = False).iloc[:5, :1]
# Out:
# Year               2001
# Asia           34227.09
# North America  28795.88
# Europe         21934.18
# Latin America   7036.15
# Africa          5756.85

# %%
an3.sort_values(by = [2002],ascending = False).iloc[:5, 1:2]
# Out:
# Year               2002
# Asia           35680.84
# North America  29156.41
# Europe         21969.07
# Latin America   7280.38
# Africa          5849.89

# %%
an3.sort_values(by = [2003],ascending = False).iloc[:5, 2:3]
# Out:
# Year               2003
# Asia           38181.29
# North America  29377.38
# Europe         22515.68
# Latin America   7501.35
# Africa          6140.64

# %%
an3.sort_values(by = [2004],ascending = False).iloc[:5, 3:4]
# Out:
# Year               2004
# Asia           41437.69
# North America  29993.77
# Europe         22748.28
# Latin America   7780.47
# Africa          6466.28

# %%
an3.sort_values(by = [2005],ascending = False).iloc[:5, 4:5]
# Out:
# Year               2005
# Asia           43693.91
# North America  30168.22
# Europe         22864.58
# Latin America   8059.59
# Africa          6652.36

# %%
an4.sort_values(by = [2006],ascending = False).iloc[:5, :1]
# Out:
# Year               2006
# Asia           46124.58
# North America  29958.88
# Europe         23108.81
# Latin America   8303.82
# Africa          6861.70

# %%
an4.sort_values(by = [2007],ascending = False).iloc[:5, 1:2]
# Out:
# Year               2007
# Asia           48555.25
# North America  30424.08
# Europe         22829.69
# Latin America   8571.31
# Africa          7129.19

# %%
an4.sort_values(by = [2008],ascending = False).iloc[:5, 2:3]
# Out:
# Year               2008
# Asia           49636.84
# North America  29644.87
# Europe         22829.69
# Latin America   8780.65
# Africa          7443.20

# %%
an4.sort_values(by = [2009],ascending = False).iloc[:5, 3:4]
# Out:
# Year               2009
# Asia           51858.17
# North America  28214.38
# Europe         21608.54
# Latin America   8559.68
# Africa          7606.02

# %%
an4.sort_values(by = [2010],ascending = False).iloc[:5, 4:5]
# Out:
# Year               2010
# Asia           56010.08
# North America  28830.77
# Europe         22469.16
# Latin America   9117.92
# Africa          7803.73

# %%
an5.sort_values(by = [2011],ascending = False).iloc[:5, :1]
# Out:
# Year               2011
# Asia           58324.45
# North America  28598.17
# Europe         21794.62
# Latin America   9304.00
# Africa          8117.74

# %%
an5.sort_values(by = [2012],ascending = False).iloc[:5, 1:2]
# Out:
# Year               2012
# Asia           60022.43
# North America  28167.86
# Europe         21689.95
# Latin America   9594.75
# Africa          8303.82

# %%
an5.sort_values(by = [2013],ascending = False).iloc[:5, 2:3]
# Out:
# Year               2013
# Asia           61499.44
# North America  28667.95
# Europe         21480.61
# Latin America   9978.54
# Africa          8431.75

# %%
an5.sort_values(by = [2014],ascending = False).iloc[:5, 3:4]
# Out:
# Year               2014
# Asia           62895.04
# North America  29063.37
# Europe         20689.77
# Latin America   9943.65
# Africa          8896.95

# %%
an5.sort_values(by = [2015],ascending = False).iloc[:5, 4:5]
# Out:
# Year               2015
# Asia           63476.54
# North America  28784.25
# Europe         21038.67
# Latin America   9873.87
# Africa          8838.80

# %%
an6.sort_values(by = [2016],ascending = False).iloc[:5, :1]
# Out:
# Year               2016
# Asia           63941.74
# North America  28563.28
# Europe         21224.75
# Latin America   9745.94
# Africa          9106.29

# %%
an6.sort_values(by = [2017],ascending = False).iloc[:5, 1:2]
# 6          107.0   98.0    14.0          90.0                  29.0
# 7          109.0  109.0    15.0          86.0                  31.0
# 8          111.0  111.0    17.0          92.0                  32.0
# 9          109.0  126.0    18.0          94.0                  32.0
# 10         109.0  123.0    19.0          98.0                  31.0
# 11         105.0  133.0    20.0         100.0                  40.0
# 12         100.0  138.0    20.0         114.0                  39.0
# 13         113.0  143.0    21.0         115.0                  38.0
# 14         123.0  156.0    24.0         115.0                  42.0
# 15         118.0  173.0    27.0         123.0                  44.0
# 16         120.0  180.0    25.0         132.0                  46.0
# 17         131.0  191.0    25.0         138.0                  50.0
# 18         142.0  205.0    28.0         151.0                  59.0
# 19         144.0  204.0    29.0         159.0                  64.0
# 20         134.0  204.0    29.0         175.0                  61.0
# 21         137.0  208.0    28.0         184.0                  60.0
# 22         131.0  218.0    29.0         189.0                  64.0
# 23         130.0  222.0    30.0         188.0                  68.0
# 24         138.0  238.0    27.0         207.0                  74.0
# 25         129.0  238.0    33.0         216.0                  76.0
# 26         135.0  246.0    36.0         215.0                  79.0
# 27         136.0  262.0    34.0         219.0                  78.0
# 28         134.0  266.0    34.0         214.0                  78.0
# 29         129.0  269.0    36.0         215.0                  83.0
# 30         124.0  268.0    38.0         209.0                  81.0
# 31           NaN    NaN     NaN           NaN                   NaN
# 32           NaN    NaN     NaN           NaN                   NaN
#
# [33 rows x 45 columns]

# %%
df = df.set_index('Year')

# %% [markdown]
# 5 anos de maior consumo em cada país

# %%
dt = df.sort_values(by = ['China'],ascending = False)
dt.iloc[ :5, :1]
# Out:
#          China
# Year
# 2020.0  3381.0
# 2019.0  3309.0
# 2018.0  3201.0
# 2017.0  3070.0
# 2015.0  2994.0

# %%
dt = df.sort_values(by = ['United States'],ascending = False)
dt.iloc[ :5, 1:2]
# Out:
#         United States
# Year
# 2007.0         2338.0
# 2005.0         2320.0
# 2004.0         2308.0
# 2006.0         2298.0
# 2008.0         2278.0

# %%
dt = df.sort_values(by = ['Brazil'],ascending = False)
dt.iloc[ :5, 2:3]
# Out:
#         Brazil
# Year
# 2014.0   303.0
# 2015.0   297.0
# 2013.0   294.0
# 2019.0   293.0
# 2017.0   292.0

# %%
dt = df.sort_values(by = ['Belgium'],ascending = False)
dt.iloc[ :5, 3:4]
# Out:
#         Belgium
# Year
# 2010.0     60.0
# 2005.0     58.0
# 2000.0     58.0
# 2008.0     58.0
# 2004.0     58.0

# %%
dt = df.sort_values(by = ['Czechia'],ascending = False)
dt.iloc[ :5, 4:5]
# Out:
#         Czechia
# Year
# 1990.0     50.0
# 2007.0     46.0
# 2006.0     46.0
# 2004.0     46.0
# 2003.0     45.0

# %%
dt = df.sort_values(by = ['France'],ascending = False)
dt.iloc[ :5, 5:6]
# Out:
#         France
# Year
# 2005.0   273.0
# 2004.0   271.0
# 2006.0   268.0
# 2003.0   268.0
# 2008.0   266.0

# %%
dt = df.sort_values(by = ['Germany'],ascending = False)
dt.iloc[ :5, 6:7]
# Out:
#         Germany
# Year
# 1990.0    351.0
# 2006.0    349.0
# 1996.0    348.0
# 2001.0    347.0
# 1997.0    345.0

# %%
dt = df.sort_values(by = ['Italy'],ascending = False)
dt.iloc[ :5, 7:8]
# Out:
#         Italy
# Year
# 2005.0  187.0
# 2006.0  185.0
# 2007.0  184.0
# 2004.0  183.0
# 2008.0  182.0

# %%
dt = df.sort_values(by = ['Netherlands'],ascending = False)
dt.iloc[ :5, 8:9]
# Out:
#         Netherlands
# Year
# 2010.0         83.0
# 2004.0         81.0
# 2005.0         80.0
# 2003.0         80.0
# 2007.0         79.0

# %%
dt = df.sort_values(by = ['Poland'],ascending = False)
dt.iloc[ :5, 9:10]
# Out:
#         Poland
# Year
# 2018.0   106.0
# 2017.0   104.0
# 1996.0   104.0
# 2019.0   103.0
# 1990.0   103.0

# %%
dt = df.sort_values(by = ['Portugal'],ascending = False)
dt.iloc[ :5, 10:11]
# Out:
#         Portugal
# Year
# 2005.0      26.0
# 2004.0      26.0
# 2002.0      26.0
# 2000.0      25.0
# 2008.0      25.0

# %%
dt = df.sort_values(by = ['Romania'],ascending = False)
dt.iloc[ :5, 11:12]
# Out:
#         Romania
# Year
# 1990.0     62.0
# 1991.0     51.0
# 1996.0     48.0
# 1995.0     47.0
# 1992.0     46.0

# %%
dt = df.sort_values(by = ['Spain'],ascending = False)
dt.iloc[ :5, 12:13]
# Out:
#         Spain
# Year
# 2007.0  143.0
# 2005.0  142.0
# 2006.0  141.0
# 2008.0  139.0
# 2004.0  139.0

# %%
dt = df.sort_values(by = ['Sweden'],ascending = False)
dt.iloc[ :5, 13:14]
# Out:
#         Sweden
# Year
# 2004.0    53.0
# 2005.0    52.0
# 2002.0    52.0
# 2010.0    51.0
# 1996.0    51.0

# %%
dt = df.sort_values(by = ['United Kingdom'],ascending = False)
dt.iloc[ :5, 14:15]
# Out:
#         United Kingdom
# Year
# 1996.0           226.0
# 2003.0           224.0
# 2001.0           224.0
# 2005.0           223.0
# 2000.0           223.0

# %%
dt = df.sort_values(by = ['Norway'],ascending = False)
dt.iloc[ :5, 15:16]
# Out:
#         Norway
# Year
# 2013.0    33.0
# 2010.0    33.0
# 2009.0    32.0
# 2008.0    32.0
# 2012.0    31.0

# %%
dt = df.sort_values(by = ['Turkey'],ascending = False)
dt.iloc[ :5, 16:17]
# Out:
#         Turkey
# Year
# 2017.0   147.0
# 2019.0   145.0
# 2018.0   144.0
# 2020.0   141.0
# 2016.0   137.0

# %%
dt = df.sort_values(by = ['Kazakhstan'],ascending = False)
dt.iloc[ :5, 17:18]
# Out:
#         Kazakhstan
# Year
# 2013.0        82.0
# 1992.0        79.0
# 2019.0        77.0
# 2011.0        77.0
# 2018.0        76.0

# %%
dt = df.sort_values(by = ['Russia'],ascending = False)
dt.iloc[ :5, 18:19]
# Out:
#         Russia
# Year
# 1990.0   879.0
# 1991.0   871.0
# 1992.0   795.0
# 2019.0   768.0
# 2018.0   760.0

# %%
dt = df.sort_values(by = ['Ukraine'],ascending = False)
dt.iloc[ :5, 19:20]
# Out:
#         Ukraine
# Year
# 1990.0    252.0
# 1991.0    252.0
# 1992.0    220.0
# 1993.0    195.0
# 1994.0    166.0

# %%
dt = df.sort_values(by = ['Uzbekistan'],ascending = False)
dt.iloc[ :5, 20:21]
# Out:
#         Uzbekistan
# Year
# 2002.0        53.0
# 2004.0        51.0
# 2000.0        51.0
# 2001.0        51.0
# 2003.0        51.0

# %%
dt = df.sort_values(by = ['Argentina'],ascending = False)
dt.iloc[ :5, 21:22]
# Out:
#         Argentina
# Year
# 2015.0       83.0
# 2017.0       82.0
# 2016.0       82.0
# 2014.0       82.0
# 2013.0       82.0

# %%
dt = df.sort_values(by = ['Canada'],ascending = False)
dt.iloc[ :5, 22:23]
# Out:
#         Canada
# Year
# 2019.0   301.0
# 2018.0   298.0
# 2017.0   295.0
# 2016.0   287.0
# 2015.0   283.0

# %%
dt = df.sort_values(by = ['Chile'],ascending = False)
dt.iloc[ :5, 23:24]
# Out:
#         Chile
# Year
# 2019.0   40.0
# 2018.0   39.0
# 2020.0   38.0
# 2017.0   38.0
# 2016.0   38.0

# %%
dt = df.sort_values(by = ['Colombia'],ascending = False)
dt.iloc[ :5, 24:25]
# Out:
#         Colombia
# Year
# 2016.0      42.0
# 2015.0      41.0
# 2019.0      41.0
# 2013.0      40.0
# 2017.0      40.0

# %%
dt = df.sort_values(by = ['Mexico'],ascending = False)
dt.iloc[ :5, 25:26]
# Out:
#         Mexico
# Year
# 2012.0   192.0
# 2013.0   192.0
# 2014.0   188.0
# 2011.0   187.0
# 2016.0   185.0

# %%
dt = df.sort_values(by = ['Venezuela'],ascending = False)
dt.iloc[ :5, 26:27]
# Out:
#         Venezuela
# Year
# 2013.0       76.0
# 2010.0       75.0
# 2012.0       69.0
# 2011.0       67.0
# 2002.0       67.0

# %%
dt = df.sort_values(by = ['Indonesia'],ascending = False)
dt.iloc[ :5, 27:28]
# Out:
#         Indonesia
# Year
# 2019.0      237.0
# 2018.0      231.0
# 2020.0      225.0
# 2017.0      222.0
# 2016.0      209.0

# %%
dt = df.sort_values(by = ['Japan'],ascending = False)
dt.iloc[ :5, 28:29]
# Out:
#         Japan
# Year
# 2004.0  526.0
# 2005.0  524.0
# 2006.0  524.0
# 2000.0  520.0
# 2007.0  519.0

# %%
dt = df.sort_values(by = ['Malaysia'],ascending = False)
dt.iloc[ :5, 29:30]
# Out:
#         Malaysia
# Year
# 2019.0      96.0
# 2018.0      94.0
# 2014.0      89.0
# 2020.0      88.0
# 2016.0      88.0

# %%
dt = df.sort_values(by = ['South Korea'],ascending = False)
dt.iloc[ :5, 30:31]
# Out:
#         South Korea
# Year
# 2018.0        296.0
# 2017.0        295.0
# 2019.0        293.0
# 2016.0        293.0
# 2020.0        283.0

# %%
dt = df.sort_values(by = ['Taiwan'],ascending = False)
dt.iloc[ :5, 31:32]
# Out:
#         Taiwan
# Year
# 2018.0   110.0
# 2016.0   109.0
# 2014.0   109.0
# 2019.0   108.0
# 2017.0   107.0

# %%
dt = df.sort_values(by = ['Thailand'],ascending = False)
dt.iloc[ :5, 32:33]
# Out:
#         Thailand
# Year
# 2017.0     139.0
# 2016.0     139.0
# 2019.0     137.0
# 2018.0     136.0
# 2015.0     136.0

# %%
dt = df.sort_values(by = ['India'],ascending = False)
dt.iloc[ :5, 33:34]
# Out:
#         India
# Year
# 2019.0  940.0
# 2018.0  919.0
# 2020.0  908.0
# 2017.0  883.0
# 2016.0  852.0

# %%
dt = df.sort_values(by = ['Australia'],ascending = False)
dt.iloc[ :5, 34:35]
# Out:
#         Australia
# Year
# 2019.0      129.0
# 2018.0      128.0
# 2017.0      128.0
# 2016.0      127.0
# 2015.0      127.0

# %%
dt = df.sort_values(by = ['New Zealand'],ascending = False)
dt.iloc[ :5, 35:36]
# Out:
#         New Zealand
# Year
# 2020.0         21.0
# 2019.0         21.0
# 2017.0         21.0
# 2016.0         21.0
# 2015.0         21.0

# %%
dt = df.sort_values(by = ['Algeria'],ascending = False)
dt.iloc[ :5, 36:37]
# Out:
#         Algeria
# Year
# 2019.0     65.0
# 2018.0     61.0
# 2020.0     59.0
# 2017.0     57.0
# 2016.0     56.0

# %%
dt = df.sort_values(by = ['Egypt'],ascending = False)
dt.iloc[ :5, 37:38]
# Out:
#         Egypt
# Year
# 2019.0   97.0
# 2018.0   96.0
# 2017.0   93.0
# 2020.0   92.0
# 2016.0   88.0

# %%
dt = df.sort_values(by = ['Nigeria'],ascending = False)
dt.iloc[ :5, 38:39]
# Out:
#         Nigeria
# Year
# 2018.0    160.0
# 2020.0    159.0
# 2019.0    157.0
# 2017.0    152.0
# 2016.0    150.0

# %%
dt = df.sort_values(by = ['South Africa'],ascending = False)
dt.iloc[ :5, 39:40]
# Out:
#         South Africa
# Year
# 2009.0         144.0
# 2008.0         142.0
# 2014.0         138.0
# 2011.0         137.0
# 2017.0         136.0

# %%
dt = df.sort_values(by = ['Iran'],ascending = False)
dt.iloc[ :5, 40:41]
# Out:
#          Iran
# Year
# 2019.0  269.0
# 2020.0  268.0
# 2018.0  266.0
# 2017.0  262.0
# 2016.0  246.0

# %%
dt = df.sort_values(by = ['Kuwait'],ascending = False)
dt.iloc[ :5, 41:42]
# Out:
#         Kuwait
# Year
# 2020.0    38.0
# 2019.0    36.0
# 2016.0    36.0
# 2018.0    34.0
# 2017.0    34.0

# %%
dt = df.sort_values(by = ['Saudi Arabia'],ascending = False)
dt.iloc[ :5, 42:43]
# Out:
#         Saudi Arabia
# Year
# 2017.0         219.0
# 2015.0         216.0
# 2019.0         215.0
# 2016.0         215.0
# 2018.0         214.0

# %%
dt = df.sort_values(by = ['United Arab Emirates'],ascending = False)
dt.iloc[ :5, 43:44]
# Out:
#         United Arab Emirates
# Year
# 2019.0                  83.0
# 2020.0                  81.0
# 2016.0                  79.0
# 2018.0                  78.0
# 2017.0                  78.0

# %% [markdown]
# 5 anos de menor consumo em cada país

# %%
dt = df.sort_values(by = ['China'])
dt.iloc[ :5, :1]
# Out:
#         China
# Year
# 1991.0  848.0
# 1990.0  874.0
# 1992.0  877.0
# 1993.0  929.0
# 1994.0  973.0

# %%
dt = df.sort_values(by = ['United States'])
dt.iloc[ :5, 1:2]
# Out:
#         United States
# Year
# 1990.0         1910.0
# 1991.0         1925.0
# 1992.0         1964.0
# 1993.0         1998.0
# 1994.0         2036.0

# %%
dt = df.sort_values(by = ['Brazil'])
dt.iloc[ :5, 2:3]
# Out:
#         Brazil
# Year
# 1990.0   141.0
# 1991.0   143.0
# 1992.0   145.0
# 1993.0   148.0
# 1994.0   156.0

# %%
dt = df.sort_values(by = ['Belgium'])
dt.iloc[ :5, 3:4]
# Out:
#         Belgium
# Year
# 1990.0     48.0
# 1993.0     49.0
# 1991.0     50.0
# 2020.0     51.0
# 1992.0     51.0

# %%
dt = df.sort_values(by = ['Czechia'])
dt.iloc[ :5, 4:5]
# Out:
#         Czechia
# Year
# 2020.0     39.0
# 1999.0     39.0
# 2016.0     41.0
# 1994.0     41.0
# 2000.0     41.0

# %%
dt = df.sort_values(by = ['France'])
dt.iloc[ :5, 5:6]
# Out:
#         France
# Year
# 2020.0   217.0
# 1990.0   225.0
# 1994.0   231.0
# 1992.0   234.0
# 1991.0   237.0

# %%
dt = df.sort_values(by = ['Germany'])
dt.iloc[ :5, 6:7]
# Out:
#         Germany
# Year
# 2020.0    275.0
# 2019.0    294.0
# 2018.0    302.0
# 2014.0    307.0
# 2015.0    309.0

# %%
dt = df.sort_values(by = ['Italy'])
dt.iloc[ :5, 7:8]
# Out:
#         Italy
# Year
# 2020.0  137.0
# 2014.0  147.0
# 1994.0  147.0
# 1990.0  147.0
# 1992.0  149.0

# %%
dt = df.sort_values(by = ['Netherlands'])
dt.iloc[ :5, 8:9]
# Out:
#         Netherlands
# Year
# 1990.0         67.0
# 1991.0         69.0
# 1992.0         69.0
# 1994.0         70.0
# 2020.0         70.0

# %%
dt = df.sort_values(by = ['Poland'])
dt.iloc[ :5, 9:10]
# Out:
#         Poland
# Year
# 2000.0    89.0
# 2002.0    89.0
# 2001.0    90.0
# 2004.0    91.0
# 2003.0    91.0

# %%
dt = df.sort_values(by = ['Portugal'])
dt.iloc[ :5, 10:11]
# Out:
#         Portugal
# Year
# 1990.0      17.0
# 1991.0      17.0
# 1992.0      18.0
# 1993.0      18.0
# 1994.0      18.0

# %%
dt = df.sort_values(by = ['Romania'])
dt.iloc[ :5, 11:12]
# Out:
#         Romania
# Year
# 2020.0     32.0
# 2016.0     32.0
# 2015.0     32.0
# 2014.0     32.0
# 2013.0     32.0

# %%
dt = df.sort_values(by = ['Spain'])
dt.iloc[ :5, 12:13]
# Out:
#         Spain
# Year
# 1990.0   90.0
# 1993.0   91.0
# 1991.0   93.0
# 1992.0   95.0
# 1994.0   96.0

# %%
dt = df.sort_values(by = ['Sweden'])
dt.iloc[ :5, 13:14]
# Out:
#         Sweden
# Year
# 2015.0    44.0
# 2009.0    45.0
# 1993.0    46.0
# 1990.0    47.0
# 2020.0    47.0

# %%
dt = df.sort_values(by = ['United Kingdom'])
dt.iloc[ :5, 14:15]
# Out:
#         United Kingdom
# Year
# 2020.0           154.0
# 2019.0           170.0
# 2018.0           175.0
# 2017.0           176.0
# 2016.0           179.0

# %%
dt = df.sort_values(by = ['Norway'])
dt.iloc[ :5, 15:16]
# Out:
#         Norway
# Year
# 1990.0    21.0
# 1991.0    22.0
# 1992.0    22.0
# 1994.0    23.0
# 1996.0    23.0

# %%
dt = df.sort_values(by = ['Turkey'])
dt.iloc[ :5, 16:17]
# Out:
#         Turkey
# Year
# 1990.0    51.0
# 1991.0    51.0
# 1992.0    53.0
# 1993.0    56.0
# 1994.0    56.0

# %%
dt = df.sort_values(by = ['Kazakhstan'])
dt.iloc[ :5, 17:18]
# Out:
#         Kazakhstan
# Year
# 2001.0        35.0
# 2000.0        36.0
# 1999.0        36.0
# 1997.0        39.0
# 1998.0        39.0

# %%
dt = df.sort_values(by = ['Russia'])
dt.iloc[ :5, 18:19]
# Out:
#         Russia
# Year
# 1998.0   588.0
# 1997.0   602.0
# 1999.0   609.0
# 2000.0   619.0
# 2002.0   623.0

# %%
dt = df.sort_values(by = ['Ukraine'])
dt.iloc[ :5, 19:20]
# Out:
#         Ukraine
# Year
# 2020.0     86.0
# 2017.0     89.0
# 2019.0     89.0
# 2016.0     92.0
# 2018.0     93.0

# %%
dt = df.sort_values(by = ['Uzbekistan'])
dt.iloc[ :5, 20:21]
# Out:
#         Uzbekistan
# Year
# 2015.0        39.0
# 2014.0        41.0
# 2016.0        42.0
# 1995.0        43.0
# 2020.0        44.0

# %%
dt = df.sort_values(by = ['Argentina'])
dt.iloc[ :5, 21:22]
# Out:
#         Argentina
# Year
# 1990.0       44.0
# 1991.0       46.0
# 1992.0       47.0
# 1993.0       48.0
# 1994.0       52.0

# %%
dt = df.sort_values(by = ['Canada'])
dt.iloc[ :5, 22:23]
# Out:
#         Canada
# Year
# 1991.0   210.0
# 1990.0   211.0
# 1992.0   216.0
# 1993.0   223.0
# 1994.0   231.0

# %%
dt = df.sort_values(by = ['Chile'])
dt.iloc[ :5, 23:24]
# Out:
#         Chile
# Year
# 1990.0   14.0
# 1991.0   14.0
# 1992.0   15.0
# 1993.0   16.0
# 1994.0   17.0

# %%
dt = df.sort_values(by = ['Colombia'])
dt.iloc[ :5, 24:25]
# Out:
#         Colombia
# Year
# 1990.0      24.0
# 1991.0      24.0
# 1992.0      25.0
# 2002.0      25.0
# 1993.0      26.0

# %%
dt = df.sort_values(by = ['Mexico'])
dt.iloc[ :5, 25:26]
# Out:
#         Mexico
# Year
# 1990.0   124.0
# 1991.0   130.0
# 1992.0   131.0
# 1995.0   132.0
# 1993.0   133.0

# %%
dt = df.sort_values(by = ['Venezuela'])
dt.iloc[ :5, 26:27]
# Out:
#         Venezuela
# Year
# 2020.0       29.0
# 2019.0       36.0
# 1990.0       40.0
# 1991.0       41.0
# 2018.0       42.0

# %%
dt = df.sort_values(by = ['Indonesia'])
dt.iloc[ :5, 27:28]
# Out:
#         Indonesia
# Year
# 1990.0       99.0
# 1991.0      103.0
# 1992.0      108.0
# 1993.0      119.0
# 1994.0      119.0

# %%
dt = df.sort_values(by = ['Japan'])
dt.iloc[ :5, 28:29]
# Out:
#         Japan
# Year
# 2020.0  386.0
# 2019.0  416.0
# 2018.0  428.0
# 2016.0  429.0
# 2017.0  434.0

# %%
dt = df.sort_values(by = ['Malaysia'])
dt.iloc[ :5, 29:30]
# Out:
#         Malaysia
# Year
# 1990.0      21.0
# 1991.0      26.0
# 1992.0      29.0
# 1993.0      32.0
# 1994.0      32.0

# %%
dt = df.sort_values(by = ['South Korea'])
dt.iloc[ :5, 30:31]
# Out:
#         South Korea
# Year
# 1990.0         94.0
# 1991.0        101.0
# 1992.0        111.0
# 1993.0        125.0
# 1994.0        133.0

# %%
dt = df.sort_values(by = ['Taiwan'])
dt.iloc[ :5, 31:32]
# Out:
#         Taiwan
# Year
# 1990.0    48.0
# 1991.0    52.0
# 1992.0    54.0
# 1993.0    58.0
# 1994.0    60.0

# %%
dt = df.sort_values(by = ['Thailand'])
dt.iloc[ :5, 32:33]
# Out:
#         Thailand
# Year
# 1990.0      42.0
# 1991.0      46.0
# 1992.0      49.0
# 1993.0      51.0
# 1994.0      57.0

# %%
dt = df.sort_values(by = ['India'])
dt.iloc[ :5, 33:34]
# Out:
#         India
# Year
# 1990.0  306.0
# 1991.0  318.0
# 1992.0  330.0
# 1993.0  338.0
# 1994.0  351.0

# %%
dt = df.sort_values(by = ['Australia'])
dt.iloc[ :5, 34:35]
# Out:
#         Australia
# Year
# 1991.0       85.0
# 1990.0       86.0
# 1992.0       87.0
# 1993.0       91.0
# 1994.0       91.0

# %%
dt = df.sort_values(by = ['New Zealand'])
dt.iloc[ :5, 35:36]
# Out:
#         New Zealand
# Year
# 1990.0         14.0
# 1991.0         14.0
# 1992.0         14.0
# 1993.0         15.0
# 1994.0         15.0

# %%
dt = df.sort_values(by = ['Algeria'])
dt.iloc[ :5, 36:37]
# Out:
#         Algeria
# Year
# 1990.0     22.0
# 1991.0     23.0
# 1994.0     23.0
# 1996.0     23.0
# 1992.0     24.0

# %%
dt = df.sort_values(by = ['Egypt'])
dt.iloc[ :5, 37:38]
# Out:
#         Egypt
# Year
# 1990.0   33.0
# 1991.0   33.0
# 1992.0   34.0
# 1994.0   34.0
# 1993.0   35.0

# %%
dt = df.sort_values(by = ['Nigeria'])
dt.iloc[ :5, 38:39]
# Out:
#         Nigeria
# Year
# 1990.0     66.0
# 1991.0     70.0
# 1992.0     72.0
# 1994.0     72.0
# 1995.0     73.0

# %%
dt = df.sort_values(by = ['South Africa'])
dt.iloc[ :5, 39:40]
# Out:
#         South Africa
# Year
# 1992.0          88.0
# 1990.0          90.0
# 1991.0          92.0
# 1993.0          94.0
# 1994.0          98.0

# %%
dt = df.sort_values(by = ['Iran'])
dt.iloc[ :5, 40:41]
# Out:
#         Iran
# Year
# 1990.0  69.0
# 1991.0  77.0
# 1992.0  81.0
# 1993.0  87.0
# 1994.0  97.0

# %%
dt = df.sort_values(by = ['Kuwait'])
dt.iloc[ :5, 41:42]
# Out:
#         Kuwait
# Year
# 1991.0     3.0
# 1990.0     9.0
# 1992.0     9.0
# 1993.0    12.0
# 1994.0    14.0

# %%
dt = df.sort_values(by = ['Saudi Arabia'])
dt.iloc[ :5, 42:43]
# Out:
#         Saudi Arabia
# Year
# 1990.0          58.0
# 1991.0          68.0
# 1992.0          77.0
# 1993.0          80.0
# 1994.0          84.0

# %%
dt = df.sort_values(by = ['United Arab Emirates'])
# Egypt                   88.0    93.0    96.0    97.0    92.0     NaN     NaN
# Nigeria                150.0   152.0   160.0   157.0   159.0     NaN     NaN
# South Africa           135.0   136.0   134.0   129.0   124.0     NaN     NaN
# Iran                   246.0   262.0   266.0   269.0   268.0     NaN     NaN
# Kuwait                  36.0    34.0    34.0    36.0    38.0     NaN     NaN
# Saudi Arabia           215.0   219.0   214.0   215.0   209.0     NaN     NaN
# United Arab Emirates    79.0    78.0    78.0    83.0    81.0     NaN     NaN
#
# [44 rows x 33 columns]

# %%
an1.sort_values(by = [1990], ascending = False).iloc[:5 , :1]
# Out:
# Year           1990.0
# United States  1910.0
# Russia          879.0
# China           874.0
# Japan           440.0
# Germany         351.0

# %%
an1.sort_values(by = [1991], ascending = False).iloc[:5 , 1:2]
# Out:
# Year           1991.0
# United States  1925.0
# Russia          871.0
# China           848.0
# Japan           445.0
# Germany         344.0

# %%
an1.sort_values(by = [1992], ascending = False).iloc[:5 , 2:3]
# Out:
# Year           1992.0
# United States  1964.0
# China           877.0
# Russia          795.0
# Japan           455.0
# Germany         338.0

# %%
an1.sort_values(by = [1993], ascending = False).iloc[:5 , 3:4]
# Out:
# Year           1993.0
# United States  1998.0
# China           929.0
# Russia          751.0
# Japan           458.0
# India           338.0

# %%
an1.sort_values(by = [1994], ascending = False).iloc[:5 , 4:5]
# Out:
# Year           1994.0
# United States  2036.0
# China           973.0
# Russia          657.0
# Japan           483.0
# India           351.0

# %%
an1.sort_values(by = [1995], ascending = False).iloc[:5 , 5:6]
# Out:
# Year           1995.0
# United States  2063.0
# China          1045.0
# Russia          636.0
# Japan           495.0
# India           371.0

# %%
an2.sort_values(by = [1996], ascending = False).iloc[:5 , :1]
# Out:
# Year           1996.0
# United States  2108.0
# China          1074.0
# Russia          630.0
# Japan           506.0
# India           383.0

# %%
an2.sort_values(by = [1997], ascending = False).iloc[:5 , 1:2]
# Out:
# Year           1997.0
# United States  2130.0
# China          1073.0
# Russia          602.0
# Japan           511.0
# India           398.0

# %%
an2.sort_values(by = [1998], ascending = False).iloc[:5 , 2:3]
# Out:
# Year           1998.0
# United States  2148.0
# China          1079.0
# Russia          588.0
# Japan           502.0
# India           407.0

# %%
an2.sort_values(by = [1999], ascending = False).iloc[:5 , 3:4]
# Out:
# Year           1999.0
# United States  2206.0
# China          1099.0
# Russia          609.0
# Japan           510.0
# India           431.0

# %%
an2.sort_values(by = [2000], ascending = False).iloc[:5 , 4:5]
# Out:
# Year           2000.0
# United States  2269.0
# China          1130.0
# Russia          619.0
# Japan           520.0
# India           441.0

# %%
an3.sort_values(by = [2001], ascending = False).iloc[:5 , :1]
# Out:
# Year           2001.0
# United States  2226.0
# China          1168.0
# Russia          626.0
# Japan           511.0
# India           448.0

# %%
an3.sort_values(by = [2002], ascending = False).iloc[:5 , 1:2]
# Out:
# Year           2002.0
# United States  2256.0
# China          1246.0
# Russia          623.0
# Japan           513.0
# India           462.0

# %%
an3.sort_values(by = [2003], ascending = False).iloc[:5 , 2:3]
# Out:
# Year           2003.0
# United States  2262.0
# China          1420.0
# Russia          645.0
# Japan           509.0
# India           474.0

# %%
an3.sort_values(by = [2004], ascending = False).iloc[:5 , 3:4]
# Out:
# Year           2004.0
# United States  2308.0
# China          1615.0
# Russia          647.0
# Japan           526.0
# India           500.0

# %%
an3.sort_values(by = [2005], ascending = False).iloc[:5 , 4:5]
# Out:
# Year           2005.0
# United States  2320.0
# China          1782.0
# Russia          651.0
# Japan           524.0
# India           515.0

# %%
an4.sort_values(by = [2006], ascending = False).iloc[:5 , :1]
# Out:
# Year           2006.0
# United States  2298.0
# China          1950.0
# Russia          670.0
# India           533.0
# Japan           524.0

# %%
an4.sort_values(by = [2007], ascending = False).iloc[:5 , 1:2]
# Out:
# Year           2007.0
# United States  2338.0
# China          2099.0
# Russia          672.0
# India           568.0
# Japan           519.0

# %%
an4.sort_values(by = [2008], ascending = False).iloc[:5 , 2:3]
# Out:
# Year           2008.0
# United States  2278.0
# China          2155.0
# Russia          688.0
# India           604.0
# Japan           500.0

# %%
an4.sort_values(by = [2009], ascending = False).iloc[:5 , 3:4]
# Out:
# Year           2009.0
# China          2297.0
# United States  2165.0
# India           663.0
# Russia          647.0
# Japan           477.0

# %%
an4.sort_values(by = [2010], ascending = False).iloc[:5 , 4:5]
# Out:
# Year           2010.0
# China          2536.0
# United States  2217.0
# India           701.0
# Russia          688.0
# Japan           503.0

# %%
an5.sort_values(by = [2011], ascending = False).iloc[:5 , :1]
# Out:
# Year           2011.0
# China          2723.0
# United States  2191.0
# India           734.0
# Russia          711.0
# Japan           466.0

# %%
an5.sort_values(by = [2012], ascending = False).iloc[:5 , 1:2]
# Out:
# Year           2012.0
# China          2821.0
# United States  2152.0
# India           766.0
# Russia          728.0
# Japan           456.0

# %%
an5.sort_values(by = [2013], ascending = False).iloc[:5 , 2:3]
# Out:
# Year           2013.0
# China          2912.0
# United States  2190.0
# India           779.0
# Russia          707.0
# Japan           457.0

# %%
an5.sort_values(by = [2014], ascending = False).iloc[:5 , 3:4]
# Out:
# Year           2014.0
# China          2966.0
# United States  2216.0
# India           822.0
# Russia          707.0
# Japan           442.0

# %%
an5.sort_values(by = [2015], ascending = False).iloc[:5 , 4:5]
# Out:
# Year           2015.0
# China          2994.0
# United States  2192.0
# India           835.0
# Russia          693.0
# Japan           434.0

# %%
an6.sort_values(by = [2016], ascending = False).iloc[:5 , :1]
# Out:
# Year           2016.0
# China          2977.0
# United States  2168.0
# India           852.0
# Russia          714.0
# Japan           429.0

# %%
an6.sort_values(by = [2017], ascending = False).iloc[:5 , 1:2]
# Out:
# Year           2017.0
# China          3070.0
# United States  2161.0
# India           883.0
# Russia          729.0
# Japan           434.0

# %%
an6.sort_values(by = [2018], ascending = False).iloc[:5 , 2:3]
# Out:
# Year           2018.0
# China          3201.0
# United States  2236.0
# India           919.0
# Russia          760.0
# Japan           428.0

# %%
an6.sort_values(by = [2019], ascending = False).iloc[:5 , 3:4]
# Out:
# Year           2019.0
# China          3309.0
# United States  2214.0
# India           940.0
# Russia          768.0
# Japan           416.0

# %%
an6.sort_values(by = [2020], ascending = False).iloc[:5 , 4:5]
# Out:
# Year           2020.0
# China          3381.0
# United States  2046.0
# India           908.0
# Russia          731.0
# Japan           386.0

# %% [markdown]
# Paises com o menor consumo com cada ano

# %%
an1.sort_values(by = [1990]).iloc[:5 , :1]
# Out:
# Year                  1990.0
# Kuwait                   9.0
# New Zealand             14.0
# Chile                   14.0
# Portugal                17.0
# United Arab Emirates    20.0

# %%
an1.sort_values(by = [1991]).iloc[:5 , 1:2]
# Out:
# Year         1991.0
# Kuwait          3.0
# New Zealand    14.0
# Chile          14.0
# Portugal       17.0
# Norway         22.0

# %%
an1.sort_values(by = [1992]).iloc[:5 , 2:3]
# Out:
# Year                  1992.0
# Kuwait                   9.0
# New Zealand             14.0
# Chile                   15.0
# Portugal                18.0
# United Arab Emirates    22.0

# %%
an1.sort_values(by = [1993]).iloc[:5 , 3:4]
# Out:
# Year                  1993.0
# Kuwait                  12.0
# New Zealand             15.0
# Chile                   16.0
# Portugal                18.0
# United Arab Emirates    23.0

# %%
an1.sort_values(by = [1994]).iloc[:5 , 4:5]
# Out:
# Year         1994.0
# Kuwait         14.0
# New Zealand    15.0
# Chile          17.0
# Portugal       18.0
# Algeria        23.0

# %%
an1.sort_values(by = [1995]).iloc[:5 , 5:6]
# Out:
# Year         1995.0
# Kuwait         15.0
# New Zealand    15.0
# Chile          18.0
# Portugal       20.0
# Algeria        24.0

# %%
an2.sort_values(by = [1996]).iloc[:5 , :1]
# Out:
# Year         1996.0
# Kuwait         14.0
# New Zealand    16.0
# Chile          20.0
# Portugal       20.0
# Algeria        23.0

# %%
an2.sort_values(by = [1997]).iloc[:5 , 1:2]
# Out:
# Year         1997.0
# Kuwait         15.0
# New Zealand    16.0
# Portugal       21.0
# Chile          23.0
# Algeria        24.0

# %%
an2.sort_values(by = [1998]).iloc[:5 , 2:3]
# Out:
# Year         1998.0
# New Zealand    16.0
# Kuwait         17.0
# Portugal       23.0
# Chile          24.0
# Algeria        25.0

# %%
an2.sort_values(by = [1999]).iloc[:5 , 3:4]
# Out:
# Year         1999.0
# New Zealand    17.0
# Kuwait         18.0
# Portugal       24.0
# Chile          25.0
# Colombia       26.0

# %%
an2.sort_values(by = [2000]).iloc[:5 , 4:5]
# Out:
# Year         2000.0
# New Zealand    17.0
# Kuwait         19.0
# Chile          25.0
# Portugal       25.0
# Colombia       26.0

# %%
an3.sort_values(by = [2001]).iloc[:5 , :1]
# Out:
# Year         2001.0
# New Zealand    17.0
# Kuwait         20.0
# Chile          25.0
# Portugal       25.0
# Colombia       26.0

# %%
an3.sort_values(by = [2002]).iloc[:5 , 1:2]
# Out:
# Year         2002.0
# New Zealand    17.0
# Kuwait         20.0
# Colombia       25.0
# Norway         25.0
# Chile          26.0

# %%
an3.sort_values(by = [2003]).iloc[:5 , 2:3]
# Out:
# Year         2003.0
# New Zealand    17.0
# Kuwait         21.0
# Portugal       25.0
# Colombia       26.0
# Chile          26.0

# %%
an3.sort_values(by = [2004]).iloc[:5 , 3:4]
# Out:
# Year         2004.0
# New Zealand    18.0
# Kuwait         24.0
# Colombia       26.0
# Portugal       26.0
# Norway         27.0

# %%
an3.sort_values(by = [2005]).iloc[:5 , 4:5]
# Out:
# Year         2005.0
# New Zealand    17.0
# Portugal       26.0
# Kuwait         27.0
# Norway         27.0
# Colombia       27.0

# %%
an4.sort_values(by = [2006]).iloc[:5 , :1]
# Out:
# Year         2006.0
# New Zealand    17.0
# Kuwait         25.0
# Portugal       25.0
# Norway         27.0
# Colombia       29.0

# %%
an4.sort_values(by = [2007]).iloc[:5 , 1:2]
# Out:
# Year         2007.0
# New Zealand    17.0
# Kuwait         25.0
# Portugal       25.0
# Norway         28.0
# Colombia       28.0

# %%
an4.sort_values(by = [2008]).iloc[:5 , 2:3]
# Out:
# Year         2008.0
# New Zealand    18.0
# Portugal       25.0
# Kuwait         28.0
# Colombia       30.0
# Chile          30.0

# %%
an4.sort_values(by = [2009]).iloc[:5 , 3:4]
# Out:
# Year         2009.0
# New Zealand    18.0
# Portugal       24.0
# Kuwait         29.0
# Chile          30.0
# Colombia       31.0

# %%
an4.sort_values(by = [2010]).iloc[:5 , 4:5]
# Out:
# Year         2010.0
# New Zealand    19.0
# Portugal       23.0
# Kuwait         29.0
# Colombia       30.0
# Chile          31.0

# %%
an5.sort_values(by = [2011]).iloc[:5 , :1]
# Out:
# Year         2011.0
# New Zealand    18.0
# Portugal       23.0
# Kuwait         28.0
# Norway         28.0
# Colombia       31.0

# %%
an5.sort_values(by = [2012]).iloc[:5 , 1:2]
# Out:
# Year         2012.0
# New Zealand    19.0
# Portugal       21.0
# Kuwait         29.0
# Colombia       30.0
# Norway         31.0

# %%
an5.sort_values(by = [2013]).iloc[:5 , 2:3]
# Out:
# Year         2013.0
# New Zealand    19.0
# Portugal       22.0
# Kuwait         30.0
# Romania        32.0
# Norway         33.0

# %%
an5.sort_values(by = [2014]).iloc[:5 , 3:4]
# Out:
# Year         2014.0
# New Zealand    21.0
# Portugal       21.0
# Kuwait         27.0
# Norway         29.0
# Romania        32.0

# %%
an5.sort_values(by = [2015]).iloc[:5 , 4:5]
# Out:
# Year         2015.0
# New Zealand    21.0
# Portugal       22.0
# Norway         30.0
# Romania        32.0
# Kuwait         33.0

# %%
an6.sort_values(by = [2016]).iloc[:5 , :1]
# Out:
# Year         2016.0
# New Zealand    21.0
# Portugal       22.0
# Norway         29.0
# Romania        32.0
# Kuwait         36.0

# %%
an6.sort_values(by = [2017]).iloc[:5 , 1:2]
# Out:
# Year         2017.0
# New Zealand    21.0
# Portugal       23.0
# Norway         30.0
# Romania        33.0
# Kuwait         34.0

# %%
an6.sort_values(by = [2018]).iloc[:5 , 2:3]
# Out:
# Year         2018.0
# New Zealand    20.0
# Portugal       22.0
# Norway         29.0
# Kuwait         34.0
# Romania        34.0

# %%
an6.sort_values(by = [2019]).iloc[:5 , 3:4]
# Out:
# Year         2019.0
# New Zealand    21.0
# Portugal       22.0
# Norway         28.0
# Romania        33.0
# Kuwait         36.0

# %%
an6.sort_values(by = [2020]).iloc[:5 , 4:5]
# Out:
# Year         2020.0
# Portugal       20.0
# New Zealand    21.0
# Norway         27.0
# Venezuela      29.0
# Romania        32.0
