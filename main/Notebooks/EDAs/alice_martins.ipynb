# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
e_cont = pd.read_csv('../../Energydata/Continent_Consumption_TWH.csv')
e_cont
# Out:
#     Year      World      OECD     BRICS    Europe  North America  \
# 0   1990  101855.54  52602.49  26621.07  20654.88       24667.23
# 1   1991  102483.56  53207.25  26434.99  20631.62       24841.68
# 2   1992  102588.23  53788.75  25993.05  20189.68       25341.77
# 3   1993  103646.56  54614.48  26283.80  20189.68       25830.23
# 4   1994  104449.03  55579.77  25993.05  20085.01       26365.21
# 5   1995  107112.30  56754.40  26946.71  20713.03       26714.11
# 6   1996  109763.94  58417.49  27481.69  21445.72       27295.61
# 7   1997  110903.68  59022.25  27446.80  21341.05       27574.73
# 8   1998  111450.29  59219.96  27528.21  21503.87       27772.44
# 9   1999  113974.00  60301.55  28319.05  21306.16       28528.39
# 10  2000  116590.75  61685.52  28923.81  21538.76       29342.49
# 11  2001  117521.15  61452.92  29528.57  21934.18       28795.88
# 12  2002  120207.68  61987.90  30552.01  21969.07       29156.41
# ...

# %%
e_cont = e_cont.set_index('Year')

# %% [markdown]
# # Analise do Consumo por Continente

# %% [markdown]
# 5 anos com maior consumo

# %%
df = e_cont.sort_values(by = ['World'], ascending = False)
df.iloc[:5, :1]
# Out:
#           World
# Year
# 2019  167553.41
# 2018  166297.37
# 2017  162459.47
# 2020  160819.64
# 2016  159377.52

# %%
df = e_cont.sort_values(by = ['OECD'], ascending = False)
df.iloc[:5, 1:2]
# Out:
#           OECD
# Year
# 2007  64883.77
# 2006  64616.28
# 2005  64453.46
# 2004  64058.04
# 2008  64034.78

# %%
df = e_cont.sort_values(by = ['BRICS'], ascending = False)
df.iloc[:5, 2:3]
# Out:
#          BRICS
# Year
# 2019  63255.57
# 2020  63162.53
# 2018  61673.89
# 2017  59429.30
# 2016  57742.95

# %%
df = e_cont.sort_values(by = ['Europe'], ascending = False)
df.iloc[:5, 3:4]
# Out:
#         Europe
# Year
# 2006  23108.81
# 2005  22864.58
# 2008  22829.69
# 2007  22829.69
# 2004  22748.28

# %%
df = e_cont.sort_values(by = ['North America'], ascending = False)
df.iloc[:5, 4:5]
# Out:
#       North America
# Year
# 2007       30424.08
# 2005       30168.22
# 2004       29993.77
# 2006       29958.88
# 2008       29644.87

# %%
df = e_cont.sort_values(by = ['Latin America'], ascending = False)
df.iloc[:5, 5:6]
# Out:
#       Latin America
# Year
# 2013        9978.54
# 2014        9943.65
# 2015        9873.87
# 2016        9745.94
# 2017        9687.79

# %%
df = e_cont.sort_values(by = ['Asia'], ascending = False)
df.iloc[:5, 6:7]
# Out:
#           Asia
# Year
# 2019  69582.29
# 2020  69256.65
# 2018  68035.50
# 2017  65721.13
# 2016  63941.74

# %%
df = e_cont.sort_values(by = ['Pacific'], ascending = False)
df.iloc[:5, 7:8]
# Out:
#       Pacific
# Year
# 2019  1802.65
# 2018  1791.02
# 2017  1791.02
# 2020  1767.76
# 2016  1767.76

# %%
df = e_cont.sort_values(by = ['Africa'], ascending = False)
df.iloc[:5, 8:9]
# Out:
#        Africa
# Year
# 2019  9641.27
# 2018  9559.86
# 2020  9408.67
# 2017  9304.00
# 2016  9106.29

# %%
df = e_cont.sort_values(by = ['Middle-East'], ascending = False)
df.iloc[:5, 9:10]
# Out:
#       Middle-East
# Year
# 2019      9455.19
# 2020      9338.89
# 2018      9257.48
# 2017      9210.96
# 2016      8862.06

# %%
df = e_cont.sort_values(by = ['CIS'], ascending = False)
df.iloc[:5, 10:11]
# Out:
#            CIS
# Year
# 1990  16049.40
# 1991  15898.21
# 1992  14339.79
# 1993  13246.57
# 2019  12490.62

# %% [markdown]
# 5 anos com menor consumo

# %%
df = e_cont.sort_values(by = ['World'])
df.iloc[:5, :1]
# Out:
#           World
# Year
# 1990  101855.54
# 1991  102483.56
# 1992  102588.23
# 1993  103646.56
# 1994  104449.03

# %%
df = e_cont.sort_values(by = ['OECD'])
df.iloc[:5, 1:2]
# Out:
#           OECD
# Year
# 1990  52602.49
# 1991  53207.25
# 1992  53788.75
# 1993  54614.48
# 1994  55579.77

# %%
df = e_cont.sort_values(by = ['BRICS'])
df.iloc[:5, 2:3]
# Out:
#          BRICS
# Year
# 1992  25993.05
# 1994  25993.05
# 1993  26283.80
# 1991  26434.99
# 1990  26621.07

# %%
df = e_cont.sort_values(by = ['Europe'])
df.iloc[:5, 3:4]
# Out:
#         Europe
# Year
# 2020  19643.07
# 1994  20085.01
# 1992  20189.68
# 1993  20189.68
# 1991  20631.62

# %%
df = e_cont.sort_values(by = ['North America'])
df.iloc[:5, 4:5]
# Out:
#       North America
# Year
# 1990       24667.23
# 1991       24841.68
# 1992       25341.77
# 1993       25830.23
# 1994       26365.21

# %%
df = e_cont.sort_values(by = ['Latin America'])
df.iloc[:5, 5:6]
# Out:
#       Latin America
# Year
# 1990        5373.06
# 1991        5500.99
# 1992        5628.92
# 1993        5675.44
# 1994        5989.45

# %%
df = e_cont.sort_values(by = ['Asia'])
df.iloc[:5, 6:7]
# Out:
#           Asia
# Year
# 1990  24574.19
# 1991  24783.53
# 1992  25690.67
# 1993  26876.93
# 1994  28098.08

# %%
df = e_cont.sort_values(by = ['Pacific'])
df.iloc[:5, 7:8]
# Out:
#       Pacific
# Year
# 1991  1186.26
# 1990  1197.89
# 1992  1209.52
# 1993  1267.67
# 1994  1279.30

# %%
df = e_cont.sort_values(by = ['Africa'])
df.iloc[:5, 8:9]
# Out:
#        Africa
# Year
# 1990  4407.77
# 1991  4535.70
# 1992  4582.22
# 1993  4721.78
# 1994  4803.19

# %%
df = e_cont.sort_values(by = ['Middle-East'])
df.iloc[:5, 9:10]
# Out:
#       Middle-East
# Year
# 1990      2581.86
# 1991      2744.68
# 1992      3081.95
# 1993      3349.44
# 1994      3640.19

# %%
df = e_cont.sort_values(by = ['CIS'])
df.iloc[:5, 10:11]
# Out:
#            CIS
# Year
# 1998  10152.99
# 1999  10373.96
# 1997  10373.96
# 2000  10501.89
# 2001  10571.67

# %% [markdown]
# Gráficos

# %%
e_cont.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
ax = plt.axes()
ax.plot(e_cont['World'])
ax.set(xlim=(1990, 2020), ylim=(101000, 168000),
       xlabel='anos', ylabel='consumo',
       title='Consumo Mundial ao longo dos anos');

# %%
ax = plt.axes()
ax.plot(e_cont['OECD'])
ax.set(xlim=(1990, 2020), ylim=(52000, 65000),
       xlabel='anos', ylabel='consumo',
       title='Consumo do OECD ao longo dos anos');

# %%
ax = plt.axes()
ax.plot(e_cont['BRICS'])
ax.set(xlim=(1990, 2020), ylim=(25000, 64000),
       xlabel='anos', ylabel='consumo',
       title='Consumo do BRICS ao longo dos anos');

# %%
ax = plt.axes()
ax.plot(e_cont['Europe'])
ax.set(xlim=(1990, 2020), ylim=(19000, 23500),
       xlabel='anos', ylabel='consumo',
       title='Consumo Europeu ao longo dos anos');

# %%
ax = plt.axes()
ax.plot(e_cont['North America'])
ax.set(xlim=(1990, 2020), ylim=(24000, 30500),
       xlabel='anos', ylabel='consumo',
       title='Consumo da America do Norte ao longo dos anos');

# %%
ax = plt.axes()
ax.plot(e_cont['Latin America'])
ax.set(xlim=(1990, 2020), ylim=(5000, 10000),
       xlabel='anos', ylabel='consumo',
       title='Consumo da America Latina ao longo dos anos');

# %%
ax = plt.axes()
ax.plot(e_cont['Asia'])
ax.set(xlim=(1990, 2020), ylim=(24000, 70000),
       xlabel='anos', ylabel='consumo',
       title='Consumo da Asia ao longo dos anos');

# %%
ax = plt.axes()
ax.plot(e_cont['Pacific'])
ax.set(xlim=(1990, 2020), ylim=(1000, 2000),
       xlabel='anos', ylabel='consumo',
       title='Consumo da Oceania ao longo dos anos');

# %%
ax = plt.axes()
ax.plot(e_cont['Africa'])
ax.set(xlim=(1990, 2020), ylim=(4000, 10000),
       xlabel='anos', ylabel='consumo',
       title='Consumo da Africa ao longo dos anos');

# %%
ax = plt.axes()
ax.plot(e_cont['Middle-East'])
ax.set(xlim=(1990, 2020), ylim=(2000, 10000),
       xlabel='anos', ylabel='consumo',
       title='Consumo do Oriente Médio ao longo dos anos');

# %%
ax = plt.axes()
ax.plot(e_cont['CIS'])
ax.set(xlim=(1990, 2020), ylim=(10000, 16200),
       xlabel='anos', ylabel='consumo',
       title='Consumo do CIS ao longo dos anos');

# %% [markdown]
# Os 5 continentes com menor consumo em cada ano

# %%
e_cont.pop('World')
e_cont.pop('OECD')
e_cont.pop('BRICS')
e_cont.pop('CIS')
# Out:
# Year
# 1990    16049.40
# 1991    15898.21
# 1992    14339.79
# 1993    13246.57
# 1994    11606.74
# 1995    11188.06
# 1996    10850.79
# 1997    10373.96
# 1998    10152.99
# 1999    10373.96
# 2000    10501.89
# 2001    10571.67
# 2002    10653.08
# 2003    11036.87
# 2004    11188.06
# 2005    11222.95
# 2006    11548.59
# 2007    11664.89
# 2008    11874.23
# 2009    10967.09
# 2010    11804.45
# 2011    12164.98
# 2012    12269.65
# 2013    12002.16
# 2014    11699.78
# 2015    11222.95
# 2016    11595.11
# 2017    11792.82
# 2018    12385.95
# 2019    12490.62
# 2020    11804.45
# Name: CIS, dtype: float64

# %%
dt = e_cont.T

an1 = dt.iloc[: , :6]
an2 = dt.iloc[: , 6: 11]
an3 = dt.iloc[: , 11:16]
an4 = dt.iloc[: , 16:21]
an5 = dt.iloc[: , 21:26]
an6 = dt.iloc[: , 26: ]

# %%
an1.sort_values(by = [1990]).iloc[:5, :1]
# Out:
# Year               1990
# Pacific         1197.89
# Middle-East     2581.86
# Africa          4407.77
# Latin America   5373.06
# Europe         20654.88

# %%
an1.sort_values(by = [1991]).iloc[:5, 1:2]
# Out:
# Year               1991
# Pacific         1186.26
# Middle-East     2744.68
# Africa          4535.70
# Latin America   5500.99
# Europe         20631.62

# %%
an1.sort_values(by = [1992]).iloc[:5, 2:3]
# Out:
# Year               1992
# Pacific         1209.52
# Middle-East     3081.95
# Africa          4582.22
# Latin America   5628.92
# Europe         20189.68

# %%
an1.sort_values(by = [1993]).iloc[:5, 3:4]
# Out:
# Year               1993
# Pacific         1267.67
# Middle-East     3349.44
# Africa          4721.78
# Latin America   5675.44
# Europe         20189.68

# %%
an1.sort_values(by = [1994]).iloc[:5, 4:5]
# Out:
# Year               1994
# Pacific         1279.30
# Middle-East     3640.19
# Africa          4803.19
# Latin America   5989.45
# Europe         20085.01

# %%
an1.sort_values(by = [1995]).iloc[:5, 5:6]
# Out:
# Year               1995
# Pacific         1290.93
# Middle-East     3744.86
# Africa          5000.90
# Latin America   6024.34
# Europe         20713.03

# %%
an2.sort_values(by = [1996]).iloc[:5, :1]
# Out:
# Year               1996
# Pacific         1372.34
# Middle-East     3814.64
# Africa          5152.09
# Latin America   6303.46
# Europe         21445.72

# %%
an2.sort_values(by = [1997]).iloc[:5, 1:2]
# Out:
# Year               1997
# Pacific         1407.23
# Middle-East     4058.87
# Africa          5280.02
# Latin America   6570.95
# Europe         21341.05

# %%
an2.sort_values(by = [1998]).iloc[:5, 2:3]
# Out:
# Year               1998
# Pacific         1442.12
# Middle-East     4082.13
# Africa          5431.21
# Latin America   6803.55
# Europe         21503.87

# %%
an2.sort_values(by = [1999]).iloc[:5, 3:4]
# Out:
# Year               1999
# Pacific         1477.01
# Middle-East     4244.95
# Africa          5559.14
# Latin America   6989.63
# Europe         21306.16

# %%
an2.sort_values(by = [2000]).iloc[:5, 4:5]
# Out:
# Year               2000
# Pacific         1500.27
# Middle-East     4314.73
# Africa          5617.29
# Latin America   7024.52
# Europe         21538.76

# %%
an3.sort_values(by = [2001]).iloc[:5, :1]
# Out:
# Year               2001
# Pacific         1477.01
# Middle-East     4663.63
# Africa          5756.85
# Latin America   7036.15
# Europe         21934.18

# %%
an3.sort_values(by = [2002]).iloc[:5, 1:2]
# Out:
# Year               2002
# Pacific         1523.53
# Middle-East     4884.60
# Africa          5849.89
# Latin America   7280.38
# Europe         21969.07

# %%
an3.sort_values(by = [2003]).iloc[:5, 2:3]
# Out:
# Year               2003
# Pacific         1535.16
# Middle-East     4954.38
# Africa          6140.64
# Latin America   7501.35
# Europe         22515.68

# %%
an3.sort_values(by = [2004]).iloc[:5, 3:4]
# Out:
# Year               2004
# Pacific         1558.42
# Middle-East     5245.13
# Africa          6466.28
# Latin America   7780.47
# Europe         22748.28

# %%
an3.sort_values(by = [2005]).iloc[:5, 4:5]
# Out:
# Year               2005
# Pacific         1570.05
# Middle-East     5675.44
# Africa          6652.36
# Latin America   8059.59
# Europe         22864.58

# %%
an4.sort_values(by = [2006]).iloc[:5, :1]
# Out:
# Year               2006
# Pacific         1616.57
# Middle-East     5989.45
# Africa          6861.70
# Latin America   8303.82
# Europe         23108.81

# %%
an4.sort_values(by = [2007]).iloc[:5, 1:2]
# Out:
# Year               2007
# Pacific         1663.09
# Middle-East     6315.09
# Africa          7129.19
# Latin America   8571.31
# Europe         22829.69

# %%
an4.sort_values(by = [2008]).iloc[:5, 2:3]
# Out:
# Year               2008
# Pacific         1721.24
# Middle-East     6850.07
# Africa          7443.20
# Latin America   8780.65
# Europe         22829.69

# %%
an4.sort_values(by = [2009]).iloc[:5, 3:4]
# Out:
# Year               2009
# Pacific         1721.24
# Middle-East     7059.41
# Africa          7606.02
# Latin America   8559.68
# Europe         21608.54

# %%
an4.sort_values(by = [2010]).iloc[:5, 4:5]
# Out:
# Year               2010
# Pacific         1732.87
# Middle-East     7361.79
# Africa          7803.73
# Latin America   9117.92
# Europe         22469.16

# %%
an5.sort_values(by = [2011]).iloc[:5, :1]
# Out:
# Year               2011
# Pacific         1744.50
# Middle-East     7524.61
# Africa          8117.74
# Latin America   9304.00
# Europe         21794.62

# %%
an5.sort_values(by = [2012]).iloc[:5, 1:2]
# Out:
# Year               2012
# Pacific         1744.50
# Middle-East     7943.29
# Africa          8303.82
# Latin America   9594.75
# Europe         21689.95

# %%
an5.sort_values(by = [2013]).iloc[:5, 2:3]
# Out:
# Year               2013
# Pacific         1767.76
# Middle-East     8071.22
# Africa          8431.75
# Latin America   9978.54
# Europe         21480.61

# %%
an5.sort_values(by = [2014]).iloc[:5, 3:4]
# Out:
# Year               2014
# Pacific         1767.76
# Middle-East     8513.16
# Africa          8896.95
# Latin America   9943.65
# Europe         20689.77

# %%
an5.sort_values(by = [2014]).iloc[:5, 4:5]
# Out:
# Year               2015
# Pacific         1767.76
# Middle-East     8675.98
# Africa          8838.80
# Latin America   9873.87
# Europe         21038.67

# %%
an6.sort_values(by = [2016]).iloc[:5, :1]
# Out:
# Year               2016
# Pacific         1767.76
# Middle-East     8862.06
# Africa          9106.29
# Latin America   9745.94
# Europe         21224.75

# %%
an6.sort_values(by = [2017]).iloc[:5, 1:2]
# Out:
# Year               2017
# Pacific         1791.02
# Middle-East     9210.96
# Africa          9304.00
# Latin America   9687.79
# Europe         21620.17

# %%
an6.sort_values(by = [2018]).iloc[:5, 2:3]
# Out:
# Year               2018
# Pacific         1791.02
# Middle-East     9257.48
# Latin America   9513.34
# Africa          9559.86
# Europe         21399.20

# %%
an6.sort_values(by = [2019]).iloc[:5, 3:4]
# Out:
# Year               2019
# Pacific         1802.65
# Middle-East     9455.19
# Latin America   9478.45
# Africa          9641.27
# Europe         21061.93

# %%
an6.sort_values(by = [2020]).iloc[:5, 4:5]
# Out:
# Year               2020
# Pacific         1767.76
# Latin America   8815.54
# Middle-East     9338.89
# Africa          9408.67
# Europe         19643.07

# %% [markdown]
# Os 5 continente com maior consumo em cada ano

# %%
an1.sort_values(by = [1990],ascending = False).iloc[:5, :1]
# Out:
# Year               1990
# North America  24667.23
# Asia           24574.19
# Europe         20654.88
# Latin America   5373.06
# Africa          4407.77

# %%
an1.sort_values(by = [1991],ascending = False).iloc[:5, 1:2]
# Out:
# Year               1991
# North America  24841.68
# Asia           24783.53
# Europe         20631.62
# Latin America   5500.99
# Africa          4535.70

# %%
an1.sort_values(by = [1992],ascending = False).iloc[:5, 2:3]
# Out:
# Year               1992
# Asia           25690.67
# North America  25341.77
# Europe         20189.68
# Latin America   5628.92
# Africa          4582.22

# %%
an1.sort_values(by = [1993],ascending = False).iloc[:5, 3:4]
# Out:
# Year               1993
# Asia           26876.93
# North America  25830.23
# Europe         20189.68
# Latin America   5675.44
# Africa          4721.78

# %%
an1.sort_values(by = [1994],ascending = False).iloc[:5, 4:5]
# Out:
# Year               1994
# Asia           28098.08
# North America  26365.21
# Europe         20085.01
# Latin America   5989.45
# Africa          4803.19

# %%
an1.sort_values(by = [1995],ascending = False).iloc[:5, 5:6]
# Out:
# Year               1995
# Asia           29761.17
# North America  26714.11
# Europe         20713.03
# Latin America   6024.34
# Africa          5000.90

# %%
an2.sort_values(by = [1996],ascending = False).iloc[:5, :1]
# Out:
# Year               1996
# Asia           30772.98
# North America  27295.61
# Europe         21445.72
# Latin America   6303.46
# Africa          5152.09

# %%
an2.sort_values(by = [1997],ascending = False).iloc[:5, 1:2]
# Out:
# Year               1997
# Asia           31435.89
# North America  27574.73
# Europe         21341.05
# Latin America   6570.95
# Africa          5280.02

# %%
an2.sort_values(by = [1998],ascending = False).iloc[:5, 2:3]
# Out:
# Year               1998
# Asia           31331.22
# North America  27772.44
# Europe         21503.87
# Latin America   6803.55
# Africa          5431.21

# %%
an2.sort_values(by = [1999],ascending = False).iloc[:5, 3:4]
# Out:
# Year               1999
# Asia           32412.81
# North America  28528.39
# Europe         21306.16
# Latin America   6989.63
# Africa          5559.14

# %%
an2.sort_values(by = [2000],ascending = False).iloc[:5, 4:5]
# Out:
# Year               2000
# Asia           33564.18
# North America  29342.49
# Europe         21538.76
# Latin America   7024.52
# Africa          5617.29

# %%
an3.sort_values(by = [2001],ascending = False).iloc[:5, :1]
# Out:
# Year               2001
# Asia           34227.09
# North America  28795.88
# Europe         21934.18
# Latin America   7036.15
# Africa          5756.85

# %%
an3.sort_values(by = [2002],ascending = False).iloc[:5, 1:2]
# Out:
# Year               2002
# Asia           35680.84
# North America  29156.41
# Europe         21969.07
# Latin America   7280.38
# Africa          5849.89

# %%
an3.sort_values(by = [2003],ascending = False).iloc[:5, 2:3]
# Out:
# Year               2003
# Asia           38181.29
# North America  29377.38
# Europe         22515.68
# Latin America   7501.35
# Africa          6140.64

# %%
an3.sort_values(by = [2004],ascending = False).iloc[:5, 3:4]
# Out:
# Year               2004
# Asia           41437.69
# North America  29993.77
# Europe         22748.28
# Latin America   7780.47
# Africa          6466.28

# %%
an3.sort_values(by = [2005],ascending = False).iloc[:5, 4:5]
# Out:
# Year               2005
# Asia           43693.91
# North America  30168.22
# Europe         22864.58
# Latin America   8059.59
# Africa          6652.36

# %%
an4.sort_values(by = [2006],ascending = False).iloc[:5, :1]
# Out:
# Year               2006
# Asia           46124.58
# North America  29958.88
# Europe         23108.81
# Latin America   8303.82
# Africa          6861.70

# %%
an4.sort_values(by = [2007],ascending = False).iloc[:5, 1:2]
# Out:
# Year               2007
# Asia           48555.25
# North America  30424.08
# Europe         22829.69
# Latin America   8571.31
# Africa          7129.19

# %%
an4.sort_values(by = [2008],ascending = False).iloc[:5, 2:3]
# Out:
# Year               2008
# Asia           49636.84
# North America  29644.87
# Europe         22829.69
# Latin America   8780.65
# Africa          7443.20

# %%
an4.sort_values(by = [2009],ascending = False).iloc[:5, 3:4]
# Out:
# Year               2009
# Asia           51858.17
# North America  28214.38
# Europe         21608.54
# Latin America   8559.68
# Africa          7606.02

# %%
an4.sort_values(by = [2010],ascending = False).iloc[:5, 4:5]
# Out:
# Year               2010
# Asia           56010.08
# North America  28830.77
# Europe         22469.16
# Latin America   9117.92
# Africa          7803.73

# %%
an5.sort_values(by = [2011],ascending = False).iloc[:5, :1]
# Out:
# Year               2011
# Asia           58324.45
# North America  28598.17
# Europe         21794.62
# Latin America   9304.00
# Africa          8117.74

# %%
an5.sort_values(by = [2012],ascending = False).iloc[:5, 1:2]
# Out:
# Year               2012
# Asia           60022.43
# North America  28167.86
# Europe         21689.95
# Latin America   9594.75
# Africa          8303.82

# %%
an5.sort_values(by = [2013],ascending = False).iloc[:5, 2:3]
# Out:
# Year               2013
# Asia           61499.44
# North America  28667.95
# Europe         21480.61
# Latin America   9978.54
# Africa          8431.75

# %%
an5.sort_values(by = [2014],ascending = False).iloc[:5, 3:4]
# Out:
# Year               2014
# Asia           62895.04
# North America  29063.37
# Europe         20689.77
# Latin America   9943.65
# Africa          8896.95

# %%
an5.sort_values(by = [2015],ascending = False).iloc[:5, 4:5]
# Out:
# Year               2015
# Asia           63476.54
# North America  28784.25
# Europe         21038.67
# Latin America   9873.87
# Africa          8838.80

# %%
an6.sort_values(by = [2016],ascending = False).iloc[:5, :1]
# Out:
# Year               2016
# Asia           63941.74
# North America  28563.28
# Europe         21224.75
# Latin America   9745.94
# Africa          9106.29

# %%
an6.sort_values(by = [2017],ascending = False).iloc[:5, 1:2]
# Out:
# Year               2017
# Asia           65721.13
# North America  28563.28
# Europe         21620.17
# Latin America   9687.79
# Africa          9304.00

# %%
an6.sort_values(by = [2018],ascending = False).iloc[:5, 2:3]
# Out:
# Year               2018
# Asia           68035.50
# North America  29470.42
# Europe         21399.20
# Africa          9559.86
# Latin America   9513.34

# %%
an6.sort_values(by = [2019],ascending = False).iloc[:5, 3:4]
# Out:
# Year               2019
# Asia           69582.29
# North America  29249.45
# Europe         21061.93
# Africa          9641.27
# Latin America   9478.45

# %%
an6.sort_values(by = [2020],ascending = False).iloc[:5, 4:5]
# Out:
# Year               2020
# Asia           69256.65
# North America  27063.01
# Europe         19643.07
# Africa          9408.67
# Middle-East     9338.89

# %% [markdown]
# Gráficos

# %%
plt.style.use('fivethirtyeight')
an1.plot()
# Out:
# <AxesSubplot:>

# %%
plt.style.use('fivethirtyeight')
an1.iloc[:5, :1].plot()
# Out:
# <AxesSubplot:>

# %%
plt.style.use('fivethirtyeight')
an1.iloc[:5, 1:2].plot()
# Out:
# <AxesSubplot:>

# %%
plt.style.use('fivethirtyeight')
an1.iloc[:5, 2:3].plot()
# Out:
# <AxesSubplot:>

# %%
plt.style.use('fivethirtyeight')
an1.iloc[:5, 3:4].plot()
# Out:
# <AxesSubplot:>

# %%
plt.style.use('fivethirtyeight')
an1.iloc[:5, 4:5].plot()
# Out:
# <AxesSubplot:>

# %%
plt.style.use('fivethirtyeight')
an1.iloc[:5, 5:6].plot()
# Out:
# <AxesSubplot:>

# %%
plt.style.use('fivethirtyeight')
an2.iloc[:5, :1].plot()
# Out:
# <AxesSubplot:>

# %%
plt.style.use('fivethirtyeight')
an2.iloc[:5, 1:2].plot()
# Out:
# <AxesSubplot:>

# %%
plt.style.use('fivethirtyeight')
an2.iloc[:5, 2:3].plot()
# Out:
# <AxesSubplot:>

# %%
plt.style.use('fivethirtyeight')
an2.iloc[:5, 3:4].plot()
# Out:
# <AxesSubplot:>

# %%
plt.style.use('fivethirtyeight')
an2.iloc[:5, 4:5].plot()
# Out:
# <AxesSubplot:>

# %%
an2.plot()
# Out:
# <AxesSubplot:>

# %%
an3.iloc[:5, :1].plot()
# Out:
# <AxesSubplot:>

# %%
an3.iloc[:5, 1:2].plot()
# Out:
# <AxesSubplot:>

# %%
an3.iloc[:5, 2:3].plot()
# Out:
# <AxesSubplot:>

# %%
an3.iloc[:5, 3:4].plot()
# Out:
# <AxesSubplot:>

# %%
an3.iloc[:5, 4:5].plot()
# Out:
# <AxesSubplot:>

# %%
an3.plot()
# Out:
# <AxesSubplot:>

# %%
an4.iloc[:5, :1].plot()
# Out:
# <AxesSubplot:>

# %%
an4.iloc[:5, 1:2].plot()
# Out:
# <AxesSubplot:>

# %%
an4.iloc[:5, 2:3].plot()
# Out:
# <AxesSubplot:>

# %%
an4.iloc[:5, 3:4].plot()
# Out:
# <AxesSubplot:>

# %%
an4.iloc[:5, 4:5].plot()
# Out:
# <AxesSubplot:>

# %%
an4.plot()
# Out:
# <AxesSubplot:>

# %%
an5.iloc[:5, :1].plot()
# Out:
# <AxesSubplot:>

# %%
an5.iloc[:5, 1:2].plot()
# Out:
# <AxesSubplot:>

# %%
an5.iloc[:5, 2:3].plot()
# Out:
# <AxesSubplot:>

# %%
an5.iloc[:5, 3:4].plot()
# Out:
# <AxesSubplot:>

# %%
an5.iloc[:5, 4:5].plot()
# Out:
# <AxesSubplot:>

# %%
an5.plot()
# Out:
# <AxesSubplot:>

# %%
an6.iloc[:5, :1].plot()
# Out:
# <AxesSubplot:>

# %%
an6.iloc[:5, 1:2].plot()
# Out:
# <AxesSubplot:>

# %%
an6.iloc[:5, 2:3].plot()
# Out:
# <AxesSubplot:>

# %%
an6.iloc[:5, 3:4].plot()
# Out:
# <AxesSubplot:>

# %%
an6.iloc[:5, 4:5].plot()
# Out:
# <AxesSubplot:>

# %%
an6.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Analise do Consumo por país

# %%
e_pais = pd.read_csv("../../Energydata/Country_Consumption_TWH.csv")
e_pais
# Out:
#       Year   China  United States  Brazil  Belgium  Czechia  France  Germany  \
# 0   1990.0   874.0         1910.0   141.0     48.0     50.0   225.0    351.0
# 1   1991.0   848.0         1925.0   143.0     50.0     45.0   237.0    344.0
# 2   1992.0   877.0         1964.0   145.0     51.0     44.0   234.0    338.0
# 3   1993.0   929.0         1998.0   148.0     49.0     43.0   238.0    335.0
# 4   1994.0   973.0         2036.0   156.0     52.0     41.0   231.0    333.0
# 5   1995.0  1045.0         2063.0   162.0     53.0     42.0   240.0    336.0
# 6   1996.0  1074.0         2108.0   170.0     56.0     43.0   251.0    348.0
# 7   1997.0  1073.0         2130.0   179.0     56.0     43.0   244.0    345.0
# 8   1998.0  1079.0         2148.0   183.0     57.0     42.0   252.0    343.0
# 9   1999.0  1099.0         2206.0   187.0     57.0     39.0   252.0    335.0
# 10  2000.0  1130.0         2269.0   188.0     58.0     41.0   255.0    337.0
# ...

# %%
e_pais = e_pais.set_index('Year')

# %% [markdown]
# 5 anos de maior consumo em cada país

# %%
df = e_pais.sort_values(by = ['China'],ascending = False)
df.iloc[ :5, :1]
# Out:
#          China
# Year
# 2020.0  3381.0
# 2019.0  3309.0
# 2018.0  3201.0
# 2017.0  3070.0
# 2015.0  2994.0

# %%
dt = df.sort_values(by = ['United States'],ascending = False)
dt.iloc[ :5, 1:2]
# Out:
#         United States
# Year
# 2007.0         2338.0
# 2005.0         2320.0
# 2004.0         2308.0
# 2006.0         2298.0
# 2008.0         2278.0

# %%
df = e_pais.sort_values(by = ['Brazil'],ascending = False)
df.iloc[ :5, 2:3]
# Out:
#         Brazil
# Year
# 2014.0   303.0
# 2015.0   297.0
# 2013.0   294.0
# 2019.0   293.0
# 2017.0   292.0

# %%
df = e_pais.sort_values(by = ['Belgium'],ascending = False)
df.iloc[ :5, 3:4]
# Out:
#         Belgium
# Year
# 2010.0     60.0
# 2005.0     58.0
# 2000.0     58.0
# 2008.0     58.0
# 2004.0     58.0

# %%
df = e_pais.sort_values(by = ['Czechia'],ascending = False)
df.iloc[ :5, 4:5]
# Out:
#         Czechia
# Year
# 1990.0     50.0
# 2007.0     46.0
# 2006.0     46.0
# 2004.0     46.0
# 2003.0     45.0

# %%
df = e_pais.sort_values(by = ['France'],ascending = False)
df.iloc[ :5, 5:6]
# Out:
#         France
# Year
# 2005.0   273.0
# 2004.0   271.0
# 2006.0   268.0
# 2003.0   268.0
# 2008.0   266.0

# %%
df = e_pais.sort_values(by = ['Germany'],ascending = False)
df.iloc[ :5, 6:7]
# Out:
#         Germany
# Year
# 1990.0    351.0
# 2006.0    349.0
# 1996.0    348.0
# 2001.0    347.0
# 1997.0    345.0

# %%
df = e_pais.sort_values(by = ['Italy'],ascending = False)
df.iloc[ :5, 7:8]
# Out:
#         Italy
# Year
# 2005.0  187.0
# 2006.0  185.0
# 2007.0  184.0
# 2004.0  183.0
# 2008.0  182.0

# %%
df = e_pais.sort_values(by = ['Netherlands'],ascending = False)
df.iloc[ :5, 8:9]
# Out:
#         Netherlands
# Year
# 2010.0         83.0
# 2004.0         81.0
# 2005.0         80.0
# 2003.0         80.0
# 2007.0         79.0

# %%
df = e_pais.sort_values(by = ['Poland'],ascending = False)
df.iloc[ :5, 9:10]
# Out:
#         Poland
# Year
# 2018.0   106.0
# 2017.0   104.0
# 1996.0   104.0
# 2019.0   103.0
# 1990.0   103.0

# %%
dt = df.sort_values(by = ['Portugal'],ascending = False)
dt.iloc[ :5, 10:11]
# Out:
#         Portugal
# Year
# 2002.0      26.0
# 2004.0      26.0
# 2005.0      26.0
# 2008.0      25.0
# 2007.0      25.0

# %%
df = e_pais.sort_values(by = ['Romania'],ascending = False)
df.iloc[ :5, 11:12]
# Out:
#         Romania
# Year
# 1990.0     62.0
# 1991.0     51.0
# 1996.0     48.0
# 1995.0     47.0
# 1992.0     46.0

# %%
df = e_pais.sort_values(by = ['Spain'],ascending = False)
df.iloc[ :5, 12:13]
# Out:
#         Spain
# Year
# 2007.0  143.0
# 2005.0  142.0
# 2006.0  141.0
# 2008.0  139.0
# 2004.0  139.0

# %%
df = e_pais.sort_values(by = ['Sweden'],ascending = False)
df.iloc[ :5, 13:14]
# Out:
#         Sweden
# Year
# 2004.0    53.0
# 2005.0    52.0
# 2002.0    52.0
# 2010.0    51.0
# 1996.0    51.0

# %%
df = e_pais.sort_values(by = ['United Kingdom'],ascending = False)
df.iloc[ :5, 14:15]
# Out:
#         United Kingdom
# Year
# 1996.0           226.0
# 2003.0           224.0
# 2001.0           224.0
# 2005.0           223.0
# 2000.0           223.0

# %%
df = e_pais.sort_values(by = ['Norway'],ascending = False)
df.iloc[ :5, 15:16]
# Out:
#         Norway
# Year
# 2013.0    33.0
# 2010.0    33.0
# 2009.0    32.0
# 2008.0    32.0
# 2012.0    31.0

# %%
df = e_pais.sort_values(by = ['Turkey'],ascending = False)
df.iloc[ :5, 16:17]
# Out:
#         Turkey
# Year
# 2017.0   147.0
# 2019.0   145.0
# 2018.0   144.0
# 2020.0   141.0
# 2016.0   137.0

# %%
df = e_pais.sort_values(by = ['Kazakhstan'],ascending = False)
df.iloc[ :5, 17:18]
# Out:
#         Kazakhstan
# Year
# 2013.0        82.0
# 1992.0        79.0
# 2019.0        77.0
# 2011.0        77.0
# 2018.0        76.0

# %%
df = e_pais.sort_values(by = ['Russia'],ascending = False)
df.iloc[ :5, 18:19]
# Out:
#         Russia
# Year
# 1990.0   879.0
# 1991.0   871.0
# 1992.0   795.0
# 2019.0   768.0
# 2018.0   760.0

# %%
df = e_pais.sort_values(by = ['Ukraine'],ascending = False)
df.iloc[ :5, 19:20]
# Out:
#         Ukraine
# Year
# 1990.0    252.0
# 1991.0    252.0
# 1992.0    220.0
# 1993.0    195.0
# 1994.0    166.0

# %%
df = e_pais.sort_values(by = ['Uzbekistan'],ascending = False)
df.iloc[ :5, 20:21]
# Out:
#         Uzbekistan
# Year
# 2002.0        53.0
# 2004.0        51.0
# 2000.0        51.0
# 2001.0        51.0
# 2003.0        51.0

# %%
df = e_pais.sort_values(by = ['Argentina'],ascending = False)
df.iloc[ :5, 21:22]
# Out:
#         Argentina
# Year
# 2015.0       83.0
# 2017.0       82.0
# 2016.0       82.0
# 2014.0       82.0
# 2013.0       82.0

# %%
df = e_pais.sort_values(by = ['Canada'],ascending = False)
df.iloc[ :5, 22:23]
# Out:
#         Canada
# Year
# 2019.0   301.0
# 2018.0   298.0
# 2017.0   295.0
# 2016.0   287.0
# 2015.0   283.0

# %%
df = e_pais.sort_values(by = ['Chile'],ascending = False)
df.iloc[ :5, 23:24]
# Out:
#         Chile
# Year
# 2019.0   40.0
# 2018.0   39.0
# 2020.0   38.0
# 2017.0   38.0
# 2016.0   38.0

# %%
df = e_pais.sort_values(by = ['Colombia'],ascending = False)
df.iloc[ :5, 24:25]
# Out:
#         Colombia
# Year
# 2016.0      42.0
# 2015.0      41.0
# 2019.0      41.0
# 2013.0      40.0
# 2017.0      40.0

# %%
df = e_pais.sort_values(by = ['Mexico'],ascending = False)
df.iloc[ :5, 25:26]
# Out:
#         Mexico
# Year
# 2012.0   192.0
# 2013.0   192.0
# 2014.0   188.0
# 2011.0   187.0
# 2016.0   185.0

# %%
df = e_pais.sort_values(by = ['Venezuela'],ascending = False)
df.iloc[ :5, 26:27]
# Out:
#         Venezuela
# Year
# 2013.0       76.0
# 2010.0       75.0
# 2012.0       69.0
# 2011.0       67.0
# 2002.0       67.0

# %%
df = e_pais.sort_values(by = ['Indonesia'],ascending = False)
df.iloc[ :5, 27:28]
# Out:
#         Indonesia
# Year
# 2019.0      237.0
# 2018.0      231.0
# 2020.0      225.0
# 2017.0      222.0
# 2016.0      209.0

# %%
df = e_pais.sort_values(by = ['Japan'],ascending = False)
df.iloc[ :5, 28:29]
# Out:
#         Japan
# Year
# 2004.0  526.0
# 2005.0  524.0
# 2006.0  524.0
# 2000.0  520.0
# 2007.0  519.0

# %%
df = e_pais.sort_values(by = ['Malaysia'],ascending = False)
df.iloc[ :5, 29:30]
# Out:
#         Malaysia
# Year
# 2019.0      96.0
# 2018.0      94.0
# 2014.0      89.0
# 2020.0      88.0
# 2016.0      88.0

# %%
df = e_pais.sort_values(by = ['South Korea'],ascending = False)
df.iloc[ :5, 30:31]
# Out:
#         South Korea
# Year
# 2018.0        296.0
# 2017.0        295.0
# 2019.0        293.0
# 2016.0        293.0
# 2020.0        283.0

# %%
df = e_pais.sort_values(by = ['Taiwan'],ascending = False)
df.iloc[ :5, 31:32]
# Out:
#         Taiwan
# Year
# 2018.0   110.0
# 2016.0   109.0
# 2014.0   109.0
# 2019.0   108.0
# 2017.0   107.0

# %%
df = e_pais.sort_values(by = ['Thailand'],ascending = False)
df.iloc[ :5, 32:33]
# Out:
#         Thailand
# Year
# 2017.0     139.0
# 2016.0     139.0
# 2019.0     137.0
# 2018.0     136.0
# 2015.0     136.0

# %%
df = e_pais.sort_values(by = ['India'],ascending = False)
df.iloc[ :5, 33:34]
# Out:
#         India
# Year
# 2019.0  940.0
# 2018.0  919.0
# 2020.0  908.0
# 2017.0  883.0
# 2016.0  852.0

# %%
df = e_pais.sort_values(by = ['Australia'],ascending = False)
df.iloc[ :5, 34:35]
# Out:
#         Australia
# Year
# 2019.0      129.0
# 2018.0      128.0
# 2017.0      128.0
# 2016.0      127.0
# 2015.0      127.0

# %%
df = e_pais.sort_values(by = ['New Zealand'],ascending = False)
df.iloc[ :5, 35:36]
# Out:
#         New Zealand
# Year
# 2020.0         21.0
# 2019.0         21.0
# 2017.0         21.0
# 2016.0         21.0
# 2015.0         21.0

# %%
df = e_pais.sort_values(by = ['Algeria'],ascending = False)
df.iloc[ :5, 36:37]
# Out:
#         Algeria
# Year
# 2019.0     65.0
# 2018.0     61.0
# 2020.0     59.0
# 2017.0     57.0
# 2016.0     56.0

# %%
df = e_pais.sort_values(by = ['Egypt'],ascending = False)
df.iloc[ :5, 37:38]
# Out:
#         Egypt
# Year
# 2019.0   97.0
# 2018.0   96.0
# 2017.0   93.0
# 2020.0   92.0
# 2016.0   88.0

# %%
df = e_pais.sort_values(by = ['Nigeria'],ascending = False)
df.iloc[ :5, 38:39]
# Out:
#         Nigeria
# Year
# 2018.0    160.0
# 2020.0    159.0
# 2019.0    157.0
# 2017.0    152.0
# 2016.0    150.0

# %%
df = e_pais.sort_values(by = ['South Africa'],ascending = False)
df.iloc[ :5, 39:40]
# Out:
#         South Africa
# Year
# 2009.0         144.0
# 2008.0         142.0
# 2014.0         138.0
# 2011.0         137.0
# 2017.0         136.0

# %%
df = e_pais.sort_values(by = ['Iran'],ascending = False)
df.iloc[ :5, 40:41]
# Out:
#          Iran
# Year
# 2019.0  269.0
# 2020.0  268.0
# 2018.0  266.0
# 2017.0  262.0
# 2016.0  246.0

# %%
df = e_pais.sort_values(by = ['Kuwait'],ascending = False)
df.iloc[ :5, 41:42]
# Out:
#         Kuwait
# Year
# 2020.0    38.0
# 2019.0    36.0
# 2016.0    36.0
# 2018.0    34.0
# 2017.0    34.0

# %%
df = e_pais.sort_values(by = ['Saudi Arabia'],ascending = False)
df.iloc[ :5, 42:43]
# Out:
#         Saudi Arabia
# Year
# 2017.0         219.0
# 2015.0         216.0
# 2019.0         215.0
# 2016.0         215.0
# 2018.0         214.0

# %%
df = e_pais.sort_values(by = ['United Arab Emirates'],ascending = False)
df.iloc[ :5, 43:44]
# Out:
#         United Arab Emirates
# Year
# 2019.0                  83.0
# 2020.0                  81.0
# 2016.0                  79.0
# 2018.0                  78.0
# 2017.0                  78.0

# %% [markdown]
# 5 anos de menor consumo em cada país

# %%
df = e_pais.sort_values(by = ['China'])
df.iloc[ :5, :1]
# Out:
#         China
# Year
# 1991.0  848.0
# 1990.0  874.0
# 1992.0  877.0
# 1993.0  929.0
# 1994.0  973.0

# %%
df = e_pais.sort_values(by = ['United States'])
df.iloc[ :5, 1:2]
# Out:
#         United States
# Year
# 1990.0         1910.0
# 1991.0         1925.0
# 1992.0         1964.0
# 1993.0         1998.0
# 1994.0         2036.0

# %%
df = e_pais.sort_values(by = ['Brazil'])
df.iloc[ :5, 2:3]
# Out:
#         Brazil
# Year
# 1990.0   141.0
# 1991.0   143.0
# 1992.0   145.0
# 1993.0   148.0
# 1994.0   156.0

# %%
df = e_pais.sort_values(by = ['Belgium'])
df.iloc[ :5, 3:4]
# Out:
#         Belgium
# Year
# 1990.0     48.0
# 1993.0     49.0
# 1991.0     50.0
# 2020.0     51.0
# 1992.0     51.0

# %%
df = e_pais.sort_values(by = ['Czechia'])
df.iloc[ :5, 4:5]
# Out:
#         Czechia
# Year
# 2020.0     39.0
# 1999.0     39.0
# 2016.0     41.0
# 1994.0     41.0
# 2000.0     41.0

# %%
df = e_pais.sort_values(by = ['France'])
df.iloc[ :5, 5:6]
# Out:
#         France
# Year
# 2020.0   217.0
# 1990.0   225.0
# 1994.0   231.0
# 1992.0   234.0
# 1991.0   237.0

# %%
df = e_pais.sort_values(by = ['Germany'])
df.iloc[ :5, 6:7]
# Out:
#         Germany
# Year
# 2020.0    275.0
# 2019.0    294.0
# 2018.0    302.0
# 2014.0    307.0
# 2015.0    309.0

# %%
df = e_pais.sort_values(by = ['Italy'])
df.iloc[ :5, 7:8]
# Out:
#         Italy
# Year
# 2020.0  137.0
# 2014.0  147.0
# 1994.0  147.0
# 1990.0  147.0
# 1992.0  149.0

# %%
df = e_pais.sort_values(by = ['Netherlands'])
df.iloc[ :5, 8:9]
# Out:
#         Netherlands
# Year
# 1990.0         67.0
# 1991.0         69.0
# 1992.0         69.0
# 1994.0         70.0
# 2020.0         70.0

# %%
df = e_pais.sort_values(by = ['Poland'])
df.iloc[ :5, 9:10]
# Out:
#         Poland
# Year
# 2000.0    89.0
# 2002.0    89.0
# 2001.0    90.0
# 2004.0    91.0
# 2003.0    91.0

# %%
df = e_pais.sort_values(by = ['Portugal'])
df.iloc[ :5, 10:11]
# Out:
#         Portugal
# Year
# 1990.0      17.0
# 1991.0      17.0
# 1992.0      18.0
# 1993.0      18.0
# 1994.0      18.0

# %%
df = e_pais.sort_values(by = ['Romania'])
df.iloc[ :5, 11:12]
# Out:
#         Romania
# Year
# 2020.0     32.0
# 2016.0     32.0
# 2015.0     32.0
# 2014.0     32.0
# 2013.0     32.0

# %%
df = e_pais.sort_values(by = ['Spain'])
df.iloc[ :5, 12:13]
# Out:
#         Spain
# Year
# 1990.0   90.0
# 1993.0   91.0
# 1991.0   93.0
# 1992.0   95.0
# 1994.0   96.0

# %%
df = e_pais.sort_values(by = ['Sweden'])
df.iloc[ :5, 13:14]
# Out:
#         Sweden
# Year
# 2015.0    44.0
# 2009.0    45.0
# 1993.0    46.0
# 1990.0    47.0
# 2020.0    47.0

# %%
df = e_pais.sort_values(by = ['United Kingdom'])
df.iloc[ :5, 14:15]
# Out:
#         United Kingdom
# Year
# 2020.0           154.0
# 2019.0           170.0
# 2018.0           175.0
# 2017.0           176.0
# 2016.0           179.0

# %%
df = e_pais.sort_values(by = ['Norway'])
df.iloc[ :5, 15:16]
# Out:
#         Norway
# Year
# 1990.0    21.0
# 1991.0    22.0
# 1992.0    22.0
# 1994.0    23.0
# 1996.0    23.0

# %%
df = e_pais.sort_values(by = ['Turkey'])
df.iloc[ :5, 16:17]
# Out:
#         Turkey
# Year
# 1990.0    51.0
# 1991.0    51.0
# 1992.0    53.0
# 1993.0    56.0
# 1994.0    56.0

# %%
df = e_pais.sort_values(by = ['Kazakhstan'])
df.iloc[ :5, 17:18]
# Out:
#         Kazakhstan
# Year
# 2001.0        35.0
# 2000.0        36.0
# 1999.0        36.0
# 1997.0        39.0
# 1998.0        39.0

# %%
df = e_pais.sort_values(by = ['Russia'])
df.iloc[ :5, 18:19]
# Out:
#         Russia
# Year
# 1998.0   588.0
# 1997.0   602.0
# 1999.0   609.0
# 2000.0   619.0
# 2002.0   623.0

# %%
df = e_pais.sort_values(by = ['Ukraine'])
df.iloc[ :5, 19:20]
# Out:
#         Ukraine
# Year
# 2020.0     86.0
# 2017.0     89.0
# 2019.0     89.0
# 2016.0     92.0
# 2018.0     93.0

# %%
df = e_pais.sort_values(by = ['Uzbekistan'])
df.iloc[ :5, 20:21]
# Out:
#         Uzbekistan
# Year
# 2015.0        39.0
# 2014.0        41.0
# 2016.0        42.0
# 1995.0        43.0
# 2020.0        44.0

# %%
df = e_pais.sort_values(by = ['Argentina'])
df.iloc[ :5, 21:22]
# Out:
#         Argentina
# Year
# 1990.0       44.0
# 1991.0       46.0
# 1992.0       47.0
# 1993.0       48.0
# 1994.0       52.0

# %%
df = e_pais.sort_values(by = ['Canada'])
df.iloc[ :5, 22:23]
# Out:
#         Canada
# Year
# 1991.0   210.0
# 1990.0   211.0
# 1992.0   216.0
# 1993.0   223.0
# 1994.0   231.0

# %%
df = e_pais.sort_values(by = ['Chile'])
df.iloc[ :5, 23:24]
# Out:
#         Chile
# Year
# 1990.0   14.0
# 1991.0   14.0
# 1992.0   15.0
# 1993.0   16.0
# 1994.0   17.0

# %%
df = e_pais.sort_values(by = ['Colombia'])
df.iloc[ :5, 24:25]
# Out:
#         Colombia
# Year
# 1990.0      24.0
# 1991.0      24.0
# 1992.0      25.0
# 2002.0      25.0
# 1993.0      26.0

# %%
df = e_pais.sort_values(by = ['Mexico'])
df.iloc[ :5, 25:26]
# Out:
#         Mexico
# Year
# 1990.0   124.0
# 1991.0   130.0
# 1992.0   131.0
# 1995.0   132.0
# 1993.0   133.0

# %%
df = e_pais.sort_values(by = ['Venezuela'])
df.iloc[ :5, 26:27]
# Out:
#         Venezuela
# Year
# 2020.0       29.0
# 2019.0       36.0
# 1990.0       40.0
# 1991.0       41.0
# 2018.0       42.0

# %%
df = e_pais.sort_values(by = ['Indonesia'])
df.iloc[ :5, 27:28]
# Out:
#         Indonesia
# Year
# 1990.0       99.0
# 1991.0      103.0
# 1992.0      108.0
# 1993.0      119.0
# 1994.0      119.0

# %%
df = e_pais.sort_values(by = ['Japan'])
df.iloc[ :5, 28:29]
# Out:
#         Japan
# Year
# 2020.0  386.0
# 2019.0  416.0
# 2018.0  428.0
# 2016.0  429.0
# 2017.0  434.0

# %%
df = e_pais.sort_values(by = ['Malaysia'])
df.iloc[ :5, 29:30]
# Out:
#         Malaysia
# Year
# 1990.0      21.0
# 1991.0      26.0
# 1992.0      29.0
# 1993.0      32.0
# 1994.0      32.0

# %%
df = e_pais.sort_values(by = ['South Korea'])
df.iloc[ :5, 30:31]
# Out:
#         South Korea
# Year
# 1990.0         94.0
# 1991.0        101.0
# 1992.0        111.0
# 1993.0        125.0
# 1994.0        133.0

# %%
df = e_pais.sort_values(by = ['Taiwan'])
df.iloc[ :5, 31:32]
# Out:
#         Taiwan
# Year
# 1990.0    48.0
# 1991.0    52.0
# 1992.0    54.0
# 1993.0    58.0
# 1994.0    60.0

# %%
df = e_pais.sort_values(by = ['Thailand'])
df.iloc[ :5, 32:33]
# Out:
#         Thailand
# Year
# 1990.0      42.0
# 1991.0      46.0
# 1992.0      49.0
# 1993.0      51.0
# 1994.0      57.0

# %%
df = e_pais.sort_values(by = ['India'])
df.iloc[ :5, 33:34]
# Out:
#         India
# Year
# 1990.0  306.0
# 1991.0  318.0
# 1992.0  330.0
# 1993.0  338.0
# 1994.0  351.0

# %%
df = e_pais.sort_values(by = ['Australia'])
df.iloc[ :5, 34:35]
# Out:
#         Australia
# Year
# 1991.0       85.0
# 1990.0       86.0
# 1992.0       87.0
# 1993.0       91.0
# 1994.0       91.0

# %%
df = e_pais.sort_values(by = ['New Zealand'])
df.iloc[ :5, 35:36]
# Out:
#         New Zealand
# Year
# 1990.0         14.0
# 1991.0         14.0
# 1992.0         14.0
# 1993.0         15.0
# 1994.0         15.0

# %%
df = e_pais.sort_values(by = ['Algeria'])
df.iloc[ :5, 36:37]
# Out:
#         Algeria
# Year
# 1990.0     22.0
# 1991.0     23.0
# 1994.0     23.0
# 1996.0     23.0
# 1992.0     24.0

# %%
df = e_pais.sort_values(by = ['Egypt'])
df.iloc[ :5, 37:38]
# Out:
#         Egypt
# Year
# 1990.0   33.0
# 1991.0   33.0
# 1992.0   34.0
# 1994.0   34.0
# 1993.0   35.0

# %%
df = e_pais.sort_values(by = ['Nigeria'])
df.iloc[ :5, 38:39]
# Out:
#         Nigeria
# Year
# 1990.0     66.0
# 1991.0     70.0
# 1992.0     72.0
# 1994.0     72.0
# 1995.0     73.0

# %%
df = e_pais.sort_values(by = ['South Africa'])
df.iloc[ :5, 39:40]
# Out:
#         South Africa
# Year
# 1992.0          88.0
# 1990.0          90.0
# 1991.0          92.0
# 1993.0          94.0
# 1994.0          98.0

# %%
df = e_pais.sort_values(by = ['Iran'])
df.iloc[ :5, 40:41]
# Out:
#         Iran
# Year
# 1990.0  69.0
# 1991.0  77.0
# 1992.0  81.0
# 1993.0  87.0
# 1994.0  97.0

# %%
df = e_pais.sort_values(by = ['Kuwait'])
df.iloc[ :5, 41:42]
# Out:
#         Kuwait
# Year
# 1991.0     3.0
# 1990.0     9.0
# 1992.0     9.0
# 1993.0    12.0
# 1994.0    14.0

# %%
df = e_pais.sort_values(by = ['Saudi Arabia'])
df.iloc[ :5, 42:43]
# Out:
#         Saudi Arabia
# Year
# 1990.0          58.0
# 1991.0          68.0
# 1992.0          77.0
# 1993.0          80.0
# 1994.0          84.0

# %%
df = e_pais.sort_values(by = ['United Arab Emirates'])
df.iloc[ :5, 43:44]
# Out:
#         United Arab Emirates
# Year
# 1990.0                  20.0
# 1992.0                  22.0
# 1991.0                  23.0
# 1993.0                  23.0
# 1994.0                  26.0

# %% [markdown]
# Paises com maior consumo em cada ano

# %%
df = e_pais.T 

an1 = df.iloc[: , :6]
an2 = df.iloc[: , 6: 11]
an3 = df.iloc[: , 11:16]
an4 = df.iloc[: , 16:21]
an5 = df.iloc[: , 21:26]
an6 = df.iloc[: , 26: ]

# %%
an1.sort_values(by = [1990], ascending = False).iloc[:5 , :1]
# Out:
# Year           1990.0
# United States  1910.0
# Russia          879.0
# China           874.0
# Japan           440.0
# Germany         351.0

# %%
an1.sort_values(by = [1991], ascending = False).iloc[:5 , 1:2]
# Out:
# Year           1991.0
# United States  1925.0
# Russia          871.0
# China           848.0
# Japan           445.0
# Germany         344.0

# %%
an1.sort_values(by = [1992], ascending = False).iloc[:5 , 2:3]
# Out:
# Year           1992.0
# United States  1964.0
# China           877.0
# Russia          795.0
# Japan           455.0
# Germany         338.0

# %%
an1.sort_values(by = [1993], ascending = False).iloc[:5 , 3:4]
# Out:
# Year           1993.0
# United States  1998.0
# China           929.0
# Russia          751.0
# Japan           458.0
# India           338.0

# %%
an1.sort_values(by = [1994], ascending = False).iloc[:5 , 4:5]
# Out:
# Year           1994.0
# United States  2036.0
# China           973.0
# Russia          657.0
# Japan           483.0
# India           351.0

# %%
an1.sort_values(by = [1995], ascending = False).iloc[:5 , 5:6]
# Out:
# Year           1995.0
# United States  2063.0
# China          1045.0
# Russia          636.0
# Japan           495.0
# India           371.0

# %%
an2.sort_values(by = [1996], ascending = False).iloc[:5 , :1]
# Out:
# Year           1996.0
# United States  2108.0
# China          1074.0
# Russia          630.0
# Japan           506.0
# India           383.0

# %%
an2.sort_values(by = [1997], ascending = False).iloc[:5 , 1:2]
# Out:
# Year           1997.0
# United States  2130.0
# China          1073.0
# Russia          602.0
# Japan           511.0
# India           398.0

# %%
an2.sort_values(by = [1998], ascending = False).iloc[:5 , 2:3]
# Out:
# Year           1998.0
# United States  2148.0
# China          1079.0
# Russia          588.0
# Japan           502.0
# India           407.0

# %%
an2.sort_values(by = [1999], ascending = False).iloc[:5 , 3:4]
# Out:
# Year           1999.0
# United States  2206.0
# China          1099.0
# Russia          609.0
# Japan           510.0
# India           431.0

# %%
an2.sort_values(by = [2000], ascending = False).iloc[:5 , 4:5]
# Out:
# Year           2000.0
# United States  2269.0
# China          1130.0
# Russia          619.0
# Japan           520.0
# India           441.0

# %%
an3.sort_values(by = [2001], ascending = False).iloc[:5 , :1]
# Out:
# Year           2001.0
# United States  2226.0
# China          1168.0
# Russia          626.0
# Japan           511.0
# India           448.0

# %%
an3.sort_values(by = [2002], ascending = False).iloc[:5 , 1:2]
# Out:
# Year           2002.0
# United States  2256.0
# China          1246.0
# Russia          623.0
# Japan           513.0
# India           462.0

# %%
an3.sort_values(by = [2003], ascending = False).iloc[:5 , 2:3]
# Out:
# Year           2003.0
# United States  2262.0
# China          1420.0
# Russia          645.0
# Japan           509.0
# India           474.0

# %%
an3.sort_values(by = [2004], ascending = False).iloc[:5 , 3:4]
# Out:
# Year           2004.0
# United States  2308.0
# China          1615.0
# Russia          647.0
# Japan           526.0
# India           500.0

# %%
an3.sort_values(by = [2005], ascending = False).iloc[:5 , 4:5]
# Out:
# Year           2005.0
# United States  2320.0
# China          1782.0
# Russia          651.0
# Japan           524.0
# India           515.0

# %%
an4.sort_values(by = [2006], ascending = False).iloc[:5 , :1]
# Out:
# Year           2006.0
# United States  2298.0
# China          1950.0
# Russia          670.0
# India           533.0
# Japan           524.0

# %%
an4.sort_values(by = [2007], ascending = False).iloc[:5 , 1:2]
# Out:
# Year           2007.0
# United States  2338.0
# China          2099.0
# Russia          672.0
# India           568.0
# Japan           519.0

# %%
an4.sort_values(by = [2008], ascending = False).iloc[:5 , 2:3]
# Out:
# Year           2008.0
# United States  2278.0
# China          2155.0
# Russia          688.0
# India           604.0
# Japan           500.0

# %%
an4.sort_values(by = [2009], ascending = False).iloc[:5 , 3:4]
# Out:
# Year           2009.0
# China          2297.0
# United States  2165.0
# India           663.0
# Russia          647.0
# Japan           477.0

# %%
an4.sort_values(by = [2010], ascending = False).iloc[:5 , 4:5]
# Out:
# Year           2010.0
# China          2536.0
# United States  2217.0
# India           701.0
# Russia          688.0
# Japan           503.0

# %%
an5.sort_values(by = [2011], ascending = False).iloc[:5 , :1]
# Out:
# Year           2011.0
# China          2723.0
# United States  2191.0
# India           734.0
# Russia          711.0
# Japan           466.0

# %%
an5.sort_values(by = [2012], ascending = False).iloc[:5 , 1:2]
# Out:
# Year           2012.0
# China          2821.0
# United States  2152.0
# India           766.0
# Russia          728.0
# Japan           456.0

# %%
an5.sort_values(by = [2013], ascending = False).iloc[:5 , 2:3]
# Out:
# Year           2013.0
# China          2912.0
# United States  2190.0
# India           779.0
# Russia          707.0
# Japan           457.0

# %%
an5.sort_values(by = [2014], ascending = False).iloc[:5 , 3:4]
# Out:
# Year           2014.0
# China          2966.0
# United States  2216.0
# India           822.0
# Russia          707.0
# Japan           442.0

# %%
an5.sort_values(by = [2015], ascending = False).iloc[:5 , 4:5]
# Out:
# Year           2015.0
# China          2994.0
# United States  2192.0
# India           835.0
# Russia          693.0
# Japan           434.0

# %%
an6.sort_values(by = [2016], ascending = False).iloc[:5 , :1]
# Out:
# Year           2016.0
# China          2977.0
# United States  2168.0
# India           852.0
# Russia          714.0
# Japan           429.0

# %%
an6.sort_values(by = [2017], ascending = False).iloc[:5 , 1:2]
# Out:
# Year           2017.0
# China          3070.0
# United States  2161.0
# India           883.0
# Russia          729.0
# Japan           434.0

# %%
an6.sort_values(by = [2018], ascending = False).iloc[:5 , 2:3]
# Out:
# Year           2018.0
# China          3201.0
# United States  2236.0
# India           919.0
# Russia          760.0
# Japan           428.0

# %%
an6.sort_values(by = [2019], ascending = False).iloc[:5 , 3:4]
# Out:
# Year           2019.0
# China          3309.0
# United States  2214.0
# India           940.0
# Russia          768.0
# Japan           416.0

# %%
an6.sort_values(by = [2020], ascending = False).iloc[:5 , 4:5]
# Out:
# Year           2020.0
# China          3381.0
# United States  2046.0
# India           908.0
# Russia          731.0
# Japan           386.0

# %% [markdown]
# Paises com o menor consumo com cada ano

# %%
an1.sort_values(by = [1990]).iloc[:5 , :1]
# Out:
# Year                  1990.0
# Kuwait                   9.0
# New Zealand             14.0
# Chile                   14.0
# Portugal                17.0
# United Arab Emirates    20.0

# %%
an1.sort_values(by = [1991]).iloc[:5 , 1:2]
# Out:
# Year         1991.0
# Kuwait          3.0
# New Zealand    14.0
# Chile          14.0
# Portugal       17.0
# Norway         22.0

# %%
an1.sort_values(by = [1992]).iloc[:5 , 2:3]
# Out:
# Year                  1992.0
# Kuwait                   9.0
# New Zealand             14.0
# Chile                   15.0
# Portugal                18.0
# United Arab Emirates    22.0

# %%
an1.sort_values(by = [1993]).iloc[:5 , 3:4]
# Out:
# Year                  1993.0
# Kuwait                  12.0
# New Zealand             15.0
# Chile                   16.0
# Portugal                18.0
# United Arab Emirates    23.0

# %%
an1.sort_values(by = [1994]).iloc[:5 , 4:5]
# Out:
# Year         1994.0
# Kuwait         14.0
# New Zealand    15.0
# Chile          17.0
# Portugal       18.0
# Algeria        23.0

# %%
an1.sort_values(by = [1995]).iloc[:5 , 5:6]
# Out:
# Year         1995.0
# Kuwait         15.0
# New Zealand    15.0
# Chile          18.0
# Portugal       20.0
# Algeria        24.0

# %%
an2.sort_values(by = [1996]).iloc[:5 , :1]
# Out:
# Year         1996.0
# Kuwait         14.0
# New Zealand    16.0
# Chile          20.0
# Portugal       20.0
# Algeria        23.0

# %%
an2.sort_values(by = [1997]).iloc[:5 , 1:2]
# Out:
# Year         1997.0
# Kuwait         15.0
# New Zealand    16.0
# Portugal       21.0
# Chile          23.0
# Algeria        24.0

# %%
an2.sort_values(by = [1998]).iloc[:5 , 2:3]
# Out:
# Year         1998.0
# New Zealand    16.0
# Kuwait         17.0
# Portugal       23.0
# Chile          24.0
# Algeria        25.0

# %%
an2.sort_values(by = [1999]).iloc[:5 , 3:4]
# Out:
# Year         1999.0
# New Zealand    17.0
# Kuwait         18.0
# Portugal       24.0
# Chile          25.0
# Colombia       26.0

# %%
an2.sort_values(by = [2000]).iloc[:5 , 4:5]
# Out:
# Year         2000.0
# New Zealand    17.0
# Kuwait         19.0
# Chile          25.0
# Portugal       25.0
# Colombia       26.0

# %%
an3.sort_values(by = [2001]).iloc[:5 , :1]
# Out:
# Year         2001.0
# New Zealand    17.0
# Kuwait         20.0
# Chile          25.0
# Portugal       25.0
# Colombia       26.0

# %%
an3.sort_values(by = [2002]).iloc[:5 , 1:2]
# Out:
# Year         2002.0
# New Zealand    17.0
# Kuwait         20.0
# Colombia       25.0
# Norway         25.0
# Chile          26.0

# %%
an3.sort_values(by = [2003]).iloc[:5 , 2:3]
# Out:
# Year         2003.0
# New Zealand    17.0
# Kuwait         21.0
# Portugal       25.0
# Colombia       26.0
# Chile          26.0

# %%
an3.sort_values(by = [2004]).iloc[:5 , 3:4]
# Out:
# Year         2004.0
# New Zealand    18.0
# Kuwait         24.0
# Colombia       26.0
# Portugal       26.0
# Norway         27.0

# %%
an3.sort_values(by = [2005]).iloc[:5 , 4:5]
# Out:
# Year         2005.0
# New Zealand    17.0
# Portugal       26.0
# Kuwait         27.0
# Norway         27.0
# Colombia       27.0

# %%
an4.sort_values(by = [2006]).iloc[:5 , :1]
# Out:
# Year         2006.0
# New Zealand    17.0
# Kuwait         25.0
# Portugal       25.0
# Norway         27.0
# Colombia       29.0

# %%
an4.sort_values(by = [2007]).iloc[:5 , 1:2]
# Out:
# Year         2007.0
# New Zealand    17.0
# Kuwait         25.0
# Portugal       25.0
# Norway         28.0
# Colombia       28.0

# %%
an4.sort_values(by = [2008]).iloc[:5 , 2:3]
# Out:
# Year         2008.0
# New Zealand    18.0
# Portugal       25.0
# Kuwait         28.0
# Colombia       30.0
# Chile          30.0

# %%
an4.sort_values(by = [2009]).iloc[:5 , 3:4]
# Out:
# Year         2009.0
# New Zealand    18.0
# Portugal       24.0
# Kuwait         29.0
# Chile          30.0
# Colombia       31.0

# %%
an4.sort_values(by = [2010]).iloc[:5 , 4:5]
# Out:
# Year         2010.0
# New Zealand    19.0
# Portugal       23.0
# Kuwait         29.0
# Colombia       30.0
# Chile          31.0

# %%
an5.sort_values(by = [2011]).iloc[:5 , :1]
# Out:
# Year         2011.0
# New Zealand    18.0
# Portugal       23.0
# Kuwait         28.0
# Norway         28.0
# Colombia       31.0

# %%
an5.sort_values(by = [2012]).iloc[:5 , 1:2]
# Out:
# Year         2012.0
# New Zealand    19.0
# Portugal       21.0
# Kuwait         29.0
# Colombia       30.0
# Norway         31.0

# %%
an5.sort_values(by = [2013]).iloc[:5 , 2:3]
# Out:
# Year         2013.0
# New Zealand    19.0
# Portugal       22.0
# Kuwait         30.0
# Romania        32.0
# Norway         33.0

# %%
an5.sort_values(by = [2014]).iloc[:5 , 3:4]
# Out:
# Year         2014.0
# New Zealand    21.0
# Portugal       21.0
# Kuwait         27.0
# Norway         29.0
# Romania        32.0

# %%
an5.sort_values(by = [2015]).iloc[:5 , 4:5]
# Out:
# Year         2015.0
# New Zealand    21.0
# Portugal       22.0
# Norway         30.0
# Romania        32.0
# Kuwait         33.0

# %%
an6.sort_values(by = [2016]).iloc[:5 , :1]
# Out:
# Year         2016.0
# New Zealand    21.0
# Portugal       22.0
# Norway         29.0
# Romania        32.0
# Kuwait         36.0

# %%
an6.sort_values(by = [2017]).iloc[:5 , 1:2]
# Out:
# Year         2017.0
# New Zealand    21.0
# Portugal       23.0
# Norway         30.0
# Romania        33.0
# Kuwait         34.0

# %%
an6.sort_values(by = [2018]).iloc[:5 , 2:3]
# Out:
# Year         2018.0
# New Zealand    20.0
# Portugal       22.0
# Norway         29.0
# Kuwait         34.0
# Romania        34.0

# %%
an6.sort_values(by = [2019]).iloc[:5 , 3:4]
# Out:
# Year         2019.0
# New Zealand    21.0
# Portugal       22.0
# Norway         28.0
# Romania        33.0
# Kuwait         36.0

# %%
an6.sort_values(by = [2020]).iloc[:5 , 4:5]
# Out:
# Year         2020.0
# Portugal       20.0
# New Zealand    21.0
# Norway         27.0
# Venezuela      29.0
# Romania        32.0

# %% [markdown]
# Gráficos

# %%
algeria = e_pais['Algeria']
argentina = e_pais['Argentina']
australia = e_pais['Australia']
belgium = e_pais['Belgium']
brazil = e_pais['Brazil']
canada = e_pais['Canada']
chile = e_pais['Chile']
china = e_pais['China']
colombia = e_pais['Colombia']
czechia = e_pais['Czechia']
egypt = e_pais['Egypt']
france = e_pais['France']
germany = e_pais['Germany']
india = e_pais['India']
indonesia = e_pais['Indonesia']
iran = e_pais['Iran']
italy = e_pais['Italy']
japan = e_pais['Japan']
kazakhstan = e_pais['Kazakhstan']
kuwait = e_pais['Kuwait']
malaysia = e_pais['Malaysia']
mexico = e_pais['Mexico']
netherlands = e_pais['Netherlands']
new_zhealand = e_pais['New Zealand']
nigeria = e_pais['Nigeria']
norway = e_pais['Norway']
poland = e_pais['Poland']
portugal = e_pais['Portugal']
romania = e_pais['Romania']
russia = e_pais['Russia']
saudi_arabia = e_pais['Saudi Arabia']
south_africa = e_pais['South Africa']
south_korea = e_pais['South Korea']
spain = e_pais['Spain']
sweden = e_pais['Sweden']
taiwan = e_pais['Taiwan']
thailand = e_pais['Thailand']
turkey = e_pais['Turkey']
ukraine = e_pais['Ukraine']
united_emirates = e_pais['United Arab Emirates']
united_kingdom = e_pais['United Kingdom']
united_states = e_pais['United States']
uzbequistan = e_pais['Uzbekistan']
venezuela = e_pais['Venezuela']

# %%
algeria.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
argentina.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
australia.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
belgium.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
brazil.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
canada.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
chile.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
china.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
colombia.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
czechia.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
egypt.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
france.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
germany.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
india.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
indonesia.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
iran.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
italy.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
japan.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
kazakhstan.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
kuwait.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
malaysia.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
mexico.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
netherlands.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
new_zhealand.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
nigeria.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
norway.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
poland.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
portugal.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
romania.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
russia.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
saudi_arabia.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
south_africa.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
south_korea.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
spain.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
sweden.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
taiwan.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
thailand.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
turkey.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
ukraine.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
united_emirates.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
united_kingdom.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
united_states.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
uzbequistan.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
venezuela.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %% [markdown]
# # Analise do consumo por pais e por continente

# %% [markdown]
# Porcentagem de consumo de cada país por continente

# %% [markdown]
# Analise Mundial

# %%
e_cont = pd.read_csv('../../Energydata/Continent_Consumption_TWH.csv')
e_cont = e_cont.set_index('Year')
e_pais = pd.read_csv("../../Energydata/Country_Consumption_TWH.csv")
e_pais = e_pais.set_index('Year')

# %%
world = e_cont['World']
algeria_wp = (algeria * 100) / world
argentina_wp = (argentina * 100) / world
australia_wp = (australia * 100) / world
belgium_wp = (belgium * 100) / world
brazil_wp = (brazil * 100) / world
canada_wp = (canada * 100) / world
chile_wp = (chile * 100) / world
china_wp = (china * 100) / world
colombia_wp = (colombia * 100) / world
czechia_wp = (czechia * 100) / world
egypt_wp = (egypt * 100) / world
france_wp = (france * 100) / world
germany_wp = (germany * 100) / world
india_wp = (india * 100) / world
indonesia_wp = (indonesia * 100) / world
iran_wp = (iran * 100) / world
italy_wp = (italy * 100) / world
japan_wp = (japan * 100) / world
kazakhstan_wp = (kazakhstan * 100) / world
kuwait_wp = (kuwait * 100) / world
malaysia_wp = (malaysia * 100) / world
mexico_wp = (mexico * 100) / world
netherlands_wp = (netherlands * 100) / world
new_zhealand_wp = (new_zhealand * 100) / world
nigeria_wp = (nigeria * 100) / world
norway_wp = (norway * 100) / world
poland_wp = (poland * 100) / world
portugal_wp = (portugal * 100) / world
romania_wp = (romania * 100) / world
russia_wp = (russia * 100) / world
saudi_arabia_wp = (saudi_arabia * 100) / world
south_africa_wp = (south_africa * 100) / world
south_korea_wp = (south_korea * 100) / world
spain_wp = (spain * 100) / world
sweden_wp = (sweden * 100) / world
taiwan_wp = (taiwan * 100) / world
thailand_wp = (thailand * 100) / world
turkey_wp = (turkey * 100) / world
ukraine_wp = (ukraine * 100) / world
united_emirates_wp = (united_emirates * 100) / world
united_kingdom_wp = (united_kingdom * 100) / world
united_states_wp = (united_states * 100) / world
uzbequistan_wp = (uzbequistan * 100) / world
venezuela_wp = (venezuela * 100) / world

world_percentage = pd.DataFrame({'Algeria World Percentage' : algeria_wp,
                                'Argentina World Percentage' : argentina_wp,
                                'Australia World Percentage' : australia_wp,
                                'Belgium World Percentage' : belgium_wp,
                                'Brazil World Percentage' : brazil_wp,
                                'Canada World Percentage' : canada_wp,
                                'Chile World Percentage' : chile_wp,
                                'China World Percentage' : china_wp,
                                'Colombia World Percentage' : colombia_wp,
                                'Czechia World Percentage' : czechia_wp,
                                'Egypt World Percentage' : egypt_wp,
                                'France World Percentage' : france_wp,
                                'Germany World Percentage' : germany_wp,
                                'India World Percentage' : india_wp,
                                'Indonesia World Percentage' : indonesia_wp,
                                'Iran World Percentage' : iran_wp,
                                'Italy World Percentage' : italy_wp,
                                'Japan World Percentage' : japan_wp,
                                'Kazakhstan World Percentage' : kazakhstan_wp,
                                'Kuwait World Pecentage' : kuwait_wp,
                                'Malaysia World Percentage' : malaysia_wp,
                                'Mexico World Percentage' : mexico_wp,
                                'Netherlands World Percentage' : netherlands_wp,
                                'New Zhealand World Percentage' : new_zhealand_wp,
                                'Nigeria World Percentage' : nigeria_wp,
                                'Norway World Percentage' : norway_wp,
                                'Poland World Perentage' : poland_wp,
                                'Portugal World Percentage' : portugal_wp,
                                'Romania World Percentage' : romania_wp,
                                'Russia World Percentage' : russia_wp,
                                'Saudi Arabia World Percentage' : saudi_arabia_wp,
                                'South Africa World Percentage' : south_africa_wp,
                                'South Korea World Percentage' : south_korea_wp,
                                'Spain World percentage' : spain_wp,
                                'Sweden World Percentage' : sweden_wp,
                                'Taiwan World Percentage' : taiwan_wp,
                                'Thailand World Percentage' : thailand_wp,
                                'Turkey World Percentage' : turkey_wp,
                                'Ukraine World Percentage' : ukraine_wp,
                                'United Arab Emirates World Percentage' : united_emirates_wp,
                                'United Kingdom World Percentage' : united_kingdom_wp,
                                'United States World Percentage' : united_states_wp,
                                'Uzbequistan World Percentage' : uzbequistan_wp,
                                'Venezuela World Percentage' : venezuela_wp})

world_percentage_full=pd.DataFrame({ 'Algeria' : algeria, 'Algeria World Percentage' : algeria_wp,
                                'Argentina' : argentina, 'Argentina World Percentage' : argentina_wp,
                                'Australia' : australia, 'Australia World Percentage' : australia_wp,
                                'Belgium' : belgium, 'Belgium World Percentage' : belgium_wp,
                                'Brazil' : brazil, 'Brazil World Percentage' : brazil_wp,
                                'Canada' : canada, 'Canada World Percentage' : canada_wp,
                                'Chile' : chile, 'Chile World Percentage' : chile_wp,
                                'China' : china, 'China World Percentage' : china_wp,
                                'Colombia' : colombia, 'Colombia World Percentage' : colombia_wp,
                                'Czechia' : czechia, 'Czechia World Percentage' : czechia_wp,
                                'Egypt' : egypt, 'Egypt World Percentage' : egypt_wp,
                                'France' : france, 'France World Percentage' : france_wp,
                                'Germany' : germany, 'Germany World Percentage' : germany_wp,
                                'India' : india, 'India World Percentage' : india_wp,
                                'Indonesia' : indonesia, 'Indonesia World Percentage' : indonesia_wp,
                                'Iran' : iran, 'Iran World Percentage' : iran_wp,
                                'Italy' : italy, 'Italy World Percentage' : italy_wp,
                                'Japan' : japan, 'Japan World Percentage' : japan_wp,
                                'Kazakhstan' : kazakhstan, 'Kazakhstan World Percentage' : kazakhstan_wp,
                                'Kuwait' : kuwait, 'Kuwait World Pecentage' : kuwait_wp,
                                'Malaysia' : malaysia, 'Malaysia World Percentage' : malaysia_wp,
                                'Mexico' : mexico, 'Mexico World Percentage' : mexico_wp,
                                'Netherlands' : netherlands, 'Netherlands World Percentage' : netherlands_wp,
                                'New Zhealand' : new_zhealand, 'New Zhealand World Percentage' : new_zhealand_wp,
                                'Nigeria' : nigeria, 'Nigeria World Percentage' : nigeria_wp,
                                'Norway' : norway, 'Norway World Percentage' : norway_wp,
                                'Poland' : poland, 'Poland World Perentage' : poland_wp,
                                'Portugal' : portugal, 'Portugal World Percentage' : portugal_wp,
                                'Romania' : romania, 'Romania World Percentage' : romania_wp,
                                'Russia' : russia, 'Russia World Percentage' : russia_wp,
                                'Saudi Arabia' : saudi_arabia, 'Saudi Arabia World Percentage' : saudi_arabia_wp,
                                'South Africa' : south_africa, 'South Africa World Percentage' : south_africa_wp,
                                'South Korea' : south_korea, 'South Korea World Percentage' : south_korea_wp,
                                'Spain' : spain, 'Spain World percentage' : spain_wp,
                                'Sweden' : sweden, 'Sweden World Percentage' : sweden_wp,
                                'Taiwan' : taiwan, 'Taiwan World Percentage' : taiwan_wp,
                                'Thailand' : thailand, 'Thailand World Percentage' : thailand_wp,
                                'Turkey' : turkey, 'Turkey World Percentage' : turkey_wp,
                                'Ukraine' : ukraine, 'Ukraine World Percentage' : ukraine_wp,
                                'United Arab Emirates' : united_emirates, 'United Arab Emirates World Percentage' : united_emirates_wp,
                                'United Kingdom' : united_kingdom, 'United Kingdom World Percentage' : united_kingdom_wp,
                                'United States' : united_states, 'United States World Percentage' : united_states_wp,
                                'Uzbequistan' : uzbequistan, 'Uzbequistan World Percentage' : uzbequistan_wp,
                                'Venezuela' : venezuela, 'Venezuela World Percentage' : venezuela_wp,
                                'Total' : world})
world_percentage_full
# Out:
#         Algeria  Algeria World Percentage  Argentina  \
# Year
# 1990.0     22.0                  0.021599       44.0
# 1991.0     23.0                  0.022443       46.0
# 1992.0     24.0                  0.023394       47.0
# 1993.0     24.0                  0.023156       48.0
# 1994.0     23.0                  0.022020       52.0
# 1995.0     24.0                  0.022406       52.0
# 1996.0     23.0                  0.020954       54.0
# 1997.0     24.0                  0.021640       56.0
# 1998.0     25.0                  0.022432       59.0
# 1999.0     27.0                  0.023690       61.0
# 2000.0     27.0                  0.023158       61.0
# 2001.0     27.0                  0.022975       56.0
# 2002.0     29.0                  0.024125       56.0
# 2003.0     31.0                  0.024907       60.0
# 2004.0     31.0                  0.023855       67.0
# 2005.0     32.0                  0.023955       66.0
# 2006.0     35.0                  0.025474       70.0
# ...

# %% [markdown]
# Percentagem por continente

# %% [markdown]
# África

# %%
africa = e_cont['Africa']
algeria_africa = (algeria * 100) / africa
egypt_africa = (egypt * 100) / africa
nigeria_africa = (nigeria * 100) / africa
south_africa2 = (south_africa * 100) / africa

africa_percentage=pd.DataFrame({'Algeria Percentage' : algeria_africa,
                                'Egypt Percentage' : egypt_africa,
                                'Nigeria Percentagem' : nigeria_africa,
                                'South Africa Percentage' : south_africa2})

africa_percentage_full=pd.DataFrame({'Algeria' : algeria, 'Algeria Percentage' : algeria_africa,
                                'Egypt' : egypt, 'Egypt Percentage' : egypt_africa,
                                'Nigeria' : nigeria, 'Nigeria Percentagem' : nigeria_africa,
                                'South Africa' : south_africa, 'South Africa Percentage' : south_africa2,
                                'Total' : africa})

africa_percentage_full
# Out:
#         Algeria  Algeria Percentage  Egypt  Egypt Percentage  Nigeria  \
# Year
# 1990.0     22.0            0.499119   33.0          0.748678     66.0
# 1991.0     23.0            0.507088   33.0          0.727561     70.0
# 1992.0     24.0            0.523764   34.0          0.741998     72.0
# 1993.0     24.0            0.508283   35.0          0.741246     74.0
# 1994.0     23.0            0.478848   34.0          0.707863     72.0
# 1995.0     24.0            0.479914   36.0          0.719870     73.0
# 1996.0     23.0            0.446421   38.0          0.737565     76.0
# 1997.0     24.0            0.454544   40.0          0.757573     79.0
# 1998.0     25.0            0.460303   42.0          0.773308     80.0
# 1999.0     27.0            0.485687   43.0          0.773501     83.0
# 2000.0     27.0            0.480659   41.0          0.729889     87.0
# 2001.0     27.0            0.469006   47.0          0.816419     91.0
# ...

# %% [markdown]
# Asia

# %%
asia = e_cont['Asia']

china_asia = (china * 100) / asia
egypt_asia = (egypt * 100) / asia
india_asia = (india * 100) / asia
indonesia_asia = (indonesia * 100) / asia
iran_asia = (iran * 100) / asia
japan_asia = (japan * 100) / asia
kazakhstan_asia = (kazakhstan * 100) / asia
kuwait_asia = (kuwait * 100) / asia
malaysia_asia = (malaysia * 100) / asia
south_korea_asia = (south_korea * 100) / asia
taiwan_asia = (taiwan * 100) / asia
thailand_asia = (thailand * 100) / asia
turkey_asia = (turkey * 100) / asia
united_arab_emirates_asia = (united_emirates * 100) / asia
uzbequistan_asia = (uzbequistan * 100) / asia

asia_percentage=pd.DataFrame({'China Percentage' : china_asia,
                              'Egypt Percentage' : egypt_asia,
                              'India Percentage' : india_asia,
                              'Indonesia Percentage' : indonesia_asia,
                              'Iran Percentage' : iran_asia,
                              'Japan Percentage' : japan_asia,
                              'Kazakhstan Percentage' : kazakhstan_asia,
                              'Kuwait Percentage' : kuwait_asia,
                              'Malaysia Percentage' : malaysia_asia,
                              'South Korea Percentage' : south_korea_asia,
                              'Taiwan Percentagem' : taiwan_asia,
                              'Thailand Percentage' : thailand_asia,
                              'Turkey Percentage' : turkey_asia,
                              'United Arab Emirates Percentage' : united_arab_emirates_asia,
                              'Uzbequistan Percentage' : uzbequistan_asia,})

asia_percentage_full=pd.DataFrame({'China' : china, 'China Percentage' : china_asia,
                              'Egypt' : egypt, 'Egypt Percentage' : egypt_asia,
                              'India' : india, 'India Percentage' : india_asia,
                              'Indonesia' : indonesia, 'Indonesia Percentage' : indonesia_asia,
                              'Iran' : iran, 'Iran Percentage' : iran_asia,
                              'Japan' : japan, 'Japan Percentage' : japan_asia,
                              'Kazakhstan' : kazakhstan, 'Kazakhstan Percentage' : kazakhstan_asia,
                              'Kuwait' : kuwait, 'Kuwait Percentage' : kuwait_asia,
                              'Malaysia' : malaysia, 'Malaysia Percentage' : malaysia_asia,
                              'South Korea' : south_korea, 'South Korea Percentage' : south_korea_asia,
                              'Taiwan' : taiwan, 'Taiwan Percentagem' : taiwan_asia,
                              'Thailand' : thailand, 'Thailand Percentage' : thailand_asia,
                              'Turkey' : turkey, 'Turkey Percentage' : turkey_asia,
                              'United Arab Emirates' : united_emirates, 'United Arab Emirates Percentage' : united_arab_emirates_asia,
                              'Uzbequistan' : uzbequistan, 'Uzbequistan Percentage' : uzbequistan_asia,
                              'Total' : asia})

asia_percentage_full
# Out:
#          China  China Percentage  Egypt  Egypt Percentage  India  \
# Year
# 1990.0   874.0          3.556577   33.0          0.134287  306.0
# 1991.0   848.0          3.421627   33.0          0.133153  318.0
# 1992.0   877.0          3.413691   34.0          0.132344  330.0
# 1993.0   929.0          3.456496   35.0          0.130223  338.0
# 1994.0   973.0          3.462870   34.0          0.121005  351.0
# 1995.0  1045.0          3.511287   36.0          0.120963  371.0
# 1996.0  1074.0          3.490075   38.0          0.123485  383.0
# 1997.0  1073.0          3.413296   40.0          0.127243  398.0
# 1998.0  1079.0          3.443849   42.0          0.134052  407.0
# 1999.0  1099.0          3.390635   43.0          0.132664  431.0
# 2000.0  1130.0          3.366684   41.0          0.122154  441.0
# 2001.0  1168.0          3.412502   47.0          0.137318  448.0
# 2002.0  1246.0          3.492070   48.0          0.134526  462.0
# ...

# %% [markdown]
# Europe

# %%
europe = e_cont['Europe']

belgium_europe = (belgium * 100) / europe
czechia_europe = (czechia * 100) / europe
france_europe = (france * 100) / europe
germany_europe = (germany * 100) / europe
italy_europe = (italy * 100) / europe
netherlands_europe = (netherlands * 100) / europe
norway_europe = (norway * 100) / europe
poland_europe = (poland * 100) / europe
portugal_europe = (portugal * 100) / europe
romania_europe = (romania * 100) / europe
russia_europe = (russia * 100) / europe
spain_europe = (spain * 100) / europe
sweden_europe = (sweden * 100) / europe
ukraine_europe = (ukraine * 100) / europe
united_kingdom_europe = (united_kingdom * 100) / europe

europe_percentage=pd.DataFrame({'Belgium Percentage' : belgium_europe,
                                'Czechia Percentage' : czechia_europe,
                                'France Percentage' : france_europe,
                                'Germany Percentage' : germany_europe,
                                'Italy Percentage' : italy_europe,
                                'Netherlands Percentage' : netherlands_europe,
                                'Norway Percentage' : norway_europe,
                                'Poland Percentage' : poland_europe,
                                'Portugal Percentage' : portugal_europe,
                                'Romania Percentage' : romania_europe,
                                'Russia Percentagem' : russia_europe,
                                'Spain Percentage' : spain_europe,
                                'Sweden Percentage' : sweden_europe,
                                'Ukraine Percentage' : ukraine_europe,
                                'United Kingdom Percentage' : united_kingdom_europe,})

europe_percentage_full=pd.DataFrame({'Belgium' : belgium, 'Belgium Percentage' : belgium_europe,
                                'Czechia' : czechia, 'Czechia Percentage' : czechia_europe,
                                'France' : france, 'France Percentage' : france_europe,
                                'Germany' : germany, 'Germany Percentage' : germany_europe,
                                'Italy' : italy, 'Italy Percentage' : italy_europe,
                                'Netherlands' : netherlands, 'Netherlands Percentage' : netherlands_europe,
                                'Norway' : norway, 'Norway Percentage' : norway_europe,
                                'Poland' : poland, 'Poland Percentage' : poland_europe,
                                'Portugal' : portugal, 'Portugal Percentage' : portugal_europe,
                                'Romania' : romania, 'Romania Percentage' : romania_europe,
                                'Russia' : russia, 'Russia Percentagem' : russia_europe,
                                'Spain' : spain, 'Spain Percentage' : spain_europe,
                                'Sweden' : sweden, 'Sweden Percentage' : sweden_europe,
                                'Ukraine' : ukraine, 'Ukraine Percentage' : ukraine_europe,
                                'United Kingdom' : united_kingdom, 'United Kingdom Percentage' : united_kingdom_europe,
                                'Total' : europe})

europe_percentage_full
# Out:
#         Belgium  Belgium Percentage  Czechia  Czechia Percentage  France  \
# Year
# 1990.0     48.0            0.232391     50.0            0.242074   225.0
# 1991.0     50.0            0.242346     45.0            0.218112   237.0
# 1992.0     51.0            0.252604     44.0            0.217933   234.0
# 1993.0     49.0            0.242698     43.0            0.212980   238.0
# 1994.0     52.0            0.258900     41.0            0.204132   231.0
# 1995.0     53.0            0.255878     42.0            0.202771   240.0
# 1996.0     56.0            0.261124     43.0            0.200506   251.0
# 1997.0     56.0            0.262405     43.0            0.201490   244.0
# 1998.0     57.0            0.265069     42.0            0.195314   252.0
# 1999.0     57.0            0.267528     39.0            0.183046   252.0
# 2000.0     58.0            0.269282     41.0            0.190355   255.0
# 2001.0     58.0            0.264427     42.0            0.191482   260.0
# ...

# %% [markdown]
# Latin America

# %%
latin_america = e_cont['Latin America']

argentina_latin = (argentina * 100) / latin_america
brazil_latin = (brazil * 100) / latin_america
chile_latin = (chile * 100) / latin_america
colombia_latin = (colombia * 100) / latin_america
mexico_latin = (mexico * 100) / latin_america
venezuela_latin = (venezuela * 100) / latin_america

latin_percentage=pd.DataFrame({ 'Argentina Percentage' : argentina_latin,
                                'Brazil Percentage' : brazil_latin,
                                'Chile Percentage' : chile_latin,
                                'Colombia Percentage' : colombia_latin,
                                'Mexico Percentage' : mexico_latin,
                                'Venezuela Percentage' : venezuela_latin,})

latin_percentage_full=pd.DataFrame({ 'Argentina' : argentina, 'Argentina Percentage' : argentina_latin,
                                'Brazil' : brazil, 'Brazil Percentage' : brazil_latin,
                                'Chile' : chile, 'Chile Percentage' : chile_latin,
                                'Colombia' : colombia, 'Colombia Percentage' : colombia_latin,
                                'Mexico' : mexico, 'Mexico Percentage' : mexico_latin,
                                'Venezuela' : venezuela, 'Venezuela Percentage' : venezuela_latin,
                                'Total' : latin_america})

latin_percentage_full
# Out:
#         Argentina  Argentina Percentage  Brazil  Brazil Percentage  Chile  \
# Year
# 1990.0       44.0              0.818900   141.0           2.624203   14.0
# 1991.0       46.0              0.836213   143.0           2.599532   14.0
# 1992.0       47.0              0.834974   145.0           2.575983   15.0
# 1993.0       48.0              0.845749   148.0           2.607727   16.0
# 1994.0       52.0              0.868193   156.0           2.604580   17.0
# 1995.0       52.0              0.863165   162.0           2.689091   18.0
# 1996.0       54.0              0.856672   170.0           2.696932   20.0
# 1997.0       56.0              0.852236   179.0           2.724111   23.0
# 1998.0       59.0              0.867194   183.0           2.689772   24.0
# 1999.0       61.0              0.872721   187.0           2.675392   25.0
# 2000.0       61.0              0.868387   188.0           2.676339   25.0
# 2001.0       56.0              0.795890   191.0           2.714553   25.0
# ...

# %% [markdown]
# Middle-East

# %%
middle_east = e_cont['Middle-East']

algeria_east = (algeria * 100) / middle_east
egypt_east = (egypt * 100) / middle_east
iran_east = (iran * 100) / middle_east
kuwait_east = (kuwait * 100) / middle_east
saudi_arabia_east = (saudi_arabia * 100) / middle_east
united_emirates_east = (united_emirates * 100) / middle_east


middle_east_percentage = pd.DataFrame({'Algeria Percentage' : algeria_east,
                                       'Egypt Percentage' : egypt_east,
                                       'Iran Percentage' : iran_east,
                                       'Kuwait Percentage' : kuwait_east,
                                       'Sausi Arabia Percentage' : saudi_arabia_east,
                                       'United Arab Emirates Percentage' : united_emirates_east})


middle_east_percentage_full=pd.DataFrame({'Algeria' : algeria, 'Algeria Percentage' : algeria_east,
                                     'Egypt' : egypt, 'Egypt Percentage' : egypt_east,
                                     'Iran' : iran, 'Iran Percentage' : iran_east,
                                     'Kuwait' : kuwait, 'Kuwait Percentage' : kuwait_east,
                                     'Saudi Arabia' : saudi_arabia, 'Sausi Arabia Percentage' : saudi_arabia_east,
                                     'United Arab Emirates' : united_emirates, 'United Arab Emirates Percentage' : united_emirates_east,
                                     'Total' : middle_east})

middle_east_percentage_full
# Out:
#         Algeria  Algeria Percentage  Egypt  Egypt Percentage   Iran  \
# Year
# 1990.0     22.0            0.852099   33.0          1.278148   69.0
# 1991.0     23.0            0.837985   33.0          1.202326   77.0
# 1992.0     24.0            0.778728   34.0          1.103198   81.0
# 1993.0     24.0            0.716538   35.0          1.044951   87.0
# 1994.0     23.0            0.631835   34.0          0.934017   97.0
# 1995.0     24.0            0.640878   36.0          0.961318  101.0
# 1996.0     23.0            0.602940   38.0          0.996162   98.0
# 1997.0     24.0            0.591298   40.0          0.985496  109.0
# 1998.0     25.0            0.612425   42.0          1.028875  111.0
# 1999.0     27.0            0.636050   43.0          1.012968  126.0
# 2000.0     27.0            0.625763   41.0          0.950233  123.0
# 2001.0     27.0            0.578948   47.0          1.007799  133.0
# 2002.0     29.0            0.593703   48.0          0.982680  138.0
# ...

# %% [markdown]
# North America

# %%
north_america = e_cont['North America']

canada_north = (canada * 100) / north_america
mexico_north = (mexico * 100) / north_america
united_states_north = (united_states * 100) / north_america

north_america_percentage=pd.DataFrame({'Canada Percentage' : canada_north,
                                       'Mexico Percentage' : mexico_north,
                                       'United States Percentage' : united_states_north,})

north_america_percentage_full=pd.DataFrame({'Canada' : canada, 'Canada Percentage' : canada_north,
                                       'Mexico' : mexico, 'Mexico Percentage' : mexico_north,
                                       'United States' : united_states, 'United States Percentage' : united_states_north,
                                       'Total' : north_america})

north_america_percentage_full
# Out:
#         Canada  Canada Percentage  Mexico  Mexico Percentage  United States  \
# Year
# 1990.0   211.0           0.855386   124.0           0.502691         1910.0
# 1991.0   210.0           0.845353   130.0           0.523314         1925.0
# 1992.0   216.0           0.852348   131.0           0.516933         1964.0
# 1993.0   223.0           0.863330   133.0           0.514901         1998.0
# 1994.0   231.0           0.876155   136.0           0.515831         2036.0
# 1995.0   234.0           0.875942   132.0           0.494121         2063.0
# 1996.0   239.0           0.875599   135.0           0.494585         2108.0
# 1997.0   242.0           0.877615   142.0           0.514964         2130.0
# 1998.0   240.0           0.864166   146.0           0.525701         2148.0
# 1999.0   247.0           0.865804   150.0           0.525792         2206.0
# 2000.0   254.0           0.865639   151.0           0.514612         2269.0
# ...

# %% [markdown]
# Pacific

# %%
pacific = e_cont['Pacific']

australia_pacific = (australia * 100) / pacific
new_zhealand_pacific = (new_zhealand * 100) / pacific

pacific_percentage=pd.DataFrame({'Australia Percentage' : australia_pacific,
                                 'New Zhealand Percentage' : new_zhealand_pacific})

pacific_percentage_full=pd.DataFrame({'Australia' : australia, 'Australia Percentage' : australia_pacific,
                                      'New Zhealand' : new_zhealand, 'New Zhealand Percentage' : new_zhealand_pacific,
                                      'Total' : pacific})


pacific_percentage_full
# Out:
#         Australia  Australia Percentage  New Zhealand  \
# Year
# 1990.0       86.0              7.179290          14.0
# 1991.0       85.0              7.165377          14.0
# 1992.0       87.0              7.192936          14.0
# 1993.0       91.0              7.178524          15.0
# 1994.0       91.0              7.113265          15.0
# 1995.0       93.0              7.204109          15.0
# 1996.0       99.0              7.213956          16.0
# 1997.0      101.0              7.177220          16.0
# 1998.0      104.0              7.211605          16.0
# 1999.0      106.0              7.176661          17.0
# 2000.0      108.0              7.198704          17.0
# 2001.0      106.0              7.176661          17.0
# 2002.0      109.0              7.154437          17.0
# 2003.0      111.0              7.230517          17.0
# 2004.0      113.0              7.250934          18.0
# 2005.0      113.0              7.197223          17.0
# ...

# %% [markdown]
# Gráficos

# %%
africa_percentage.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
asia_percentage.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
asia_percentage.iloc[: , :6].plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
asia_percentage.iloc[: ,6:12].plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
asia_percentage.iloc[: ,12:].plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
europe_percentage.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
europe_percentage.iloc[:,:6].plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
europe_percentage.iloc[:,6:12].plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
europe_percentage.iloc[:,12:].plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
latin_percentage.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
middle_east_percentage.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
north_america_percentage.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
pacific_percentage.plot()
# Out:
# <AxesSubplot:xlabel='Year'>
